# %%
import numpy as np
import scipy as sp
import sympy as smp
import matplotlib.pyplot as plt
import pandas as pd #Lo necesito para cargar y leer el csv
import tensorflow as tf
import os
import random
import time
import math
import keras 
import json
from datetime import datetime

#import tensorflow
from tensorflow import keras
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from tensorflow.keras.layers import Dense, LSTM, BatchNormalization, Dropout, InputLayer
from tensorflow.keras.models import Sequential #
from sklearn.model_selection import train_test_split
from keras.regularizers import l2, l1, l1_l2
from sklearn.utils import shuffle
import pandas as pd
from scipy.signal import savgol_filter
from scipy.interpolate import CubicSpline
from scipy.ndimage import gaussian_filter1d
#from keras_tuner import RandomSearch
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
# Out:
# 2025-07-18 12:25:10.321954: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-07-18 12:25:10.321981: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-07-18 12:25:10.321988: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
import tensorflow as tf
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available: 2

# %%
tf.keras.backend.set_floatx('float64')

# %% [markdown]
# # **Filtro Discreto para agregar aceleraciones**
# De acuerdo con el paper *Identification of robot forward dynamics via neural network*:
#
# “The corresponding joint accelerations were retrieved through the application of an appropriate discrete filter to the joint velocities just collected.”
#
# Entonces, se tomarán dos datos “de más” (muestra 0 y muestra 101) para permitir aplicar el filtro discreto a las n-2 muestras y tener información de velocidad. Se podrán estudiar otras técnicas para derivar las aceleraciones a partir de las velocidades.

# %%
# Definir una función para calcular las aceleraciones utilizando un filtro de diferencia finita
def calcular_aceleraciones(velocidades, h):
    aceleraciones = []
    for i in range(1, len(velocidades) -1 ):
        # Aplicar el filtro de diferencia finita para calcular la aceleración
        #aceleracion = (velocidades[i + 1] - 2 * velocidades[i] + velocidades[i - 1]) #->Esto no seria la segunda derivada?
        aceleracion = (velocidades[i + 1] -  velocidades[i - 1])/(2*h)
        aceleraciones.append(aceleracion)
    return np.array(aceleraciones)

# Definir una función para calcular las aceleraciones utilizando un filtro de diferencia finita
def calcular_aceleraciones_2(velocidades, h):
    aceleraciones = []
    for i in range(1, len(velocidades) - 4 ):
        # Aplicar el filtro de diferencia finita para calcular la aceleración
        aceleracion = (- velocidades[i + 2] +  8*velocidades[i + 1] - 8*velocidades[i - 2] + velocidades[i - 1]) /(12*h)
        aceleraciones.append(aceleracion)
    return np.array(aceleraciones)



import os, types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.

cos_client = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='1eFnNpgSMiDaf_Yx-ZXteaGaokoLTfIKQXajc1kbdepo',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/identity/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.direct.us-south.cloud-object-storage.appdomain.cloud')

bucket = 'irb140-donotdelete-pr-sdzbp1zcz7qnal'
object_key = 'Output_linear_002_test_NN_NN.csv'

body = cos_client.get_object(Bucket=bucket,Key=object_key)['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_1 = pd.read_csv(body)
df_1.head(10)



def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.

cos_client = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='1eFnNpgSMiDaf_Yx-ZXteaGaokoLTfIKQXajc1kbdepo',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/identity/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.direct.us-south.cloud-object-storage.appdomain.cloud')

bucket = 'irb140-donotdelete-pr-sdzbp1zcz7qnal'
object_key = 'Output_NN_NN_merged_2.csv'

body = cos_client.get_object(Bucket=bucket,Key=object_key)['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_2 = pd.read_csv(body)
df_2.head(10)





def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.

cos_client = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='1eFnNpgSMiDaf_Yx-ZXteaGaokoLTfIKQXajc1kbdepo',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/identity/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.direct.us-south.cloud-object-storage.appdomain.cloud')

bucket = 'irb140-donotdelete-pr-sdzbp1zcz7qnal'
object_key = 'Output_NN_NN_merged.csv'

body = cos_client.get_object(Bucket=bucket,Key=object_key)['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_3 = pd.read_csv(body)
df_3.head(10)



def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.

cos_client = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='1eFnNpgSMiDaf_Yx-ZXteaGaokoLTfIKQXajc1kbdepo',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/identity/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.direct.us-south.cloud-object-storage.appdomain.cloud')

bucket = 'irb140-donotdelete-pr-sdzbp1zcz7qnal'
object_key = 'Output_NN_NN_4e6_fixed.csv'

body = cos_client.get_object(Bucket=bucket,Key=object_key)['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_4 = pd.read_csv(body)
df_4.head(10)



def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.

cos_client = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='1eFnNpgSMiDaf_Yx-ZXteaGaokoLTfIKQXajc1kbdepo',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/identity/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.direct.us-south.cloud-object-storage.appdomain.cloud')

bucket = 'irb140-donotdelete-pr-sdzbp1zcz7qnal'
object_key = 'Output_NN_NN_1.csv'

body = cos_client.get_object(Bucket=bucket,Key=object_key)['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_5 = pd.read_csv(body)
df_5.head(10)



def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.

cos_client = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='1eFnNpgSMiDaf_Yx-ZXteaGaokoLTfIKQXajc1kbdepo',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/identity/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.direct.us-south.cloud-object-storage.appdomain.cloud')

bucket = 'irb140-donotdelete-pr-sdzbp1zcz7qnal'
object_key = 'Output_NN_NN_CUT_MERGED.csv'

body = cos_client.get_object(Bucket=bucket,Key=object_key)['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_6 = pd.read_csv(body)
df_6.head(10)




def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.

cos_client = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='1eFnNpgSMiDaf_Yx-ZXteaGaokoLTfIKQXajc1kbdepo',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/identity/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.direct.us-south.cloud-object-storage.appdomain.cloud')

bucket = 'irb140-donotdelete-pr-sdzbp1zcz7qnal'
object_key = 'Output_linear_NN_NN.csv'

body = cos_client.get_object(Bucket=bucket,Key=object_key)['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_7 = pd.read_csv(body)
df_7.head(10)
# Out:
#    start_time   random_ID   end_time   random_V   random_Z   pos_j1   pos_j2  \
# 0        0.01           1       0.01    44.3387    13.3286  38.8691  56.8166
# 1        0.02           1       0.02    44.3387    13.3286  38.8691  56.8166
# 2        0.03           1       0.03    44.3387    13.3286  38.8692  56.8166
# 3        0.04           1       0.04    44.3387    13.3286  38.8699  56.8153
# 4        0.05           1       0.05    44.3387    13.3286  38.8714  56.8120
# 5        0.06           1       0.06    44.3387    13.3286  38.8763  56.7989
# 6        0.07           1       0.07    44.3387    13.3286  38.8817  56.7832
# 7        0.08           1       0.08    44.3387    13.3286  38.8929  56.7504
# 8        0.09           1       0.09    44.3387    13.3286  38.9018  56.7246
# 9        0.10           1       0.10    44.3387    13.3286  38.9163  56.6832
#
#     pos_j3   pos_j4   pos_j5  ...        vel_j3        vel_j4        vel_j5  \
# 0 -44.4538  27.1509  77.9901  ... -7.966630e-07  6.367170e-07  1.104570e-06
# 1 -44.4538  27.1509  77.9901  ... -2.476310e-07  1.979140e-07  3.433390e-07
# 2 -44.4537  27.1509  77.9901  ...  3.026870e-02  4.242320e-03  2.885760e-03
# 3 -44.4507  27.1520  77.9909  ...  5.273590e-01  2.336480e-01  1.593350e-01
# 4 -44.4418  27.1564  77.9938  ...  1.585330e+00  7.950580e-01  5.422220e-01
# 5 -44.4053  27.1760  78.0072  ...  4.291600e+00  2.351820e+00  1.603630e+00
# 6 -44.3611  27.2004  78.0239  ...  6.281490e+00  3.492510e+00  2.380870e+00
# 7 -44.2693  27.2516  78.0587  ...  8.464700e+00  4.705810e+00  3.206830e+00
# 8 -44.1971  27.2916  78.0860  ...  9.247770e+00  5.125500e+00  3.492240e+00
# 9 -44.0811  27.3558  78.1297  ...  9.772430e+00  5.406370e+00  3.683100e+00
#
#          vel_j6    torq_j1   torq_j2    torq_j3   torq_j4   torq_j5   torq_j6
# 0  1.654760e-06   0.000081  -102.576 -20.845600  0.074018  0.003685  0.000014
# 1  5.143560e-07   0.000025  -102.576 -20.845500  0.074011  0.003668  0.000000
# 2 -3.938810e-03   2.260020  -103.952 -19.350800  0.492498  0.581197 -0.202456
# 3 -2.190560e-01  11.834500  -111.350 -11.681700  2.834510  4.505330 -1.883060
# 4 -7.461850e-01  16.103400  -116.560  -6.329820  3.748950  6.033220 -2.586040
# 5 -2.208290e+00  18.597000  -122.413  -0.557024  4.770580  7.714690 -3.344290
# 6 -3.278950e+00  18.280300  -124.063  -0.119863  5.282180  8.566820 -3.707570
# 7 -4.416410e+00  17.220700  -124.072  -1.504390  5.758580  9.368880 -4.036480
# 8 -4.809320e+00  16.861400  -123.960  -2.147740  5.917320  9.636010 -4.145240
# 9 -5.072010e+00  16.645000  -123.820  -2.589730  6.023040  9.813340 -4.217430
#
# [10 rows x 23 columns]

# %%
import numpy as np

# Variables y configuraciones
num_variables = 6
time_interval = 0.05

datos_IRB_140 = {
    'datos_IRB_140_Output_linear_NN_NN': df_7,
    'datos_IRB_140_Output_NN_NN_merged': df_5,
    'datos_IRB_140_Output_NN_NN_New_2': df_3
}

tcps_vels = {}
tcps_accus = {}

j_poses = {}
j_vels = {}
j_accels = {}
j_torqs = {}
times = {}

# Nombres de los archivos base usados como etiquetas
files = ['Output_linear_NN_NN', 'Output_NN_NN_merged', 'Output_NN_NN_New_2']
datos_IRB_140_st = 'datos_IRB_140_'

tcp_vel = 'rand_v'
tcp_accu = 'rand_z'

j_pos = 'pos_j'
j_vel = 'vel_j'
j_accel = 'acc_j'
j_torq = 'torq_j'

def calcular_aceleraciones(vels, dt):
    """Calcula aceleración usando esquema de diferencias finitas centradas de 5 puntos."""
    acc = np.zeros_like(vels)
    n = len(vels)
    for i in range(2, n - 2):
        acc[i] = (-vels[i + 2] + 8 * vels[i + 1] - 8 * vels[i - 1] + vels[i - 2]) / (12 * dt)
    return acc

# Procesamiento de los dataframes
for file in files:
    print(file)
    variable_name = datos_IRB_140_st + file
    df = datos_IRB_140[variable_name]

    # Tiempo
    time_var = f"{file}_time"
    times[time_var] = df.iloc[:, 0].values

    # Velocidades y aceleraciones TCP
    tcps_vels_name = f"{file}_{tcp_vel}"
    tcps_vels[tcps_vels_name] = df.iloc[1:-1, 3].values

    tcps_accus_name = f"{file}_{tcp_accu}"
    tcps_accus[tcps_accus_name] = df.iloc[1:-1, 4].values

    # Articulaciones
    for i in range(1, num_variables + 1):
        # Posición articular (en radianes)
        pos_j_name = f"{file}_{j_pos}{i}"
        j_poses[pos_j_name] = df.iloc[:, 4 + i].values *(np.pi/180.0)

        # Velocidad articular (en radianes/s)
        vel_j_name = f"{file}_{j_vel}{i}"
        j_vels[vel_j_name] = df.iloc[:, 10 + i].values *(np.pi/180.0)

        # Torque articular
        torq_j_name = f"{file}_{j_torq}{i}"
        j_torqs[torq_j_name] = df.iloc[:, 16 + i].values

        # Torque articular: calcular max y normalizar inmediatamente
        #torq_j_name = f"{file}_{j_torq}{i}"
        #raw_torque = df.iloc[:, 16 + i].values

        #max_torque = np.max(np.abs(raw_torque))
        #if max_torque == 0:
        #    print(f"⚠️ Torque máximo en {file} eje {i} es 0. Se dejará sin normalizar.")
        #    normalized_torque = raw_torque
        #else:
        #    normalized_torque = raw_torque / max_torque

        #j_torqs[torq_j_name] = normalized_torque

        # Aceleración articular (calculada numéricamente)
        acc_j_name = f"{file}_{j_accel}{i}"
        j_accels[acc_j_name] = calcular_aceleraciones(j_vels[vel_j_name], time_interval) *(np.pi/180.0)
# Out:
# Output_linear_NN_NN
# Output_NN_NN_merged
# Output_NN_NN_New_2

# %%
tcps_vels['Output_NN_NN_merged_rand_v']#[2:-2]
tcps_accus['Output_NN_NN_merged_rand_z']#[2:-2]

j_poses['Output_NN_NN_merged_pos_j1']#[2:-2]
j_poses['Output_NN_NN_merged_pos_j2']#[2:-2]
j_poses['Output_NN_NN_merged_pos_j3']#[2:-2]
j_poses['Output_NN_NN_merged_pos_j4']#[2:-2]
j_poses['Output_NN_NN_merged_pos_j5']#[2:-2]
j_poses['Output_NN_NN_merged_pos_j6']#[2:-2]

j_vels['Output_NN_NN_merged_vel_j1']#[2:-2]
j_vels['Output_NN_NN_merged_vel_j2']#[2:-2]
j_vels['Output_NN_NN_merged_vel_j3']#[2:-2]
j_vels['Output_NN_NN_merged_vel_j4']#[2:-2]
j_vels['Output_NN_NN_merged_vel_j5']#[2:-2]
j_vels['Output_NN_NN_merged_vel_j6']#[2:-2]

j_torqs['Output_NN_NN_merged_torq_j1']#[2:-2]
j_torqs['Output_NN_NN_merged_torq_j2']#[2:-2]
j_torqs['Output_NN_NN_merged_torq_j3']#[2:-2]
j_torqs['Output_NN_NN_merged_torq_j4']#[2:-2]
j_torqs['Output_NN_NN_merged_torq_j5']#[2:-2]
j_torqs['Output_NN_NN_merged_torq_j6']#[2:-2]

j_accels['Output_NN_NN_merged_acc_j1']#[2:-2]
j_accels['Output_NN_NN_merged_acc_j2']#[2:-2]
j_accels['Output_NN_NN_merged_acc_j3']#[2:-2]
j_accels['Output_NN_NN_merged_acc_j4']#[2:-2]
j_accels['Output_NN_NN_merged_acc_j5']#[2:-2]
j_accels['Output_NN_NN_merged_acc_j6']#[2:-2]
# Out:
# array([0.00000000e+00, 0.00000000e+00, 1.46989582e-04, ...,
#        1.00269901e-06, 0.00000000e+00, 0.00000000e+00])

# %%
tcps_vels['Output_linear_NN_NN_rand_v']#[2:-2]
tcps_accus['Output_linear_NN_NN_rand_z']#[2:-2]

j_poses['Output_linear_NN_NN_pos_j1']#[2:-2]
j_poses['Output_linear_NN_NN_pos_j2']#[2:-2]
j_poses['Output_linear_NN_NN_pos_j3']#[2:-2]
j_poses['Output_linear_NN_NN_pos_j4']#[2:-2]
j_poses['Output_linear_NN_NN_pos_j5']#[2:-2]
j_poses['Output_linear_NN_NN_pos_j6']#[2:-2]

j_vels['Output_linear_NN_NN_vel_j1']#[2:-2]
j_vels['Output_linear_NN_NN_vel_j2']#[2:-2]
j_vels['Output_linear_NN_NN_vel_j3']#[2:-2]
j_vels['Output_linear_NN_NN_vel_j4']#[2:-2]
j_vels['Output_linear_NN_NN_vel_j5']#[2:-2]
j_vels['Output_linear_NN_NN_vel_j6']#[2:-2]

j_torqs['Output_linear_NN_NN_torq_j1']#[2:-2]
j_torqs['Output_linear_NN_NN_torq_j2']#[2:-2]
j_torqs['Output_linear_NN_NN_torq_j3']#[2:-2]
j_torqs['Output_linear_NN_NN_torq_j4']#[2:-2]
j_torqs['Output_linear_NN_NN_torq_j5']#[2:-2]
j_torqs['Output_linear_NN_NN_torq_j6']#[2:-2]

j_accels['Output_linear_NN_NN_acc_j1']#[2:-2]
j_accels['Output_linear_NN_NN_acc_j2']#[2:-2]
j_accels['Output_linear_NN_NN_acc_j3']#[2:-2]
j_accels['Output_linear_NN_NN_acc_j4']#[2:-2]
j_accels['Output_linear_NN_NN_acc_j5']#[2:-2]
j_accels['Output_linear_NN_NN_acc_j6']#[2:-2]
# Out:
# array([ 0.00000000e+00,  0.00000000e+00, -5.10876647e-04, ...,
#        -3.22950787e-18,  0.00000000e+00,  0.00000000e+00])

# %%
print(j_poses['Output_NN_NN_merged_pos_j6'].shape)
print(j_accels['Output_NN_NN_merged_acc_j6'].shape)
# Out:
# (299999,)
# (299999,)

# %%
print(j_accels['Output_NN_NN_merged_acc_j6'][2:-2].shape)
# Out:
# (299995,)

# %%
pos_j1 = np.concatenate([j_poses['Output_NN_NN_merged_pos_j1'][2:-2],j_poses['Output_linear_NN_NN_pos_j1'][2:-2]])
pos_j2 = np.concatenate([j_poses['Output_NN_NN_merged_pos_j2'][2:-2],j_poses['Output_linear_NN_NN_pos_j2'][2:-2]])
pos_j3 = np.concatenate([j_poses['Output_NN_NN_merged_pos_j3'][2:-2],j_poses['Output_linear_NN_NN_pos_j3'][2:-2]])
pos_j4 = np.concatenate([j_poses['Output_NN_NN_merged_pos_j4'][2:-2],j_poses['Output_linear_NN_NN_pos_j4'][2:-2]])
pos_j5 = np.concatenate([j_poses['Output_NN_NN_merged_pos_j5'][2:-2],j_poses['Output_linear_NN_NN_pos_j5'][2:-2]])
pos_j6 = np.concatenate([j_poses['Output_NN_NN_merged_pos_j6'][2:-2],j_poses['Output_linear_NN_NN_pos_j6'][2:-2]])

vels_j1 = np.concatenate([j_vels['Output_NN_NN_merged_vel_j1'][2:-2],j_vels['Output_linear_NN_NN_vel_j1'][2:-2]])
vels_j2 = np.concatenate([j_vels['Output_NN_NN_merged_vel_j2'][2:-2],j_vels['Output_linear_NN_NN_vel_j2'][2:-2]])
vels_j3 = np.concatenate([j_vels['Output_NN_NN_merged_vel_j3'][2:-2],j_vels['Output_linear_NN_NN_vel_j3'][2:-2]])
vels_j4 = np.concatenate([j_vels['Output_NN_NN_merged_vel_j4'][2:-2],j_vels['Output_linear_NN_NN_vel_j4'][2:-2]])
vels_j5 = np.concatenate([j_vels['Output_NN_NN_merged_vel_j5'][2:-2],j_vels['Output_linear_NN_NN_vel_j5'][2:-2]])
vels_j6 = np.concatenate([j_vels['Output_NN_NN_merged_vel_j6'][2:-2],j_vels['Output_linear_NN_NN_vel_j6'][2:-2]])

torq_j1 = np.concatenate([j_torqs['Output_NN_NN_merged_torq_j1'][2:-2],j_torqs['Output_linear_NN_NN_torq_j1'][2:-2]])
torq_j2 = np.concatenate([j_torqs['Output_NN_NN_merged_torq_j2'][2:-2],j_torqs['Output_linear_NN_NN_torq_j2'][2:-2]])
torq_j3 = np.concatenate([j_torqs['Output_NN_NN_merged_torq_j3'][2:-2],j_torqs['Output_linear_NN_NN_torq_j3'][2:-2]])
torq_j4 = np.concatenate([j_torqs['Output_NN_NN_merged_torq_j4'][2:-2],j_torqs['Output_linear_NN_NN_torq_j4'][2:-2]])
torq_j5 = np.concatenate([j_torqs['Output_NN_NN_merged_torq_j5'][2:-2],j_torqs['Output_linear_NN_NN_torq_j5'][2:-2]])
torq_j6 = np.concatenate([j_torqs['Output_NN_NN_merged_torq_j6'][2:-2],j_torqs['Output_linear_NN_NN_torq_j6'][2:-2]])

accs_j1 = np.concatenate([j_accels['Output_NN_NN_merged_acc_j1'][2:-2],j_accels['Output_linear_NN_NN_acc_j1'][2:-2]])
accs_j2 = np.concatenate([j_accels['Output_NN_NN_merged_acc_j2'][2:-2],j_accels['Output_linear_NN_NN_acc_j2'][2:-2]])
accs_j3 = np.concatenate([j_accels['Output_NN_NN_merged_acc_j3'][2:-2],j_accels['Output_linear_NN_NN_acc_j3'][2:-2]])
accs_j4 = np.concatenate([j_accels['Output_NN_NN_merged_acc_j4'][2:-2],j_accels['Output_linear_NN_NN_acc_j4'][2:-2]])
accs_j5 = np.concatenate([j_accels['Output_NN_NN_merged_acc_j5'][2:-2],j_accels['Output_linear_NN_NN_acc_j5'][2:-2]])
accs_j6 = np.concatenate([j_accels['Output_NN_NN_merged_acc_j6'][2:-2],j_accels['Output_linear_NN_NN_acc_j6'][2:-2]])

# %%
#Los dos primeros y los dos ultimos puntos no tienen informacion de aceleración, ya que la misma usa cuatro puntos para reconsruirse
#time_joint= times['Output_NN_NN_merged_time'][2:-2]

#pos_j1 = j_poses['Output_NN_NN_merged_pos_j1'][2:-2]  #34440 -> 34438, k
#pos_j2 = j_poses['Output_NN_NN_merged_pos_j2'][2:-2]
#pos_j3 = j_poses['Output_NN_NN_merged_pos_j3'][2:-2]
#pos_j4 = j_poses['Output_NN_NN_merged_pos_j4'][2:-2]
#pos_j5 = j_poses['Output_NN_NN_merged_pos_j5'][2:-2]
#pos_j6 = j_poses['Output_NN_NN_merged_pos_j6'][2:-2]

#vels_j1 = j_vels['Output_NN_NN_merged_vel_j1'][2:-2]  #34440 -> 34438 k
#vels_j2 = j_vels['Output_NN_NN_merged_vel_j2'][2:-2]
#vels_j3 = j_vels['Output_NN_NN_merged_vel_j3'][2:-2]
#vels_j4 = j_vels['Output_NN_NN_merged_vel_j4'][2:-2] 
#vels_j5 = j_vels['Output_NN_NN_merged_vel_j5'][2:-2]
#vels_j6 = j_vels['Output_NN_NN_merged_vel_j6'][2:-2]

#torq_j1 = j_torqs['Output_NN_NN_merged_torq_j1'][2:-2] #34440 -> 34438 k
#torq_j2 = j_torqs['Output_NN_NN_merged_torq_j2'][2:-2]
#torq_j3 = j_torqs['Output_NN_NN_merged_torq_j3'][2:-2]
#torq_j4 = j_torqs['Output_NN_NN_merged_torq_j4'][2:-2] 
#torq_j5 = j_torqs['Output_NN_NN_merged_torq_j5'][2:-2]
#torq_j6 = j_torqs['Output_NN_NN_merged_torq_j6'][2:-2]

#accs_j1 = j_accels['Output_NN_NN_merged_acc_j1'][2:-2]  #34438 k
#accs_j2 = j_accels['Output_NN_NN_merged_acc_j2'][2:-2] 
#accs_j3 = j_accels['Output_NN_NN_merged_acc_j3'][2:-2] 
#accs_j4 = j_accels['Output_NN_NN_merged_acc_j4'][2:-2]
#accs_j5 = j_accels['Output_NN_NN_merged_acc_j5'][2:-2]
#accs_j6 = j_accels['Output_NN_NN_merged_acc_j6'][2:-2]

# %% [markdown]
# # **PROBLEMA DINÁMICO INVERSO**

# %%
inputs = np.vstack((pos_j1, pos_j2, pos_j3, pos_j4, pos_j5, pos_j6, vels_j1, vels_j2, vels_j3, vels_j4, vels_j5, vels_j6, accs_j1, accs_j2, accs_j3, accs_j4, accs_j5, accs_j6)).T
outputs = np.vstack((torq_j1, torq_j2, torq_j3, torq_j4, torq_j5, torq_j6)).T

# %% [markdown]
# # Red Feed-Forward

# %%
X_train_FF, X_test_FF, y_train_FF, y_test_FF = train_test_split(inputs, outputs, test_size = 0.2)

#Tengo que hacer preprocesado de los datos para que los calculos no sean tan pesados
scaler1_FF = StandardScaler() #RobustScaler()#
X_train_FF = scaler1_FF.fit_transform(X_train_FF)#Primero se llama a la funcion fit para que ajuste los datos
X_test_FF = scaler1_FF.transform(X_test_FF) #Una vez que los datos fueron ajustados se puede llamar a la transformacion directamente
#X_val_FF = scaler1_FF.transform(X_val_FF)

#Lo mismo para los outputs
scaler2_FF = StandardScaler() #RobustScaler()#
y_train_FF = scaler2_FF.fit_transform(y_train_FF)
y_test_FF = scaler2_FF.transform(y_test_FF)
#y_val_FF = scaler2_FF.transform(y_val_FF)

# %%
# Verificar si el modelo ya existe

FF_NN_model_path = "ff_nn_Best_Model.h5"
FF_NN_history_path = "ff_nn_best_history.json"

if os.path.exists(FF_NN_model_path):
    print("🔄 Cargando modelo FF NN existente...")
    FF_SS_network = keras.models.load_model(FF_NN_model_path)
    FF_SS_network.summary()

    if os.path.exists(FF_NN_history_path):
        with open(FF_NN_history_path, "r") as f:
            FF_NN_history = json.load(f)  # Load the history data as a dictionary

        # Create a dummy History object for plotting:
        #FF_NN_history = type('DummyHistory', (object,), {'history': FF_NN_history_dict})()

        # Graficar el history
        plt.figure(figsize=(8, 5))
        plt.plot(FF_NN_history["loss"], label="Training Loss")
        plt.plot(FF_NN_history["val_loss"], label="Validation Loss")
        plt.legend()
        plt.xlabel("Épocas")
        plt.ylabel("Loss")
        plt.grid(True)
        plt.gca().set_ylim(0, 2e-3)
        plt.title("Historial de entrenamiento del modelo FF NN (Dataset Random)")
        plt.show()
    else:
        print("⚠️ No se encontró el archivo de history.")
else:
    print("⚙️ Creando nuevo modelo...")
    #Esta forma es lo más parecida posible al paper
    FF_NN_network = keras.models.Sequential([
        keras.layers.Input(shape=(inputs.shape[1],)),  # Input layer with the shape of the input data
        #keras.layers.LayerNormalization(epsilon=1e-4),
        keras.layers.Dense(100, activation="swish"),  # First hidden layer with GELU activation
        #keras.layers.Dense(100, activation="swish"),
        keras.layers.Dense(100, activation="swish"),
        #keras.layers.Dense(200, activation="tanh"),
        keras.layers.Dense(6)
    ])
    FF_NN_network.summary()

    FF_NN_network.compile(loss = 'mean_squared_error', optimizer=keras.optimizers.Adam(learning_rate=1e-3), 
                          metrics = ['mae'])#Que pasa si uso SGD con learning rate

    checkpoint_cb = keras.callbacks.ModelCheckpoint(FF_NN_model_path, 
                                                    save_best_only=True)
    early_stopping_cb = keras.callbacks.EarlyStopping(patience=200, min_delta=1e-10, restore_best_weights=True)

    reduce_lr = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=20, min_lr=1e-8)       
    FF_NN_history = FF_NN_network.fit(X_train_FF, y_train_FF, epochs=1000, 
                                      batch_size=300, validation_split=0.3, shuffle=True, 
                                      callbacks=[checkpoint_cb, early_stopping_cb])

    with open(FF_NN_history_path, "w") as f:
        json.dump(FF_NN_history.history, f)
    with open(FF_NN_history_path, "r") as f:
        FF_NN_history = json.load(f)  # Load the history data as a dictionary

    # Create a dummy History object for plotting:
    #FF_NN_history = type('DummyHistory', (object,), {'history': FF_NN_history_dict})()

    pd.DataFrame(FF_NN_history).plot(figsize=(8, 5))
    plt.grid(True)
    #plt.gca().set_xlim(0, 1)
    plt.gca().set_ylim(0, 2e-3)
    plt.show()

print("✅ Modelo FF NN listo para usar.")
# Out:
# ⚙️ Creando nuevo modelo...
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 100)               1900
#
#  dense_4 (Dense)             (None, 100)               10100
#
#  dense_5 (Dense)             (None, 6)                 606
#
# =================================================================
# Total params: 12606 (98.48 KB)
# Trainable params: 12606 (98.48 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/1000
# 1120/1120 [==============================] - 11s 8ms/step - loss: 0.1891 - mae: 0.3571 - val_loss: 0.0968 - val_mae: 0.2511
# Epoch 2/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0719 - mae: 0.2111 - val_loss: 0.0539 - val_mae: 0.1782
# Epoch 3/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0424 - mae: 0.1553 - val_loss: 0.0337 - val_mae: 0.1358
# Epoch 4/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0273 - mae: 0.1205 - val_loss: 0.0225 - val_mae: 0.1073
# Epoch 5/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0188 - mae: 0.0973 - val_loss: 0.0162 - val_mae: 0.0888
# Epoch 6/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0144 - mae: 0.0830 - val_loss: 0.0127 - val_mae: 0.0766
# Epoch 7/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0117 - mae: 0.0731 - val_loss: 0.0112 - val_mae: 0.0702
# Epoch 8/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0101 - mae: 0.0664 - val_loss: 0.0095 - val_mae: 0.0630
# Epoch 9/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0088 - mae: 0.0609 - val_loss: 0.0084 - val_mae: 0.0591
# Epoch 10/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0079 - mae: 0.0571 - val_loss: 0.0077 - val_mae: 0.0554
# Epoch 11/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0072 - mae: 0.0537 - val_loss: 0.0069 - val_mae: 0.0519
# Epoch 12/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0067 - mae: 0.0510 - val_loss: 0.0065 - val_mae: 0.0498
# Epoch 13/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0062 - mae: 0.0487 - val_loss: 0.0063 - val_mae: 0.0478
# Epoch 14/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0059 - mae: 0.0466 - val_loss: 0.0057 - val_mae: 0.0452
# Epoch 15/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0055 - mae: 0.0446 - val_loss: 0.0053 - val_mae: 0.0427
# Epoch 16/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0052 - mae: 0.0429 - val_loss: 0.0056 - val_mae: 0.0445
# Epoch 17/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0049 - mae: 0.0415 - val_loss: 0.0048 - val_mae: 0.0406
# Epoch 18/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0047 - mae: 0.0401 - val_loss: 0.0046 - val_mae: 0.0391
# Epoch 19/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0045 - mae: 0.0390 - val_loss: 0.0043 - val_mae: 0.0373
# Epoch 20/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0042 - mae: 0.0376 - val_loss: 0.0043 - val_mae: 0.0371
# Epoch 21/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0042 - mae: 0.0372 - val_loss: 0.0041 - val_mae: 0.0366
# Epoch 22/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0039 - mae: 0.0359 - val_loss: 0.0039 - val_mae: 0.0354
# Epoch 23/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0037 - mae: 0.0349 - val_loss: 0.0038 - val_mae: 0.0345
# Epoch 24/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0036 - mae: 0.0343 - val_loss: 0.0037 - val_mae: 0.0338
# Epoch 25/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0035 - mae: 0.0336 - val_loss: 0.0034 - val_mae: 0.0324
# Epoch 26/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0034 - mae: 0.0328 - val_loss: 0.0035 - val_mae: 0.0328
# Epoch 27/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0033 - mae: 0.0322 - val_loss: 0.0034 - val_mae: 0.0335
# Epoch 28/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0032 - mae: 0.0314 - val_loss: 0.0033 - val_mae: 0.0323
# Epoch 29/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0031 - mae: 0.0311 - val_loss: 0.0033 - val_mae: 0.0329
# Epoch 30/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0030 - mae: 0.0305 - val_loss: 0.0032 - val_mae: 0.0313
# Epoch 31/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0030 - mae: 0.0301 - val_loss: 0.0030 - val_mae: 0.0297
# Epoch 32/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0029 - mae: 0.0296 - val_loss: 0.0030 - val_mae: 0.0301
# Epoch 33/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0028 - mae: 0.0289 - val_loss: 0.0036 - val_mae: 0.0282
# Epoch 34/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0028 - mae: 0.0289 - val_loss: 0.0031 - val_mae: 0.0292
# Epoch 35/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0027 - mae: 0.0281 - val_loss: 0.0028 - val_mae: 0.0288
# Epoch 36/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0026 - mae: 0.0280 - val_loss: 0.0027 - val_mae: 0.0281
# Epoch 37/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0026 - mae: 0.0275 - val_loss: 0.0026 - val_mae: 0.0267
# Epoch 38/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0025 - mae: 0.0271 - val_loss: 0.0026 - val_mae: 0.0266
# Epoch 39/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0025 - mae: 0.0268 - val_loss: 0.0026 - val_mae: 0.0280
# Epoch 40/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0024 - mae: 0.0265 - val_loss: 0.0025 - val_mae: 0.0263
# Epoch 41/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0023 - mae: 0.0261 - val_loss: 0.0024 - val_mae: 0.0262
# Epoch 42/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0023 - mae: 0.0257 - val_loss: 0.0024 - val_mae: 0.0256
# Epoch 43/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0023 - mae: 0.0257 - val_loss: 0.0025 - val_mae: 0.0271
# Epoch 44/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0023 - mae: 0.0256 - val_loss: 0.0025 - val_mae: 0.0273
# Epoch 45/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0022 - mae: 0.0251 - val_loss: 0.0024 - val_mae: 0.0258
# Epoch 46/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0021 - mae: 0.0246 - val_loss: 0.0022 - val_mae: 0.0245
# Epoch 47/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0021 - mae: 0.0244 - val_loss: 0.0022 - val_mae: 0.0243
# Epoch 48/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0021 - mae: 0.0243 - val_loss: 0.0021 - val_mae: 0.0237
# Epoch 49/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0021 - mae: 0.0241 - val_loss: 0.0021 - val_mae: 0.0234
# Epoch 50/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0020 - mae: 0.0238 - val_loss: 0.0020 - val_mae: 0.0234
# Epoch 51/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0020 - mae: 0.0237 - val_loss: 0.0020 - val_mae: 0.0234
# Epoch 52/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0020 - mae: 0.0235 - val_loss: 0.0020 - val_mae: 0.0232
# Epoch 53/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0019 - mae: 0.0233 - val_loss: 0.0021 - val_mae: 0.0244
# Epoch 54/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0019 - mae: 0.0230 - val_loss: 0.0020 - val_mae: 0.0229
# Epoch 55/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0019 - mae: 0.0228 - val_loss: 0.0019 - val_mae: 0.0226
# Epoch 56/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0019 - mae: 0.0228 - val_loss: 0.0019 - val_mae: 0.0232
# Epoch 57/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0019 - mae: 0.0228 - val_loss: 0.0020 - val_mae: 0.0233
# Epoch 58/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0018 - mae: 0.0225 - val_loss: 0.0021 - val_mae: 0.0219
# Epoch 59/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0019 - mae: 0.0228 - val_loss: 0.0019 - val_mae: 0.0225
# Epoch 60/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0018 - mae: 0.0219 - val_loss: 0.0018 - val_mae: 0.0211
# Epoch 61/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0018 - mae: 0.0221 - val_loss: 0.0019 - val_mae: 0.0224
# Epoch 62/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0017 - mae: 0.0219 - val_loss: 0.0017 - val_mae: 0.0205
# Epoch 63/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0017 - mae: 0.0216 - val_loss: 0.0018 - val_mae: 0.0216
# Epoch 64/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0019 - mae: 0.0222 - val_loss: 0.0019 - val_mae: 0.0211
# Epoch 65/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0017 - mae: 0.0216 - val_loss: 0.0017 - val_mae: 0.0214
# Epoch 66/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0017 - mae: 0.0212 - val_loss: 0.0018 - val_mae: 0.0209
# Epoch 67/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0016 - mae: 0.0210 - val_loss: 0.0017 - val_mae: 0.0211
# Epoch 68/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0016 - mae: 0.0210 - val_loss: 0.0018 - val_mae: 0.0214
# Epoch 69/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0016 - mae: 0.0211 - val_loss: 0.0017 - val_mae: 0.0212
# Epoch 70/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0016 - mae: 0.0207 - val_loss: 0.0018 - val_mae: 0.0223
# Epoch 71/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0016 - mae: 0.0208 - val_loss: 0.0017 - val_mae: 0.0210
# Epoch 72/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0016 - mae: 0.0209 - val_loss: 0.0016 - val_mae: 0.0198
# Epoch 73/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0016 - mae: 0.0206 - val_loss: 0.0017 - val_mae: 0.0207
# Epoch 74/1000
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0015 - mae: 0.0204 - val_loss: 0.0015 - val_mae: 0.0191
# Epoch 75/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0016 - mae: 0.0207 - val_loss: 0.0016 - val_mae: 0.0217
# Epoch 76/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0015 - mae: 0.0201 - val_loss: 0.0016 - val_mae: 0.0204
# Epoch 77/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0015 - mae: 0.0203 - val_loss: 0.0018 - val_mae: 0.0215
# Epoch 78/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0016 - mae: 0.0207 - val_loss: 0.0020 - val_mae: 0.0227
# Epoch 79/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0015 - mae: 0.0199 - val_loss: 0.0016 - val_mae: 0.0195
# Epoch 80/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0015 - mae: 0.0198 - val_loss: 0.0016 - val_mae: 0.0208
# Epoch 81/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0015 - mae: 0.0199 - val_loss: 0.0016 - val_mae: 0.0200
# Epoch 82/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0015 - mae: 0.0200 - val_loss: 0.0017 - val_mae: 0.0218
# Epoch 83/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0016 - mae: 0.0205 - val_loss: 0.0015 - val_mae: 0.0192
# Epoch 84/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0014 - mae: 0.0196 - val_loss: 0.0015 - val_mae: 0.0198
# Epoch 85/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0014 - mae: 0.0195 - val_loss: 0.0015 - val_mae: 0.0189
# Epoch 86/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0014 - mae: 0.0194 - val_loss: 0.0014 - val_mae: 0.0187
# Epoch 87/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0014 - mae: 0.0192 - val_loss: 0.0015 - val_mae: 0.0192
# Epoch 88/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0014 - mae: 0.0196 - val_loss: 0.0015 - val_mae: 0.0196
# Epoch 89/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0014 - mae: 0.0190 - val_loss: 0.0014 - val_mae: 0.0184
# Epoch 90/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0015 - mae: 0.0200 - val_loss: 0.0014 - val_mae: 0.0186
# Epoch 91/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0014 - mae: 0.0190 - val_loss: 0.0014 - val_mae: 0.0190
# Epoch 92/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0014 - mae: 0.0190 - val_loss: 0.0014 - val_mae: 0.0182
# Epoch 93/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0013 - mae: 0.0188 - val_loss: 0.0014 - val_mae: 0.0186
# Epoch 94/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0013 - mae: 0.0188 - val_loss: 0.0014 - val_mae: 0.0191
# Epoch 95/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0014 - mae: 0.0191 - val_loss: 0.0014 - val_mae: 0.0180
# Epoch 96/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0013 - mae: 0.0185 - val_loss: 0.0015 - val_mae: 0.0199
# Epoch 97/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0014 - mae: 0.0194 - val_loss: 0.0015 - val_mae: 0.0192
# Epoch 98/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0013 - mae: 0.0184 - val_loss: 0.0014 - val_mae: 0.0184
# Epoch 99/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0013 - mae: 0.0183 - val_loss: 0.0014 - val_mae: 0.0185
# Epoch 100/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0013 - mae: 0.0183 - val_loss: 0.0014 - val_mae: 0.0186
# Epoch 101/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0013 - mae: 0.0182 - val_loss: 0.0014 - val_mae: 0.0182
# Epoch 102/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0013 - mae: 0.0183 - val_loss: 0.0013 - val_mae: 0.0183
# Epoch 103/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0015 - mae: 0.0194 - val_loss: 0.0014 - val_mae: 0.0186
# Epoch 104/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0013 - mae: 0.0181 - val_loss: 0.0013 - val_mae: 0.0189
# Epoch 105/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0012 - mae: 0.0179 - val_loss: 0.0013 - val_mae: 0.0180
# Epoch 106/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0012 - mae: 0.0178 - val_loss: 0.0013 - val_mae: 0.0176
# Epoch 107/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0012 - mae: 0.0180 - val_loss: 0.0013 - val_mae: 0.0183
# Epoch 108/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0012 - mae: 0.0177 - val_loss: 0.0013 - val_mae: 0.0170
# Epoch 109/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0012 - mae: 0.0177 - val_loss: 0.0013 - val_mae: 0.0177
# Epoch 110/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0012 - mae: 0.0176 - val_loss: 0.0012 - val_mae: 0.0172
# Epoch 111/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0012 - mae: 0.0175 - val_loss: 0.0013 - val_mae: 0.0188
# Epoch 112/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0012 - mae: 0.0176 - val_loss: 0.0013 - val_mae: 0.0171
# Epoch 113/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0012 - mae: 0.0175 - val_loss: 0.0013 - val_mae: 0.0179
# Epoch 114/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0011 - mae: 0.0173 - val_loss: 0.0013 - val_mae: 0.0165
# Epoch 115/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0014 - mae: 0.0187 - val_loss: 0.0013 - val_mae: 0.0176
# Epoch 116/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0012 - mae: 0.0179 - val_loss: 0.0012 - val_mae: 0.0163
# Epoch 117/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0011 - mae: 0.0171 - val_loss: 0.0012 - val_mae: 0.0167
# Epoch 118/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0012 - mae: 0.0174 - val_loss: 0.0012 - val_mae: 0.0165
# Epoch 119/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0011 - mae: 0.0169 - val_loss: 0.0013 - val_mae: 0.0184
# Epoch 120/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0011 - mae: 0.0171 - val_loss: 0.0013 - val_mae: 0.0180
# Epoch 121/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0011 - mae: 0.0171 - val_loss: 0.0013 - val_mae: 0.0174
# Epoch 122/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0011 - mae: 0.0169 - val_loss: 0.0011 - val_mae: 0.0162
# Epoch 123/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0011 - mae: 0.0170 - val_loss: 0.0012 - val_mae: 0.0170
# Epoch 124/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0011 - mae: 0.0169 - val_loss: 0.0012 - val_mae: 0.0175
# Epoch 125/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0011 - mae: 0.0167 - val_loss: 0.0011 - val_mae: 0.0164
# Epoch 126/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0012 - mae: 0.0175 - val_loss: 0.0015 - val_mae: 0.0172
# Epoch 127/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0011 - mae: 0.0165 - val_loss: 0.0012 - val_mae: 0.0166
# Epoch 128/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0011 - mae: 0.0165 - val_loss: 0.0012 - val_mae: 0.0171
# Epoch 129/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0011 - mae: 0.0165 - val_loss: 0.0012 - val_mae: 0.0168
# Epoch 130/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0011 - mae: 0.0167 - val_loss: 0.0011 - val_mae: 0.0159
# Epoch 131/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0011 - mae: 0.0165 - val_loss: 0.0021 - val_mae: 0.0175
# Epoch 132/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0012 - mae: 0.0174 - val_loss: 0.0012 - val_mae: 0.0165
# Epoch 133/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0010 - mae: 0.0163 - val_loss: 0.0011 - val_mae: 0.0169
# Epoch 134/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0010 - mae: 0.0163 - val_loss: 0.0011 - val_mae: 0.0161
# Epoch 135/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0010 - mae: 0.0162 - val_loss: 0.0011 - val_mae: 0.0163
# Epoch 136/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0010 - mae: 0.0161 - val_loss: 0.0011 - val_mae: 0.0162
# Epoch 137/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0010 - mae: 0.0161 - val_loss: 0.0011 - val_mae: 0.0163
# Epoch 138/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0010 - mae: 0.0161 - val_loss: 0.0012 - val_mae: 0.0160
# Epoch 139/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 9.9246e-04 - mae: 0.0159 - val_loss: 0.0011 - val_mae: 0.0154
# Epoch 140/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0010 - mae: 0.0161 - val_loss: 0.0011 - val_mae: 0.0156
# Epoch 141/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 9.8057e-04 - mae: 0.0158 - val_loss: 0.0011 - val_mae: 0.0165
# Epoch 142/1000
# 1120/1120 [==============================] - 10s 8ms/step - loss: 0.0010 - mae: 0.0161 - val_loss: 0.0012 - val_mae: 0.0163
# Epoch 143/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0010 - mae: 0.0161 - val_loss: 0.0011 - val_mae: 0.0167
# Epoch 144/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0010 - mae: 0.0161 - val_loss: 0.0011 - val_mae: 0.0157
# Epoch 145/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 9.7248e-04 - mae: 0.0158 - val_loss: 0.0011 - val_mae: 0.0146
# Epoch 146/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 9.5595e-04 - mae: 0.0157 - val_loss: 0.0011 - val_mae: 0.0168
# Epoch 147/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 9.8303e-04 - mae: 0.0159 - val_loss: 0.0011 - val_mae: 0.0169
# Epoch 148/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 9.9087e-04 - mae: 0.0159 - val_loss: 0.0011 - val_mae: 0.0158
# Epoch 149/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 9.3917e-04 - mae: 0.0154 - val_loss: 0.0010 - val_mae: 0.0162
# Epoch 150/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 9.3757e-04 - mae: 0.0156 - val_loss: 0.0010 - val_mae: 0.0152
# Epoch 151/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0011 - mae: 0.0162 - val_loss: 0.0011 - val_mae: 0.0160
# Epoch 152/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 9.2803e-04 - mae: 0.0154 - val_loss: 0.0011 - val_mae: 0.0172
# Epoch 153/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 9.2742e-04 - mae: 0.0154 - val_loss: 0.0011 - val_mae: 0.0172
# Epoch 154/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 9.4472e-04 - mae: 0.0155 - val_loss: 0.0010 - val_mae: 0.0148
# Epoch 155/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 9.1136e-04 - mae: 0.0153 - val_loss: 9.8649e-04 - val_mae: 0.0150
# Epoch 156/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 8.9025e-04 - mae: 0.0151 - val_loss: 0.0011 - val_mae: 0.0172
# Epoch 157/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 9.0819e-04 - mae: 0.0153 - val_loss: 0.0010 - val_mae: 0.0157
# Epoch 158/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 8.9671e-04 - mae: 0.0151 - val_loss: 0.0014 - val_mae: 0.0222
# Epoch 159/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 9.1242e-04 - mae: 0.0154 - val_loss: 0.0011 - val_mae: 0.0161
# Epoch 160/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 8.8987e-04 - mae: 0.0151 - val_loss: 0.0010 - val_mae: 0.0159
# Epoch 161/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 8.6901e-04 - mae: 0.0149 - val_loss: 0.0010 - val_mae: 0.0163
# Epoch 162/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 9.7948e-04 - mae: 0.0157 - val_loss: 0.0010 - val_mae: 0.0158
# Epoch 163/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 8.7341e-04 - mae: 0.0149 - val_loss: 0.0012 - val_mae: 0.0178
# Epoch 164/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 8.9227e-04 - mae: 0.0152 - val_loss: 0.0010 - val_mae: 0.0148
# Epoch 165/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 9.0943e-04 - mae: 0.0153 - val_loss: 9.0505e-04 - val_mae: 0.0136
# Epoch 166/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 8.8089e-04 - mae: 0.0149 - val_loss: 0.0012 - val_mae: 0.0167
# Epoch 167/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 8.7997e-04 - mae: 0.0151 - val_loss: 9.0053e-04 - val_mae: 0.0144
# Epoch 168/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 8.4245e-04 - mae: 0.0147 - val_loss: 0.0010 - val_mae: 0.0158
# Epoch 169/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 8.5707e-04 - mae: 0.0148 - val_loss: 0.0010 - val_mae: 0.0161
# Epoch 170/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 8.4124e-04 - mae: 0.0147 - val_loss: 0.0010 - val_mae: 0.0158
# Epoch 171/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0010 - mae: 0.0159 - val_loss: 0.0013 - val_mae: 0.0161
# Epoch 172/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 8.8404e-04 - mae: 0.0150 - val_loss: 9.2588e-04 - val_mae: 0.0143
# Epoch 173/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 8.2191e-04 - mae: 0.0144 - val_loss: 9.2551e-04 - val_mae: 0.0152
# Epoch 174/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 8.3147e-04 - mae: 0.0146 - val_loss: 0.0010 - val_mae: 0.0154
# Epoch 175/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 8.2787e-04 - mae: 0.0145 - val_loss: 0.0011 - val_mae: 0.0161
# Epoch 176/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 8.4262e-04 - mae: 0.0147 - val_loss: 9.3297e-04 - val_mae: 0.0146
# Epoch 177/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 8.1730e-04 - mae: 0.0144 - val_loss: 9.6338e-04 - val_mae: 0.0146
# Epoch 178/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 8.4775e-04 - mae: 0.0147 - val_loss: 9.1146e-04 - val_mae: 0.0142
# Epoch 179/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 8.6834e-04 - mae: 0.0147 - val_loss: 9.5469e-04 - val_mae: 0.0143
# Epoch 180/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 8.6784e-04 - mae: 0.0148 - val_loss: 9.0186e-04 - val_mae: 0.0138
# Epoch 181/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 8.0437e-04 - mae: 0.0143 - val_loss: 9.4932e-04 - val_mae: 0.0142
# Epoch 182/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 7.9537e-04 - mae: 0.0142 - val_loss: 9.2412e-04 - val_mae: 0.0145
# Epoch 183/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 8.0090e-04 - mae: 0.0143 - val_loss: 8.9024e-04 - val_mae: 0.0143
# Epoch 184/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 7.9357e-04 - mae: 0.0142 - val_loss: 0.0011 - val_mae: 0.0157
# Epoch 185/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 8.0868e-04 - mae: 0.0143 - val_loss: 0.0011 - val_mae: 0.0162
# Epoch 186/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 8.7575e-04 - mae: 0.0148 - val_loss: 8.5722e-04 - val_mae: 0.0138
# Epoch 187/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 7.7780e-04 - mae: 0.0140 - val_loss: 8.5155e-04 - val_mae: 0.0142
# Epoch 188/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 7.7731e-04 - mae: 0.0141 - val_loss: 8.1719e-04 - val_mae: 0.0136
# Epoch 189/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 7.6627e-04 - mae: 0.0139 - val_loss: 9.4117e-04 - val_mae: 0.0140
# Epoch 190/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 8.1105e-04 - mae: 0.0143 - val_loss: 8.3044e-04 - val_mae: 0.0133
# Epoch 191/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 9.9049e-04 - mae: 0.0153 - val_loss: 0.0010 - val_mae: 0.0157
# Epoch 192/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 7.9717e-04 - mae: 0.0141 - val_loss: 9.2992e-04 - val_mae: 0.0143
# Epoch 193/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 7.6260e-04 - mae: 0.0139 - val_loss: 0.0010 - val_mae: 0.0158
# Epoch 194/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 7.7773e-04 - mae: 0.0140 - val_loss: 0.0012 - val_mae: 0.0134
# Epoch 195/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 7.6833e-04 - mae: 0.0139 - val_loss: 9.6081e-04 - val_mae: 0.0144
# Epoch 196/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 7.4345e-04 - mae: 0.0137 - val_loss: 0.0010 - val_mae: 0.0143
# Epoch 197/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 7.8334e-04 - mae: 0.0141 - val_loss: 9.3164e-04 - val_mae: 0.0134
# Epoch 198/1000
# 1120/1120 [==============================] - 10s 9ms/step - loss: 7.4740e-04 - mae: 0.0138 - val_loss: 9.2113e-04 - val_mae: 0.0144
# Epoch 199/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 7.5231e-04 - mae: 0.0138 - val_loss: 9.7073e-04 - val_mae: 0.0151
# Epoch 200/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 7.6051e-04 - mae: 0.0138 - val_loss: 8.7676e-04 - val_mae: 0.0139
# Epoch 201/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 9.3661e-04 - mae: 0.0144 - val_loss: 0.0011 - val_mae: 0.0169
# Epoch 202/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 8.6932e-04 - mae: 0.0146 - val_loss: 0.0010 - val_mae: 0.0152
# Epoch 203/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 7.8951e-04 - mae: 0.0139 - val_loss: 9.3694e-04 - val_mae: 0.0131
# Epoch 204/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 7.4730e-04 - mae: 0.0137 - val_loss: 9.0509e-04 - val_mae: 0.0141
# Epoch 205/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 7.2027e-04 - mae: 0.0135 - val_loss: 7.9070e-04 - val_mae: 0.0125
# Epoch 206/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 7.2770e-04 - mae: 0.0136 - val_loss: 8.2984e-04 - val_mae: 0.0138
# Epoch 207/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 7.1895e-04 - mae: 0.0136 - val_loss: 8.5180e-04 - val_mae: 0.0135
# Epoch 208/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 7.4326e-04 - mae: 0.0137 - val_loss: 7.9178e-04 - val_mae: 0.0123
# Epoch 209/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 7.5224e-04 - mae: 0.0138 - val_loss: 8.3603e-04 - val_mae: 0.0133
# Epoch 210/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 7.1247e-04 - mae: 0.0135 - val_loss: 8.6199e-04 - val_mae: 0.0136
# Epoch 211/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 7.1770e-04 - mae: 0.0135 - val_loss: 7.6205e-04 - val_mae: 0.0121
# Epoch 212/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 7.0015e-04 - mae: 0.0133 - val_loss: 8.0615e-04 - val_mae: 0.0127
# Epoch 213/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 7.1726e-04 - mae: 0.0134 - val_loss: 9.1190e-04 - val_mae: 0.0142
# Epoch 214/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 7.1710e-04 - mae: 0.0135 - val_loss: 8.7771e-04 - val_mae: 0.0147
# Epoch 215/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 7.0844e-04 - mae: 0.0134 - val_loss: 7.9532e-04 - val_mae: 0.0131
# Epoch 216/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.9133e-04 - mae: 0.0133 - val_loss: 8.0645e-04 - val_mae: 0.0124
# Epoch 217/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 7.4676e-04 - mae: 0.0136 - val_loss: 8.5840e-04 - val_mae: 0.0136
# Epoch 218/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.8737e-04 - mae: 0.0131 - val_loss: 8.0121e-04 - val_mae: 0.0133
# Epoch 219/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.7692e-04 - mae: 0.0131 - val_loss: 8.0654e-04 - val_mae: 0.0127
# Epoch 220/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.9428e-04 - mae: 0.0132 - val_loss: 7.8249e-04 - val_mae: 0.0126
# Epoch 221/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 7.0948e-04 - mae: 0.0134 - val_loss: 7.8375e-04 - val_mae: 0.0125
# Epoch 222/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.7781e-04 - mae: 0.0131 - val_loss: 0.0014 - val_mae: 0.0205
# Epoch 223/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 7.2085e-04 - mae: 0.0136 - val_loss: 8.0874e-04 - val_mae: 0.0134
# Epoch 224/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 8.2226e-04 - mae: 0.0139 - val_loss: 7.8734e-04 - val_mae: 0.0125
# Epoch 225/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.8088e-04 - mae: 0.0131 - val_loss: 7.4018e-04 - val_mae: 0.0121
# Epoch 226/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.8985e-04 - mae: 0.0132 - val_loss: 9.0755e-04 - val_mae: 0.0132
# Epoch 227/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 9.2281e-04 - mae: 0.0140 - val_loss: 9.0146e-04 - val_mae: 0.0147
# Epoch 228/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.8982e-04 - mae: 0.0132 - val_loss: 7.8616e-04 - val_mae: 0.0132
# Epoch 229/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.6941e-04 - mae: 0.0129 - val_loss: 7.9710e-04 - val_mae: 0.0130
# Epoch 230/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.5251e-04 - mae: 0.0128 - val_loss: 9.2290e-04 - val_mae: 0.0147
# Epoch 231/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.7255e-04 - mae: 0.0131 - val_loss: 8.0255e-04 - val_mae: 0.0130
# Epoch 232/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.7645e-04 - mae: 0.0130 - val_loss: 8.2003e-04 - val_mae: 0.0132
# Epoch 233/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.6470e-04 - mae: 0.0130 - val_loss: 8.1448e-04 - val_mae: 0.0136
# Epoch 234/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.7703e-04 - mae: 0.0131 - val_loss: 8.4541e-04 - val_mae: 0.0135
# Epoch 235/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.5832e-04 - mae: 0.0129 - val_loss: 7.5606e-04 - val_mae: 0.0124
# Epoch 236/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.5590e-04 - mae: 0.0129 - val_loss: 7.8920e-04 - val_mae: 0.0131
# Epoch 237/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 7.2976e-04 - mae: 0.0133 - val_loss: 0.0016 - val_mae: 0.0130
# Epoch 238/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 7.5345e-04 - mae: 0.0134 - val_loss: 9.1188e-04 - val_mae: 0.0127
# Epoch 239/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 7.0257e-04 - mae: 0.0133 - val_loss: 7.9953e-04 - val_mae: 0.0132
# Epoch 240/1000
# 1120/1120 [==============================] - 10s 8ms/step - loss: 6.5074e-04 - mae: 0.0128 - val_loss: 7.1724e-04 - val_mae: 0.0121
# Epoch 241/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.5387e-04 - mae: 0.0129 - val_loss: 8.2795e-04 - val_mae: 0.0142
# Epoch 242/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.3822e-04 - mae: 0.0127 - val_loss: 7.7460e-04 - val_mae: 0.0127
# Epoch 243/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.4173e-04 - mae: 0.0128 - val_loss: 7.4122e-04 - val_mae: 0.0123
# Epoch 244/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.4886e-04 - mae: 0.0128 - val_loss: 7.9033e-04 - val_mae: 0.0128
# Epoch 245/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.3197e-04 - mae: 0.0127 - val_loss: 7.4465e-04 - val_mae: 0.0129
# Epoch 246/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.3342e-04 - mae: 0.0126 - val_loss: 7.2122e-04 - val_mae: 0.0125
# Epoch 247/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.5820e-04 - mae: 0.0129 - val_loss: 0.0011 - val_mae: 0.0128
# Epoch 248/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.6151e-04 - mae: 0.0130 - val_loss: 8.0218e-04 - val_mae: 0.0120
# Epoch 249/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.2518e-04 - mae: 0.0124 - val_loss: 8.7165e-04 - val_mae: 0.0147
# Epoch 250/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.4896e-04 - mae: 0.0128 - val_loss: 7.7176e-04 - val_mae: 0.0132
# Epoch 251/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.5343e-04 - mae: 0.0130 - val_loss: 7.8568e-04 - val_mae: 0.0136
# Epoch 252/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.3073e-04 - mae: 0.0126 - val_loss: 8.4558e-04 - val_mae: 0.0130
# Epoch 253/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.1670e-04 - mae: 0.0125 - val_loss: 7.6597e-04 - val_mae: 0.0127
# Epoch 254/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.3675e-04 - mae: 0.0127 - val_loss: 7.4260e-04 - val_mae: 0.0123
# Epoch 255/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.2173e-04 - mae: 0.0125 - val_loss: 8.8406e-04 - val_mae: 0.0124
# Epoch 256/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.2534e-04 - mae: 0.0126 - val_loss: 7.5887e-04 - val_mae: 0.0123
# Epoch 257/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.7663e-04 - mae: 0.0130 - val_loss: 7.0340e-04 - val_mae: 0.0118
# Epoch 258/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.1423e-04 - mae: 0.0124 - val_loss: 7.3908e-04 - val_mae: 0.0124
# Epoch 259/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.0873e-04 - mae: 0.0125 - val_loss: 7.7848e-04 - val_mae: 0.0134
# Epoch 260/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.1940e-04 - mae: 0.0126 - val_loss: 7.7287e-04 - val_mae: 0.0124
# Epoch 261/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.2618e-04 - mae: 0.0126 - val_loss: 7.8158e-04 - val_mae: 0.0136
# Epoch 262/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.2144e-04 - mae: 0.0125 - val_loss: 7.7146e-04 - val_mae: 0.0135
# Epoch 263/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.0807e-04 - mae: 0.0125 - val_loss: 7.6985e-04 - val_mae: 0.0140
# Epoch 264/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.0917e-04 - mae: 0.0124 - val_loss: 7.4697e-04 - val_mae: 0.0124
# Epoch 265/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.2109e-04 - mae: 0.0127 - val_loss: 8.5435e-04 - val_mae: 0.0149
# Epoch 266/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.0260e-04 - mae: 0.0123 - val_loss: 7.1296e-04 - val_mae: 0.0122
# Epoch 267/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.0720e-04 - mae: 0.0124 - val_loss: 8.1025e-04 - val_mae: 0.0127
# Epoch 268/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.1303e-04 - mae: 0.0124 - val_loss: 7.4333e-04 - val_mae: 0.0123
# Epoch 269/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.0397e-04 - mae: 0.0124 - val_loss: 7.3275e-04 - val_mae: 0.0124
# Epoch 270/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.9287e-04 - mae: 0.0123 - val_loss: 7.2211e-04 - val_mae: 0.0123
# Epoch 271/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.0261e-04 - mae: 0.0124 - val_loss: 7.3257e-04 - val_mae: 0.0128
# Epoch 272/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.0416e-04 - mae: 0.0123 - val_loss: 7.6934e-04 - val_mae: 0.0132
# Epoch 273/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.0813e-04 - mae: 0.0125 - val_loss: 7.2341e-04 - val_mae: 0.0120
# Epoch 274/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.0636e-04 - mae: 0.0124 - val_loss: 7.1053e-04 - val_mae: 0.0118
# Epoch 275/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.8506e-04 - mae: 0.0122 - val_loss: 8.2122e-04 - val_mae: 0.0130
# Epoch 276/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.0202e-04 - mae: 0.0124 - val_loss: 7.9301e-04 - val_mae: 0.0135
# Epoch 277/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.8961e-04 - mae: 0.0123 - val_loss: 7.0617e-04 - val_mae: 0.0114
# Epoch 278/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.0963e-04 - mae: 0.0124 - val_loss: 7.9094e-04 - val_mae: 0.0143
# Epoch 279/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.8665e-04 - mae: 0.0123 - val_loss: 7.1545e-04 - val_mae: 0.0119
# Epoch 280/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.9065e-04 - mae: 0.0123 - val_loss: 7.1238e-04 - val_mae: 0.0116
# Epoch 281/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.8548e-04 - mae: 0.0123 - val_loss: 6.9997e-04 - val_mae: 0.0125
# Epoch 282/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.4180e-04 - mae: 0.0127 - val_loss: 8.0573e-04 - val_mae: 0.0133
# Epoch 283/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.1779e-04 - mae: 0.0125 - val_loss: 7.4357e-04 - val_mae: 0.0111
# Epoch 284/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.8570e-04 - mae: 0.0122 - val_loss: 8.0502e-04 - val_mae: 0.0126
# Epoch 285/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.7108e-04 - mae: 0.0120 - val_loss: 6.9419e-04 - val_mae: 0.0120
# Epoch 286/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.7560e-04 - mae: 0.0122 - val_loss: 6.9434e-04 - val_mae: 0.0123
# Epoch 287/1000
# 1120/1120 [==============================] - 10s 8ms/step - loss: 5.7745e-04 - mae: 0.0121 - val_loss: 6.7834e-04 - val_mae: 0.0117
# Epoch 288/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.9035e-04 - mae: 0.0122 - val_loss: 7.6488e-04 - val_mae: 0.0133
# Epoch 289/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.9600e-04 - mae: 0.0123 - val_loss: 7.2174e-04 - val_mae: 0.0126
# Epoch 290/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.9688e-04 - mae: 0.0123 - val_loss: 8.0327e-04 - val_mae: 0.0127
# Epoch 291/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.8589e-04 - mae: 0.0121 - val_loss: 7.9266e-04 - val_mae: 0.0122
# Epoch 292/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.7756e-04 - mae: 0.0121 - val_loss: 7.7403e-04 - val_mae: 0.0138
# Epoch 293/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.7181e-04 - mae: 0.0121 - val_loss: 6.8022e-04 - val_mae: 0.0121
# Epoch 294/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.8605e-04 - mae: 0.0123 - val_loss: 8.5127e-04 - val_mae: 0.0136
# Epoch 295/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.8817e-04 - mae: 0.0122 - val_loss: 6.7393e-04 - val_mae: 0.0116
# Epoch 296/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.6566e-04 - mae: 0.0120 - val_loss: 7.7857e-04 - val_mae: 0.0132
# Epoch 297/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.6942e-04 - mae: 0.0121 - val_loss: 6.9396e-04 - val_mae: 0.0123
# Epoch 298/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.6536e-04 - mae: 0.0120 - val_loss: 7.5615e-04 - val_mae: 0.0127
# Epoch 299/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.7532e-04 - mae: 0.0122 - val_loss: 7.1317e-04 - val_mae: 0.0119
# Epoch 300/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.9405e-04 - mae: 0.0124 - val_loss: 7.5395e-04 - val_mae: 0.0123
# Epoch 301/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.7009e-04 - mae: 0.0120 - val_loss: 7.1307e-04 - val_mae: 0.0124
# Epoch 302/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.5683e-04 - mae: 0.0119 - val_loss: 7.3269e-04 - val_mae: 0.0123
# Epoch 303/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.8468e-04 - mae: 0.0122 - val_loss: 8.0016e-04 - val_mae: 0.0138
# Epoch 304/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.7580e-04 - mae: 0.0121 - val_loss: 8.0170e-04 - val_mae: 0.0125
# Epoch 305/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.7144e-04 - mae: 0.0119 - val_loss: 7.2307e-04 - val_mae: 0.0119
# Epoch 306/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.7544e-04 - mae: 0.0121 - val_loss: 7.9598e-04 - val_mae: 0.0114
# Epoch 307/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.6872e-04 - mae: 0.0119 - val_loss: 6.6308e-04 - val_mae: 0.0119
# Epoch 308/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.6218e-04 - mae: 0.0121 - val_loss: 7.6155e-04 - val_mae: 0.0123
# Epoch 309/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.5014e-04 - mae: 0.0118 - val_loss: 6.8985e-04 - val_mae: 0.0124
# Epoch 310/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.6641e-04 - mae: 0.0120 - val_loss: 6.6990e-04 - val_mae: 0.0112
# Epoch 311/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.5877e-04 - mae: 0.0120 - val_loss: 6.9171e-04 - val_mae: 0.0118
# Epoch 312/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.4902e-04 - mae: 0.0118 - val_loss: 7.0114e-04 - val_mae: 0.0116
# Epoch 313/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.8805e-04 - mae: 0.0122 - val_loss: 8.4980e-04 - val_mae: 0.0145
# Epoch 314/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.5069e-04 - mae: 0.0119 - val_loss: 6.7865e-04 - val_mae: 0.0118
# Epoch 315/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.2491e-04 - mae: 0.0123 - val_loss: 9.2903e-04 - val_mae: 0.0140
# Epoch 316/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 6.1416e-04 - mae: 0.0124 - val_loss: 6.9026e-04 - val_mae: 0.0115
# Epoch 317/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.6604e-04 - mae: 0.0120 - val_loss: 7.1474e-04 - val_mae: 0.0122
# Epoch 318/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.3944e-04 - mae: 0.0117 - val_loss: 6.9767e-04 - val_mae: 0.0118
# Epoch 319/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.2797e-04 - mae: 0.0116 - val_loss: 6.8375e-04 - val_mae: 0.0119
# Epoch 320/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.3496e-04 - mae: 0.0118 - val_loss: 7.0942e-04 - val_mae: 0.0124
# Epoch 321/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.4649e-04 - mae: 0.0118 - val_loss: 6.7768e-04 - val_mae: 0.0114
# Epoch 322/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.4237e-04 - mae: 0.0118 - val_loss: 6.6191e-04 - val_mae: 0.0111
# Epoch 323/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.6334e-04 - mae: 0.0121 - val_loss: 6.7259e-04 - val_mae: 0.0119
# Epoch 324/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.5490e-04 - mae: 0.0119 - val_loss: 7.0347e-04 - val_mae: 0.0128
# Epoch 325/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.4477e-04 - mae: 0.0119 - val_loss: 6.8279e-04 - val_mae: 0.0121
# Epoch 326/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.3092e-04 - mae: 0.0117 - val_loss: 7.2030e-04 - val_mae: 0.0126
# Epoch 327/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.8641e-04 - mae: 0.0121 - val_loss: 7.1399e-04 - val_mae: 0.0123
# Epoch 328/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.3850e-04 - mae: 0.0117 - val_loss: 6.7372e-04 - val_mae: 0.0120
# Epoch 329/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.3850e-04 - mae: 0.0117 - val_loss: 6.8807e-04 - val_mae: 0.0127
# Epoch 330/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.2834e-04 - mae: 0.0116 - val_loss: 8.0301e-04 - val_mae: 0.0142
# Epoch 331/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.3686e-04 - mae: 0.0118 - val_loss: 6.9014e-04 - val_mae: 0.0115
# Epoch 332/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.1903e-04 - mae: 0.0116 - val_loss: 7.9310e-04 - val_mae: 0.0141
# Epoch 333/1000
# ...
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.8062e-04 - mae: 0.0098 - val_loss: 7.9223e-04 - val_mae: 0.0114
# Epoch 880/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.7760e-04 - mae: 0.0099 - val_loss: 5.5503e-04 - val_mae: 0.0105
# Epoch 881/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.7895e-04 - mae: 0.0099 - val_loss: 5.3331e-04 - val_mae: 0.0098
# Epoch 882/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.5814e-04 - mae: 0.0096 - val_loss: 5.1502e-04 - val_mae: 0.0100
# Epoch 883/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.7126e-04 - mae: 0.0098 - val_loss: 5.2182e-04 - val_mae: 0.0100
# Epoch 884/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.6166e-04 - mae: 0.0098 - val_loss: 5.8033e-04 - val_mae: 0.0106
# Epoch 885/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.7051e-04 - mae: 0.0098 - val_loss: 5.3493e-04 - val_mae: 0.0099
# Epoch 886/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.6605e-04 - mae: 0.0097 - val_loss: 5.4065e-04 - val_mae: 0.0097
# Epoch 887/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.7399e-04 - mae: 0.0098 - val_loss: 5.4407e-04 - val_mae: 0.0095
# Epoch 888/1000
# 1120/1120 [==============================] - 10s 9ms/step - loss: 3.6855e-04 - mae: 0.0097 - val_loss: 0.0014 - val_mae: 0.0110
# Epoch 889/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.7751e-04 - mae: 0.0099 - val_loss: 5.5098e-04 - val_mae: 0.0100
# Epoch 890/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.6733e-04 - mae: 0.0097 - val_loss: 5.4791e-04 - val_mae: 0.0098
# Epoch 891/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.8054e-04 - mae: 0.0100 - val_loss: 5.5228e-04 - val_mae: 0.0095
# Epoch 892/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.6138e-04 - mae: 0.0097 - val_loss: 5.9384e-04 - val_mae: 0.0110
# Epoch 893/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.7353e-04 - mae: 0.0099 - val_loss: 5.8687e-04 - val_mae: 0.0108
# Epoch 894/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.7797e-04 - mae: 0.0099 - val_loss: 5.9163e-04 - val_mae: 0.0095
# Epoch 895/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.6776e-04 - mae: 0.0098 - val_loss: 9.5388e-04 - val_mae: 0.0117
# Epoch 896/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.6801e-04 - mae: 0.0097 - val_loss: 5.7449e-04 - val_mae: 0.0100
# Epoch 897/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.6691e-04 - mae: 0.0097 - val_loss: 7.3526e-04 - val_mae: 0.0097
# Epoch 898/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.9303e-04 - mae: 0.0100 - val_loss: 6.0342e-04 - val_mae: 0.0107
# Epoch 899/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 4.1162e-04 - mae: 0.0101 - val_loss: 5.5143e-04 - val_mae: 0.0105
# Epoch 900/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.6688e-04 - mae: 0.0097 - val_loss: 5.6888e-04 - val_mae: 0.0108
# Epoch 901/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.5498e-04 - mae: 0.0096 - val_loss: 5.2257e-04 - val_mae: 0.0094
# Epoch 902/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.6161e-04 - mae: 0.0097 - val_loss: 5.1389e-04 - val_mae: 0.0100
# Epoch 903/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.7153e-04 - mae: 0.0099 - val_loss: 5.4601e-04 - val_mae: 0.0099
# Epoch 904/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.5554e-04 - mae: 0.0096 - val_loss: 5.2411e-04 - val_mae: 0.0092
# Epoch 905/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.9196e-04 - mae: 0.0101 - val_loss: 5.2944e-04 - val_mae: 0.0092
# Epoch 906/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.7676e-04 - mae: 0.0099 - val_loss: 5.9345e-04 - val_mae: 0.0113
# Epoch 907/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.5422e-04 - mae: 0.0096 - val_loss: 5.6135e-04 - val_mae: 0.0106
# Epoch 908/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.6561e-04 - mae: 0.0097 - val_loss: 5.5494e-04 - val_mae: 0.0100
# Epoch 909/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.6395e-04 - mae: 0.0097 - val_loss: 5.4245e-04 - val_mae: 0.0096
# Epoch 910/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.6810e-04 - mae: 0.0097 - val_loss: 4.9272e-04 - val_mae: 0.0090
# Epoch 911/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.6394e-04 - mae: 0.0097 - val_loss: 6.1063e-04 - val_mae: 0.0090
# Epoch 912/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.6694e-04 - mae: 0.0097 - val_loss: 5.3446e-04 - val_mae: 0.0094
# Epoch 913/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.7680e-04 - mae: 0.0099 - val_loss: 5.4179e-04 - val_mae: 0.0098
# Epoch 914/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.5834e-04 - mae: 0.0096 - val_loss: 5.4377e-04 - val_mae: 0.0096
# Epoch 915/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.6395e-04 - mae: 0.0097 - val_loss: 5.3561e-04 - val_mae: 0.0104
# Epoch 916/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.5880e-04 - mae: 0.0097 - val_loss: 6.6413e-04 - val_mae: 0.0117
# Epoch 917/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.7384e-04 - mae: 0.0099 - val_loss: 6.7409e-04 - val_mae: 0.0125
# Epoch 918/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.6966e-04 - mae: 0.0097 - val_loss: 5.7160e-04 - val_mae: 0.0101
# Epoch 919/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.6947e-04 - mae: 0.0097 - val_loss: 5.6277e-04 - val_mae: 0.0104
# Epoch 920/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.6263e-04 - mae: 0.0097 - val_loss: 6.1821e-04 - val_mae: 0.0100
# Epoch 921/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.8512e-04 - mae: 0.0100 - val_loss: 6.0585e-04 - val_mae: 0.0102
# Epoch 922/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 4.2187e-04 - mae: 0.0099 - val_loss: 6.3630e-04 - val_mae: 0.0111
# Epoch 923/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.8611e-04 - mae: 0.0099 - val_loss: 6.3245e-04 - val_mae: 0.0124
# Epoch 924/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.5633e-04 - mae: 0.0096 - val_loss: 5.7380e-04 - val_mae: 0.0097
# Epoch 925/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.5843e-04 - mae: 0.0097 - val_loss: 5.3807e-04 - val_mae: 0.0092
# Epoch 926/1000
# 1120/1120 [==============================] - 10s 9ms/step - loss: 3.5951e-04 - mae: 0.0097 - val_loss: 5.0073e-04 - val_mae: 0.0093
# Epoch 927/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.7385e-04 - mae: 0.0098 - val_loss: 5.0115e-04 - val_mae: 0.0093
# Epoch 928/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.6480e-04 - mae: 0.0097 - val_loss: 5.6440e-04 - val_mae: 0.0110
# Epoch 929/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.5525e-04 - mae: 0.0096 - val_loss: 5.4298e-04 - val_mae: 0.0098
# Epoch 930/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.6971e-04 - mae: 0.0098 - val_loss: 5.1610e-04 - val_mae: 0.0091
# Epoch 931/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 4.3013e-04 - mae: 0.0103 - val_loss: 5.7094e-04 - val_mae: 0.0099
# Epoch 932/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.6068e-04 - mae: 0.0096 - val_loss: 5.1522e-04 - val_mae: 0.0098
# Epoch 933/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.4760e-04 - mae: 0.0094 - val_loss: 5.6600e-04 - val_mae: 0.0113
# Epoch 934/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.5118e-04 - mae: 0.0096 - val_loss: 5.7688e-04 - val_mae: 0.0099
# Epoch 935/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.8142e-04 - mae: 0.0099 - val_loss: 6.0320e-04 - val_mae: 0.0102
# Epoch 936/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.4563e-04 - mae: 0.0094 - val_loss: 5.0957e-04 - val_mae: 0.0096
# Epoch 937/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.5758e-04 - mae: 0.0097 - val_loss: 5.4850e-04 - val_mae: 0.0087
# Epoch 938/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.5488e-04 - mae: 0.0096 - val_loss: 6.0341e-04 - val_mae: 0.0094
# Epoch 939/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.6727e-04 - mae: 0.0098 - val_loss: 5.9241e-04 - val_mae: 0.0109
# Epoch 940/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.6860e-04 - mae: 0.0098 - val_loss: 5.5913e-04 - val_mae: 0.0099
# Epoch 941/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.6306e-04 - mae: 0.0097 - val_loss: 6.4835e-04 - val_mae: 0.0104
# Epoch 942/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.6658e-04 - mae: 0.0097 - val_loss: 5.2203e-04 - val_mae: 0.0093
# Epoch 943/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.7241e-04 - mae: 0.0097 - val_loss: 5.0253e-04 - val_mae: 0.0095
# Epoch 944/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.4651e-04 - mae: 0.0095 - val_loss: 5.9535e-04 - val_mae: 0.0103
# Epoch 945/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 4.3846e-04 - mae: 0.0104 - val_loss: 5.5175e-04 - val_mae: 0.0102
# Epoch 946/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.5604e-04 - mae: 0.0095 - val_loss: 5.4963e-04 - val_mae: 0.0088
# Epoch 947/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 5.8567e-04 - mae: 0.0109 - val_loss: 5.9530e-04 - val_mae: 0.0100
# Epoch 948/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.7749e-04 - mae: 0.0097 - val_loss: 5.1612e-04 - val_mae: 0.0093
# Epoch 949/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.5950e-04 - mae: 0.0097 - val_loss: 5.5849e-04 - val_mae: 0.0096
# Epoch 950/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.4869e-04 - mae: 0.0096 - val_loss: 5.5050e-04 - val_mae: 0.0105
# Epoch 951/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.5346e-04 - mae: 0.0096 - val_loss: 5.2851e-04 - val_mae: 0.0092
# Epoch 952/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.5452e-04 - mae: 0.0097 - val_loss: 5.9831e-04 - val_mae: 0.0113
# Epoch 953/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.4744e-04 - mae: 0.0095 - val_loss: 5.6256e-04 - val_mae: 0.0109
# Epoch 954/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.4555e-04 - mae: 0.0095 - val_loss: 5.9427e-04 - val_mae: 0.0100
# Epoch 955/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.9132e-04 - mae: 0.0100 - val_loss: 4.9812e-04 - val_mae: 0.0088
# Epoch 956/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.6205e-04 - mae: 0.0098 - val_loss: 5.7237e-04 - val_mae: 0.0103
# Epoch 957/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.6176e-04 - mae: 0.0097 - val_loss: 5.3749e-04 - val_mae: 0.0090
# Epoch 958/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.6207e-04 - mae: 0.0098 - val_loss: 5.9365e-04 - val_mae: 0.0118
# Epoch 959/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.5829e-04 - mae: 0.0097 - val_loss: 7.0264e-04 - val_mae: 0.0087
# Epoch 960/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.9949e-04 - mae: 0.0099 - val_loss: 0.0011 - val_mae: 0.0152
# Epoch 961/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 4.3883e-04 - mae: 0.0103 - val_loss: 5.6788e-04 - val_mae: 0.0103
# Epoch 962/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.4730e-04 - mae: 0.0095 - val_loss: 5.5398e-04 - val_mae: 0.0109
# Epoch 963/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.4951e-04 - mae: 0.0096 - val_loss: 5.2020e-04 - val_mae: 0.0090
# Epoch 964/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.5675e-04 - mae: 0.0096 - val_loss: 6.3616e-04 - val_mae: 0.0096
# Epoch 965/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 7.2697e-04 - mae: 0.0104 - val_loss: 0.0011 - val_mae: 0.0148
# Epoch 966/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 4.8168e-04 - mae: 0.0108 - val_loss: 5.8804e-04 - val_mae: 0.0109
# Epoch 967/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.7400e-04 - mae: 0.0097 - val_loss: 5.5980e-04 - val_mae: 0.0104
# Epoch 968/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.7314e-04 - mae: 0.0099 - val_loss: 6.3670e-04 - val_mae: 0.0101
# Epoch 969/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.6981e-04 - mae: 0.0098 - val_loss: 5.3869e-04 - val_mae: 0.0103
# Epoch 970/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.5522e-04 - mae: 0.0097 - val_loss: 6.5956e-04 - val_mae: 0.0103
# Epoch 971/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.8164e-04 - mae: 0.0099 - val_loss: 5.0997e-04 - val_mae: 0.0086
# Epoch 972/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.5141e-04 - mae: 0.0095 - val_loss: 5.0518e-04 - val_mae: 0.0085
# Epoch 973/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.7020e-04 - mae: 0.0099 - val_loss: 6.9902e-04 - val_mae: 0.0091
# Epoch 974/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.4775e-04 - mae: 0.0095 - val_loss: 5.3184e-04 - val_mae: 0.0099
# Epoch 975/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 4.4961e-04 - mae: 0.0105 - val_loss: 5.6041e-04 - val_mae: 0.0099
# Epoch 976/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.5657e-04 - mae: 0.0096 - val_loss: 5.2073e-04 - val_mae: 0.0097
# Epoch 977/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.3764e-04 - mae: 0.0094 - val_loss: 5.7678e-04 - val_mae: 0.0103
# Epoch 978/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.6613e-04 - mae: 0.0098 - val_loss: 5.5496e-04 - val_mae: 0.0101
# Epoch 979/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.4409e-04 - mae: 0.0095 - val_loss: 5.2861e-04 - val_mae: 0.0101
# Epoch 980/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.6277e-04 - mae: 0.0096 - val_loss: 7.3312e-04 - val_mae: 0.0103
# Epoch 981/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.6598e-04 - mae: 0.0097 - val_loss: 5.3583e-04 - val_mae: 0.0093
# Epoch 982/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 4.1602e-04 - mae: 0.0100 - val_loss: 5.5783e-04 - val_mae: 0.0105
# Epoch 983/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.7468e-04 - mae: 0.0098 - val_loss: 4.8902e-04 - val_mae: 0.0089
# Epoch 984/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.6417e-04 - mae: 0.0097 - val_loss: 5.3610e-04 - val_mae: 0.0097
# Epoch 985/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.5943e-04 - mae: 0.0097 - val_loss: 5.5844e-04 - val_mae: 0.0105
# Epoch 986/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.5407e-04 - mae: 0.0095 - val_loss: 5.4570e-04 - val_mae: 0.0101
# Epoch 987/1000
# 1120/1120 [==============================] - 9s 8ms/step - loss: 3.5235e-04 - mae: 0.0095 - val_loss: 5.5811e-04 - val_mae: 0.0105
# Epoch 988/1000
#  621/1120 [===============>..............] - ETA: 3s - loss: 3.4404e-04 - mae: 0.0095

# %%
# !ls -lh ff_nn_Best_Model.h5 ff_nn_best_history.json

# %%
from IPython.display import FileLink

# Crear enlaces para descarga
FileLink('ff_nn_Best_Model.h5')

# %%
FileLink('ff_nn_best_history.json')

# %%
#import os
#os.remove("ff_nn_Best_Model.h5")
#os.remove("ff_nn_best_history.json")

# %%
accuracy_test_NN = FF_NN_network.evaluate(X_test_FF, y_test_FF)

# %%
predictions_NN = FF_NN_network.predict(X_test_FF)

# %%
y_test_FF[0]

# %% [markdown]
# # Verificación de métricas y validación con nuevo dataset

# %% [markdown]
# # Verificación con Dataset Lineal
