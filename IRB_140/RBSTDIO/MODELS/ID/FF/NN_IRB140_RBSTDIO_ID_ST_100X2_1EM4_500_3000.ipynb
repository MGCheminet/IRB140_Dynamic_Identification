# %%
import numpy as np
import scipy as sp
import sympy as smp
import matplotlib.pyplot as plt
import pandas as pd #Lo necesito para cargar y leer el csv
import tensorflow as tf
import os
import random
import time
import math
import keras 
import json
from datetime import datetime

#import tensorflow
from tensorflow import keras
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from tensorflow.keras.layers import Dense, LSTM, BatchNormalization, Dropout, InputLayer
from tensorflow.keras.models import Sequential #
from sklearn.model_selection import train_test_split
from keras.regularizers import l2, l1, l1_l2
from sklearn.utils import shuffle
import pandas as pd
from scipy.signal import savgol_filter
from scipy.interpolate import CubicSpline
from scipy.ndimage import gaussian_filter1d
#from keras_tuner import RandomSearch
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
# Out:
# 2025-07-21 01:42:02.564693: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-07-21 01:42:02.564716: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-07-21 01:42:02.564722: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
import tensorflow as tf
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available: 2

# %%
tf.keras.backend.set_floatx('float64')

# %% [markdown]
# # **Filtro Discreto para agregar aceleraciones**
# De acuerdo con el paper *Identification of robot forward dynamics via neural network*:
#
# “The corresponding joint accelerations were retrieved through the application of an appropriate discrete filter to the joint velocities just collected.”
#
# Entonces, se tomarán dos datos “de más” (muestra 0 y muestra 101) para permitir aplicar el filtro discreto a las n-2 muestras y tener información de velocidad. Se podrán estudiar otras técnicas para derivar las aceleraciones a partir de las velocidades.

# %%
# Definir una función para calcular las aceleraciones utilizando un filtro de diferencia finita
def calcular_aceleraciones(velocidades, h):
    aceleraciones = []
    for i in range(1, len(velocidades) -1 ):
        # Aplicar el filtro de diferencia finita para calcular la aceleración
        #aceleracion = (velocidades[i + 1] - 2 * velocidades[i] + velocidades[i - 1]) #->Esto no seria la segunda derivada?
        aceleracion = (velocidades[i + 1] -  velocidades[i - 1])/(2*h)
        aceleraciones.append(aceleracion)
    return np.array(aceleraciones)

# Definir una función para calcular las aceleraciones utilizando un filtro de diferencia finita
def calcular_aceleraciones_2(velocidades, h):
    aceleraciones = []
    for i in range(1, len(velocidades) - 4 ):
        # Aplicar el filtro de diferencia finita para calcular la aceleración
        aceleracion = (- velocidades[i + 2] +  8*velocidades[i + 1] - 8*velocidades[i - 2] + velocidades[i - 1]) /(12*h)
        aceleraciones.append(aceleracion)
    return np.array(aceleraciones)



import os, types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.

cos_client = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='1eFnNpgSMiDaf_Yx-ZXteaGaokoLTfIKQXajc1kbdepo',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/identity/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.direct.us-south.cloud-object-storage.appdomain.cloud')

bucket = 'irb140-donotdelete-pr-sdzbp1zcz7qnal'
object_key = 'Output_linear_002_test_NN_NN.csv'

body = cos_client.get_object(Bucket=bucket,Key=object_key)['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_1 = pd.read_csv(body)
df_1.head(10)



def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.

cos_client = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='1eFnNpgSMiDaf_Yx-ZXteaGaokoLTfIKQXajc1kbdepo',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/identity/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.direct.us-south.cloud-object-storage.appdomain.cloud')

bucket = 'irb140-donotdelete-pr-sdzbp1zcz7qnal'
object_key = 'Output_NN_NN_merged_2.csv'

body = cos_client.get_object(Bucket=bucket,Key=object_key)['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_2 = pd.read_csv(body)
df_2.head(10)





def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.

cos_client = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='1eFnNpgSMiDaf_Yx-ZXteaGaokoLTfIKQXajc1kbdepo',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/identity/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.direct.us-south.cloud-object-storage.appdomain.cloud')

bucket = 'irb140-donotdelete-pr-sdzbp1zcz7qnal'
object_key = 'Output_NN_NN_merged.csv'

body = cos_client.get_object(Bucket=bucket,Key=object_key)['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_3 = pd.read_csv(body)
df_3.head(10)



def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.

cos_client = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='1eFnNpgSMiDaf_Yx-ZXteaGaokoLTfIKQXajc1kbdepo',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/identity/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.direct.us-south.cloud-object-storage.appdomain.cloud')

bucket = 'irb140-donotdelete-pr-sdzbp1zcz7qnal'
object_key = 'Output_NN_NN_4e6_fixed.csv'

body = cos_client.get_object(Bucket=bucket,Key=object_key)['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_4 = pd.read_csv(body)
df_4.head(10)



def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.

cos_client = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='1eFnNpgSMiDaf_Yx-ZXteaGaokoLTfIKQXajc1kbdepo',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/identity/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.direct.us-south.cloud-object-storage.appdomain.cloud')

bucket = 'irb140-donotdelete-pr-sdzbp1zcz7qnal'
object_key = 'Output_NN_NN_1.csv'

body = cos_client.get_object(Bucket=bucket,Key=object_key)['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_5 = pd.read_csv(body)
df_5.head(10)



def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.

cos_client = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='1eFnNpgSMiDaf_Yx-ZXteaGaokoLTfIKQXajc1kbdepo',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/identity/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.direct.us-south.cloud-object-storage.appdomain.cloud')

bucket = 'irb140-donotdelete-pr-sdzbp1zcz7qnal'
object_key = 'Output_NN_NN_CUT_MERGED.csv'

body = cos_client.get_object(Bucket=bucket,Key=object_key)['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_6 = pd.read_csv(body)
df_6.head(10)




def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.

cos_client = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='1eFnNpgSMiDaf_Yx-ZXteaGaokoLTfIKQXajc1kbdepo',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/identity/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.direct.us-south.cloud-object-storage.appdomain.cloud')

bucket = 'irb140-donotdelete-pr-sdzbp1zcz7qnal'
object_key = 'Output_linear_NN_NN.csv'

body = cos_client.get_object(Bucket=bucket,Key=object_key)['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_7 = pd.read_csv(body)
df_7.head(10)
# Out:
#    start_time   random_ID   end_time   random_V   random_Z   pos_j1   pos_j2  \
# 0        0.01           1       0.01    44.3387    13.3286  38.8691  56.8166
# 1        0.02           1       0.02    44.3387    13.3286  38.8691  56.8166
# 2        0.03           1       0.03    44.3387    13.3286  38.8692  56.8166
# 3        0.04           1       0.04    44.3387    13.3286  38.8699  56.8153
# 4        0.05           1       0.05    44.3387    13.3286  38.8714  56.8120
# 5        0.06           1       0.06    44.3387    13.3286  38.8763  56.7989
# 6        0.07           1       0.07    44.3387    13.3286  38.8817  56.7832
# 7        0.08           1       0.08    44.3387    13.3286  38.8929  56.7504
# 8        0.09           1       0.09    44.3387    13.3286  38.9018  56.7246
# 9        0.10           1       0.10    44.3387    13.3286  38.9163  56.6832
#
#     pos_j3   pos_j4   pos_j5  ...        vel_j3        vel_j4        vel_j5  \
# 0 -44.4538  27.1509  77.9901  ... -7.966630e-07  6.367170e-07  1.104570e-06
# 1 -44.4538  27.1509  77.9901  ... -2.476310e-07  1.979140e-07  3.433390e-07
# 2 -44.4537  27.1509  77.9901  ...  3.026870e-02  4.242320e-03  2.885760e-03
# 3 -44.4507  27.1520  77.9909  ...  5.273590e-01  2.336480e-01  1.593350e-01
# 4 -44.4418  27.1564  77.9938  ...  1.585330e+00  7.950580e-01  5.422220e-01
# 5 -44.4053  27.1760  78.0072  ...  4.291600e+00  2.351820e+00  1.603630e+00
# 6 -44.3611  27.2004  78.0239  ...  6.281490e+00  3.492510e+00  2.380870e+00
# 7 -44.2693  27.2516  78.0587  ...  8.464700e+00  4.705810e+00  3.206830e+00
# 8 -44.1971  27.2916  78.0860  ...  9.247770e+00  5.125500e+00  3.492240e+00
# 9 -44.0811  27.3558  78.1297  ...  9.772430e+00  5.406370e+00  3.683100e+00
#
#          vel_j6    torq_j1   torq_j2    torq_j3   torq_j4   torq_j5   torq_j6
# 0  1.654760e-06   0.000081  -102.576 -20.845600  0.074018  0.003685  0.000014
# 1  5.143560e-07   0.000025  -102.576 -20.845500  0.074011  0.003668  0.000000
# 2 -3.938810e-03   2.260020  -103.952 -19.350800  0.492498  0.581197 -0.202456
# 3 -2.190560e-01  11.834500  -111.350 -11.681700  2.834510  4.505330 -1.883060
# 4 -7.461850e-01  16.103400  -116.560  -6.329820  3.748950  6.033220 -2.586040
# 5 -2.208290e+00  18.597000  -122.413  -0.557024  4.770580  7.714690 -3.344290
# 6 -3.278950e+00  18.280300  -124.063  -0.119863  5.282180  8.566820 -3.707570
# 7 -4.416410e+00  17.220700  -124.072  -1.504390  5.758580  9.368880 -4.036480
# 8 -4.809320e+00  16.861400  -123.960  -2.147740  5.917320  9.636010 -4.145240
# 9 -5.072010e+00  16.645000  -123.820  -2.589730  6.023040  9.813340 -4.217430
#
# [10 rows x 23 columns]

# %%
import numpy as np

# Variables y configuraciones
num_variables = 6
time_interval = 0.05

datos_IRB_140 = {
    'datos_IRB_140_Output_linear_NN_NN': df_7,
    'datos_IRB_140_Output_NN_NN_merged': df_5,
    'datos_IRB_140_Output_NN_NN_New_2': df_3
}

tcps_vels = {}
tcps_accus = {}

j_poses = {}
j_vels = {}
j_accels = {}
j_torqs = {}
times = {}

# Nombres de los archivos base usados como etiquetas
files = ['Output_linear_NN_NN', 'Output_NN_NN_merged', 'Output_NN_NN_New_2']
datos_IRB_140_st = 'datos_IRB_140_'

tcp_vel = 'rand_v'
tcp_accu = 'rand_z'

j_pos = 'pos_j'
j_vel = 'vel_j'
j_accel = 'acc_j'
j_torq = 'torq_j'

def calcular_aceleraciones(vels, dt):
    """Calcula aceleración usando esquema de diferencias finitas centradas de 5 puntos."""
    acc = np.zeros_like(vels)
    n = len(vels)
    for i in range(2, n - 2):
        acc[i] = (-vels[i + 2] + 8 * vels[i + 1] - 8 * vels[i - 1] + vels[i - 2]) / (12 * dt)
    return acc

# Procesamiento de los dataframes
for file in files:
    print(file)
    variable_name = datos_IRB_140_st + file
    df = datos_IRB_140[variable_name]

    # Tiempo
    time_var = f"{file}_time"
    times[time_var] = df.iloc[:, 0].values

    # Velocidades y aceleraciones TCP
    tcps_vels_name = f"{file}_{tcp_vel}"
    tcps_vels[tcps_vels_name] = df.iloc[1:-1, 3].values

    tcps_accus_name = f"{file}_{tcp_accu}"
    tcps_accus[tcps_accus_name] = df.iloc[1:-1, 4].values

    # Articulaciones
    for i in range(1, num_variables + 1):
        # Posición articular (en radianes)
        pos_j_name = f"{file}_{j_pos}{i}"
        j_poses[pos_j_name] = df.iloc[:, 4 + i].values *(np.pi/180.0)

        # Velocidad articular (en radianes/s)
        vel_j_name = f"{file}_{j_vel}{i}"
        j_vels[vel_j_name] = df.iloc[:, 10 + i].values *(np.pi/180.0)

        # Torque articular
        torq_j_name = f"{file}_{j_torq}{i}"
        j_torqs[torq_j_name] = df.iloc[:, 16 + i].values

        # Torque articular: calcular max y normalizar inmediatamente
        #torq_j_name = f"{file}_{j_torq}{i}"
        #raw_torque = df.iloc[:, 16 + i].values

        #max_torque = np.max(np.abs(raw_torque))
        #if max_torque == 0:
        #    print(f"⚠️ Torque máximo en {file} eje {i} es 0. Se dejará sin normalizar.")
        #    normalized_torque = raw_torque
        #else:
        #    normalized_torque = raw_torque / max_torque

        #j_torqs[torq_j_name] = normalized_torque

        # Aceleración articular (calculada numéricamente)
        acc_j_name = f"{file}_{j_accel}{i}"
        j_accels[acc_j_name] = calcular_aceleraciones(j_vels[vel_j_name], time_interval) *(np.pi/180.0)
# Out:
# Output_linear_NN_NN
# Output_NN_NN_merged
# Output_NN_NN_New_2

# %%
tcps_vels['Output_NN_NN_merged_rand_v']#[2:-2]
tcps_accus['Output_NN_NN_merged_rand_z']#[2:-2]

j_poses['Output_NN_NN_merged_pos_j1']#[2:-2]
j_poses['Output_NN_NN_merged_pos_j2']#[2:-2]
j_poses['Output_NN_NN_merged_pos_j3']#[2:-2]
j_poses['Output_NN_NN_merged_pos_j4']#[2:-2]
j_poses['Output_NN_NN_merged_pos_j5']#[2:-2]
j_poses['Output_NN_NN_merged_pos_j6']#[2:-2]

j_vels['Output_NN_NN_merged_vel_j1']#[2:-2]
j_vels['Output_NN_NN_merged_vel_j2']#[2:-2]
j_vels['Output_NN_NN_merged_vel_j3']#[2:-2]
j_vels['Output_NN_NN_merged_vel_j4']#[2:-2]
j_vels['Output_NN_NN_merged_vel_j5']#[2:-2]
j_vels['Output_NN_NN_merged_vel_j6']#[2:-2]

j_torqs['Output_NN_NN_merged_torq_j1']#[2:-2]
j_torqs['Output_NN_NN_merged_torq_j2']#[2:-2]
j_torqs['Output_NN_NN_merged_torq_j3']#[2:-2]
j_torqs['Output_NN_NN_merged_torq_j4']#[2:-2]
j_torqs['Output_NN_NN_merged_torq_j5']#[2:-2]
j_torqs['Output_NN_NN_merged_torq_j6']#[2:-2]

j_accels['Output_NN_NN_merged_acc_j1']#[2:-2]
j_accels['Output_NN_NN_merged_acc_j2']#[2:-2]
j_accels['Output_NN_NN_merged_acc_j3']#[2:-2]
j_accels['Output_NN_NN_merged_acc_j4']#[2:-2]
j_accels['Output_NN_NN_merged_acc_j5']#[2:-2]
j_accels['Output_NN_NN_merged_acc_j6']#[2:-2]
# Out:
# array([0.00000000e+00, 0.00000000e+00, 1.46989582e-04, ...,
#        1.00269901e-06, 0.00000000e+00, 0.00000000e+00])

# %%
tcps_vels['Output_linear_NN_NN_rand_v']#[2:-2]
tcps_accus['Output_linear_NN_NN_rand_z']#[2:-2]

j_poses['Output_linear_NN_NN_pos_j1']#[2:-2]
j_poses['Output_linear_NN_NN_pos_j2']#[2:-2]
j_poses['Output_linear_NN_NN_pos_j3']#[2:-2]
j_poses['Output_linear_NN_NN_pos_j4']#[2:-2]
j_poses['Output_linear_NN_NN_pos_j5']#[2:-2]
j_poses['Output_linear_NN_NN_pos_j6']#[2:-2]

j_vels['Output_linear_NN_NN_vel_j1']#[2:-2]
j_vels['Output_linear_NN_NN_vel_j2']#[2:-2]
j_vels['Output_linear_NN_NN_vel_j3']#[2:-2]
j_vels['Output_linear_NN_NN_vel_j4']#[2:-2]
j_vels['Output_linear_NN_NN_vel_j5']#[2:-2]
j_vels['Output_linear_NN_NN_vel_j6']#[2:-2]

j_torqs['Output_linear_NN_NN_torq_j1']#[2:-2]
j_torqs['Output_linear_NN_NN_torq_j2']#[2:-2]
j_torqs['Output_linear_NN_NN_torq_j3']#[2:-2]
j_torqs['Output_linear_NN_NN_torq_j4']#[2:-2]
j_torqs['Output_linear_NN_NN_torq_j5']#[2:-2]
j_torqs['Output_linear_NN_NN_torq_j6']#[2:-2]

j_accels['Output_linear_NN_NN_acc_j1']#[2:-2]
j_accels['Output_linear_NN_NN_acc_j2']#[2:-2]
j_accels['Output_linear_NN_NN_acc_j3']#[2:-2]
j_accels['Output_linear_NN_NN_acc_j4']#[2:-2]
j_accels['Output_linear_NN_NN_acc_j5']#[2:-2]
j_accels['Output_linear_NN_NN_acc_j6']#[2:-2]
# Out:
# array([ 0.00000000e+00,  0.00000000e+00, -5.10876647e-04, ...,
#        -3.22950787e-18,  0.00000000e+00,  0.00000000e+00])

# %%
print(j_poses['Output_NN_NN_merged_pos_j6'].shape)
print(j_accels['Output_NN_NN_merged_acc_j6'].shape)
# Out:
# (299999,)
# (299999,)

# %%
print(j_accels['Output_NN_NN_merged_acc_j6'][2:-2].shape)
# Out:
# (299995,)

# %%
pos_j1 = np.concatenate([j_poses['Output_NN_NN_merged_pos_j1'][2:-2],j_poses['Output_linear_NN_NN_pos_j1'][2:-2]])
pos_j2 = np.concatenate([j_poses['Output_NN_NN_merged_pos_j2'][2:-2],j_poses['Output_linear_NN_NN_pos_j2'][2:-2]])
pos_j3 = np.concatenate([j_poses['Output_NN_NN_merged_pos_j3'][2:-2],j_poses['Output_linear_NN_NN_pos_j3'][2:-2]])
pos_j4 = np.concatenate([j_poses['Output_NN_NN_merged_pos_j4'][2:-2],j_poses['Output_linear_NN_NN_pos_j4'][2:-2]])
pos_j5 = np.concatenate([j_poses['Output_NN_NN_merged_pos_j5'][2:-2],j_poses['Output_linear_NN_NN_pos_j5'][2:-2]])
pos_j6 = np.concatenate([j_poses['Output_NN_NN_merged_pos_j6'][2:-2],j_poses['Output_linear_NN_NN_pos_j6'][2:-2]])

vels_j1 = np.concatenate([j_vels['Output_NN_NN_merged_vel_j1'][2:-2],j_vels['Output_linear_NN_NN_vel_j1'][2:-2]])
vels_j2 = np.concatenate([j_vels['Output_NN_NN_merged_vel_j2'][2:-2],j_vels['Output_linear_NN_NN_vel_j2'][2:-2]])
vels_j3 = np.concatenate([j_vels['Output_NN_NN_merged_vel_j3'][2:-2],j_vels['Output_linear_NN_NN_vel_j3'][2:-2]])
vels_j4 = np.concatenate([j_vels['Output_NN_NN_merged_vel_j4'][2:-2],j_vels['Output_linear_NN_NN_vel_j4'][2:-2]])
vels_j5 = np.concatenate([j_vels['Output_NN_NN_merged_vel_j5'][2:-2],j_vels['Output_linear_NN_NN_vel_j5'][2:-2]])
vels_j6 = np.concatenate([j_vels['Output_NN_NN_merged_vel_j6'][2:-2],j_vels['Output_linear_NN_NN_vel_j6'][2:-2]])

torq_j1 = np.concatenate([j_torqs['Output_NN_NN_merged_torq_j1'][2:-2],j_torqs['Output_linear_NN_NN_torq_j1'][2:-2]])
torq_j2 = np.concatenate([j_torqs['Output_NN_NN_merged_torq_j2'][2:-2],j_torqs['Output_linear_NN_NN_torq_j2'][2:-2]])
torq_j3 = np.concatenate([j_torqs['Output_NN_NN_merged_torq_j3'][2:-2],j_torqs['Output_linear_NN_NN_torq_j3'][2:-2]])
torq_j4 = np.concatenate([j_torqs['Output_NN_NN_merged_torq_j4'][2:-2],j_torqs['Output_linear_NN_NN_torq_j4'][2:-2]])
torq_j5 = np.concatenate([j_torqs['Output_NN_NN_merged_torq_j5'][2:-2],j_torqs['Output_linear_NN_NN_torq_j5'][2:-2]])
torq_j6 = np.concatenate([j_torqs['Output_NN_NN_merged_torq_j6'][2:-2],j_torqs['Output_linear_NN_NN_torq_j6'][2:-2]])

accs_j1 = np.concatenate([j_accels['Output_NN_NN_merged_acc_j1'][2:-2],j_accels['Output_linear_NN_NN_acc_j1'][2:-2]])
accs_j2 = np.concatenate([j_accels['Output_NN_NN_merged_acc_j2'][2:-2],j_accels['Output_linear_NN_NN_acc_j2'][2:-2]])
accs_j3 = np.concatenate([j_accels['Output_NN_NN_merged_acc_j3'][2:-2],j_accels['Output_linear_NN_NN_acc_j3'][2:-2]])
accs_j4 = np.concatenate([j_accels['Output_NN_NN_merged_acc_j4'][2:-2],j_accels['Output_linear_NN_NN_acc_j4'][2:-2]])
accs_j5 = np.concatenate([j_accels['Output_NN_NN_merged_acc_j5'][2:-2],j_accels['Output_linear_NN_NN_acc_j5'][2:-2]])
accs_j6 = np.concatenate([j_accels['Output_NN_NN_merged_acc_j6'][2:-2],j_accels['Output_linear_NN_NN_acc_j6'][2:-2]])

# %%
#Los dos primeros y los dos ultimos puntos no tienen informacion de aceleración, ya que la misma usa cuatro puntos para reconsruirse
#time_joint= times['Output_NN_NN_merged_time'][2:-2]

#pos_j1 = j_poses['Output_NN_NN_merged_pos_j1'][2:-2]  #34440 -> 34438, k
#pos_j2 = j_poses['Output_NN_NN_merged_pos_j2'][2:-2]
#pos_j3 = j_poses['Output_NN_NN_merged_pos_j3'][2:-2]
#pos_j4 = j_poses['Output_NN_NN_merged_pos_j4'][2:-2]
#pos_j5 = j_poses['Output_NN_NN_merged_pos_j5'][2:-2]
#pos_j6 = j_poses['Output_NN_NN_merged_pos_j6'][2:-2]

#vels_j1 = j_vels['Output_NN_NN_merged_vel_j1'][2:-2]  #34440 -> 34438 k
#vels_j2 = j_vels['Output_NN_NN_merged_vel_j2'][2:-2]
#vels_j3 = j_vels['Output_NN_NN_merged_vel_j3'][2:-2]
#vels_j4 = j_vels['Output_NN_NN_merged_vel_j4'][2:-2] 
#vels_j5 = j_vels['Output_NN_NN_merged_vel_j5'][2:-2]
#vels_j6 = j_vels['Output_NN_NN_merged_vel_j6'][2:-2]

#torq_j1 = j_torqs['Output_NN_NN_merged_torq_j1'][2:-2] #34440 -> 34438 k
#torq_j2 = j_torqs['Output_NN_NN_merged_torq_j2'][2:-2]
#torq_j3 = j_torqs['Output_NN_NN_merged_torq_j3'][2:-2]
#torq_j4 = j_torqs['Output_NN_NN_merged_torq_j4'][2:-2] 
#torq_j5 = j_torqs['Output_NN_NN_merged_torq_j5'][2:-2]
#torq_j6 = j_torqs['Output_NN_NN_merged_torq_j6'][2:-2]

#accs_j1 = j_accels['Output_NN_NN_merged_acc_j1'][2:-2]  #34438 k
#accs_j2 = j_accels['Output_NN_NN_merged_acc_j2'][2:-2] 
#accs_j3 = j_accels['Output_NN_NN_merged_acc_j3'][2:-2] 
#accs_j4 = j_accels['Output_NN_NN_merged_acc_j4'][2:-2]
#accs_j5 = j_accels['Output_NN_NN_merged_acc_j5'][2:-2]
#accs_j6 = j_accels['Output_NN_NN_merged_acc_j6'][2:-2]

# %% [markdown]
# # **PROBLEMA DINÁMICO INVERSO**

# %%
inputs = np.vstack((pos_j1, pos_j2, pos_j3, pos_j4, pos_j5, pos_j6, vels_j1, vels_j2, vels_j3, vels_j4, vels_j5, vels_j6, accs_j1, accs_j2, accs_j3, accs_j4, accs_j5, accs_j6)).T
outputs = np.vstack((torq_j1, torq_j2, torq_j3, torq_j4, torq_j5, torq_j6)).T

# %% [markdown]
# # Red Feed-Forward

# %%
X_train_FF, X_test_FF, y_train_FF, y_test_FF = train_test_split(inputs, outputs, test_size = 0.2)

#Tengo que hacer preprocesado de los datos para que los calculos no sean tan pesados
scaler1_FF = StandardScaler() #RobustScaler()#
X_train_FF = scaler1_FF.fit_transform(X_train_FF)#Primero se llama a la funcion fit para que ajuste los datos
X_test_FF = scaler1_FF.transform(X_test_FF) #Una vez que los datos fueron ajustados se puede llamar a la transformacion directamente
#X_val_FF = scaler1_FF.transform(X_val_FF)

#Lo mismo para los outputs
scaler2_FF = StandardScaler() #RobustScaler()#
y_train_FF = scaler2_FF.fit_transform(y_train_FF)
y_test_FF = scaler2_FF.transform(y_test_FF)
#y_val_FF = scaler2_FF.transform(y_val_FF)

# %%
# Verificar si el modelo ya existe

FF_NN_model_path = "ff_nn_Best_Model.h5"
FF_NN_history_path = "ff_nn_best_history.json"

if os.path.exists(FF_NN_model_path):
    print("🔄 Cargando modelo FF NN existente...")
    FF_SS_network = keras.models.load_model(FF_NN_model_path)
    FF_SS_network.summary()

    if os.path.exists(FF_NN_history_path):
        with open(FF_NN_history_path, "r") as f:
            FF_NN_history = json.load(f)  # Load the history data as a dictionary

        # Create a dummy History object for plotting:
        #FF_NN_history = type('DummyHistory', (object,), {'history': FF_NN_history_dict})()

        # Graficar el history
        plt.figure(figsize=(8, 5))
        plt.plot(FF_NN_history["loss"], label="Training Loss")
        plt.plot(FF_NN_history["val_loss"], label="Validation Loss")
        plt.legend()
        plt.xlabel("Épocas")
        plt.ylabel("Loss")
        plt.grid(True)
        plt.gca().set_ylim(0, 2e-3)
        plt.title("Historial de entrenamiento del modelo FF NN (Dataset Random)")
        plt.show()
    else:
        print("⚠️ No se encontró el archivo de history.")
else:
    print("⚙️ Creando nuevo modelo...")
    #Esta forma es lo más parecida posible al paper
    FF_NN_network = keras.models.Sequential([
        keras.layers.Input(shape=(inputs.shape[1],)),  # Input layer with the shape of the input data
        #keras.layers.LayerNormalization(epsilon=1e-4),
        keras.layers.Dense(100, activation="gelu"),  # First hidden layer with GELU activation
        keras.layers.Dense(100, activation="gelu"),
        #keras.layers.Dense(100, activation="swish"),
        #keras.layers.Dense(200, activation="tanh"),
        keras.layers.Dense(6)
    ])
    FF_NN_network.summary()

    FF_NN_network.compile(loss = 'mean_squared_error', optimizer=keras.optimizers.Adam(learning_rate=1e-4), 
                          metrics = ['mae'])#Que pasa si uso SGD con learning rate

    checkpoint_cb = keras.callbacks.ModelCheckpoint(FF_NN_model_path, 
                                                    save_best_only=True)
    early_stopping_cb = keras.callbacks.EarlyStopping(patience=200, min_delta=1e-10, restore_best_weights=True)

    reduce_lr = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=20, min_lr=1e-8)       
    FF_NN_history = FF_NN_network.fit(X_train_FF, y_train_FF, epochs=3000, 
                                      batch_size=500, validation_split=0.3, shuffle=True, 
                                      callbacks=[checkpoint_cb, early_stopping_cb])

    with open(FF_NN_history_path, "w") as f:
        json.dump(FF_NN_history.history, f)
    with open(FF_NN_history_path, "r") as f:
        FF_NN_history = json.load(f)  # Load the history data as a dictionary

    # Create a dummy History object for plotting:
    #FF_NN_history = type('DummyHistory', (object,), {'history': FF_NN_history_dict})()

    pd.DataFrame(FF_NN_history).plot(figsize=(8, 5))
    plt.grid(True)
    #plt.gca().set_xlim(0, 1)
    plt.gca().set_ylim(0, 2e-3)
    plt.show()

print("✅ Modelo FF NN listo para usar.")
# Out:
# ⚙️ Creando nuevo modelo...
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               1900
#
#  dense_1 (Dense)             (None, 100)               10100
#
#  dense_2 (Dense)             (None, 6)                 606
#
# =================================================================
# Total params: 12606 (98.48 KB)
# Trainable params: 12606 (98.48 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/3000
# 672/672 [==============================] - 9s 10ms/step - loss: 0.5804 - mae: 0.6796 - val_loss: 0.3602 - val_mae: 0.5323
# Epoch 2/3000
#  17/672 [..............................] - ETA: 4s - loss: 0.3560 - mae: 0.5302
# /opt/conda/envs/Python-RT24.1-CUDA/lib/python3.11/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 672/672 [==============================] - 6s 9ms/step - loss: 0.3029 - mae: 0.4846 - val_loss: 0.2555 - val_mae: 0.4423
# Epoch 3/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.2194 - mae: 0.4066 - val_loss: 0.1898 - val_mae: 0.3747
# Epoch 4/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.1697 - mae: 0.3507 - val_loss: 0.1546 - val_mae: 0.3321
# Epoch 5/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.1430 - mae: 0.3171 - val_loss: 0.1340 - val_mae: 0.3049
# Epoch 6/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.1254 - mae: 0.2934 - val_loss: 0.1187 - val_mae: 0.2841
# Epoch 7/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.1118 - mae: 0.2741 - val_loss: 0.1068 - val_mae: 0.2661
# Epoch 8/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.1010 - mae: 0.2578 - val_loss: 0.0971 - val_mae: 0.2510
# Epoch 9/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0921 - mae: 0.2438 - val_loss: 0.0890 - val_mae: 0.2379
# Epoch 10/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0846 - mae: 0.2316 - val_loss: 0.0820 - val_mae: 0.2266
# Epoch 11/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0780 - mae: 0.2207 - val_loss: 0.0757 - val_mae: 0.2161
# Epoch 12/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0720 - mae: 0.2106 - val_loss: 0.0700 - val_mae: 0.2064
# Epoch 13/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0667 - mae: 0.2013 - val_loss: 0.0649 - val_mae: 0.1973
# Epoch 14/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0618 - mae: 0.1926 - val_loss: 0.0602 - val_mae: 0.1890
# Epoch 15/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0574 - mae: 0.1845 - val_loss: 0.0561 - val_mae: 0.1814
# Epoch 16/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0535 - mae: 0.1772 - val_loss: 0.0523 - val_mae: 0.1742
# Epoch 17/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0499 - mae: 0.1703 - val_loss: 0.0489 - val_mae: 0.1676
# Epoch 18/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0468 - mae: 0.1641 - val_loss: 0.0459 - val_mae: 0.1617
# Epoch 19/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0439 - mae: 0.1584 - val_loss: 0.0432 - val_mae: 0.1562
# Epoch 20/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0414 - mae: 0.1530 - val_loss: 0.0408 - val_mae: 0.1511
# Epoch 21/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0391 - mae: 0.1480 - val_loss: 0.0385 - val_mae: 0.1464
# Epoch 22/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0370 - mae: 0.1434 - val_loss: 0.0365 - val_mae: 0.1416
# Epoch 23/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0350 - mae: 0.1390 - val_loss: 0.0347 - val_mae: 0.1374
# Epoch 24/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0332 - mae: 0.1348 - val_loss: 0.0329 - val_mae: 0.1333
# Epoch 25/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0316 - mae: 0.1308 - val_loss: 0.0313 - val_mae: 0.1296
# Epoch 26/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0300 - mae: 0.1270 - val_loss: 0.0298 - val_mae: 0.1258
# Epoch 27/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0286 - mae: 0.1234 - val_loss: 0.0284 - val_mae: 0.1222
# Epoch 28/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0273 - mae: 0.1200 - val_loss: 0.0271 - val_mae: 0.1190
# Epoch 29/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0261 - mae: 0.1168 - val_loss: 0.0260 - val_mae: 0.1159
# Epoch 30/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0249 - mae: 0.1139 - val_loss: 0.0249 - val_mae: 0.1130
# Epoch 31/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0239 - mae: 0.1111 - val_loss: 0.0238 - val_mae: 0.1102
# Epoch 32/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0230 - mae: 0.1085 - val_loss: 0.0229 - val_mae: 0.1078
# Epoch 33/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0221 - mae: 0.1060 - val_loss: 0.0221 - val_mae: 0.1053
# Epoch 34/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0213 - mae: 0.1037 - val_loss: 0.0213 - val_mae: 0.1031
# Epoch 35/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0205 - mae: 0.1016 - val_loss: 0.0205 - val_mae: 0.1010
# Epoch 36/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0198 - mae: 0.0995 - val_loss: 0.0198 - val_mae: 0.0989
# Epoch 37/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0191 - mae: 0.0975 - val_loss: 0.0191 - val_mae: 0.0970
# Epoch 38/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0185 - mae: 0.0956 - val_loss: 0.0185 - val_mae: 0.0951
# Epoch 39/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0179 - mae: 0.0938 - val_loss: 0.0180 - val_mae: 0.0934
# Epoch 40/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0173 - mae: 0.0921 - val_loss: 0.0174 - val_mae: 0.0916
# Epoch 41/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0168 - mae: 0.0904 - val_loss: 0.0168 - val_mae: 0.0900
# Epoch 42/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0163 - mae: 0.0888 - val_loss: 0.0164 - val_mae: 0.0886
# Epoch 43/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0158 - mae: 0.0872 - val_loss: 0.0159 - val_mae: 0.0869
# Epoch 44/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0154 - mae: 0.0857 - val_loss: 0.0154 - val_mae: 0.0853
# Epoch 45/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0149 - mae: 0.0842 - val_loss: 0.0150 - val_mae: 0.0837
# Epoch 46/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0145 - mae: 0.0827 - val_loss: 0.0146 - val_mae: 0.0825
# Epoch 47/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0141 - mae: 0.0814 - val_loss: 0.0142 - val_mae: 0.0811
# Epoch 48/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0137 - mae: 0.0800 - val_loss: 0.0138 - val_mae: 0.0798
# Epoch 49/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0133 - mae: 0.0787 - val_loss: 0.0134 - val_mae: 0.0783
# Epoch 50/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0130 - mae: 0.0774 - val_loss: 0.0131 - val_mae: 0.0772
# Epoch 51/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0126 - mae: 0.0762 - val_loss: 0.0127 - val_mae: 0.0761
# Epoch 52/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0123 - mae: 0.0750 - val_loss: 0.0124 - val_mae: 0.0749
# Epoch 53/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0120 - mae: 0.0739 - val_loss: 0.0121 - val_mae: 0.0737
# Epoch 54/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0117 - mae: 0.0727 - val_loss: 0.0118 - val_mae: 0.0726
# Epoch 55/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0115 - mae: 0.0717 - val_loss: 0.0116 - val_mae: 0.0716
# Epoch 56/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0112 - mae: 0.0706 - val_loss: 0.0113 - val_mae: 0.0706
# Epoch 57/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0110 - mae: 0.0696 - val_loss: 0.0111 - val_mae: 0.0695
# Epoch 58/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0107 - mae: 0.0687 - val_loss: 0.0108 - val_mae: 0.0685
# Epoch 59/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0105 - mae: 0.0677 - val_loss: 0.0106 - val_mae: 0.0676
# Epoch 60/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0103 - mae: 0.0668 - val_loss: 0.0104 - val_mae: 0.0668
# Epoch 61/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0101 - mae: 0.0660 - val_loss: 0.0102 - val_mae: 0.0659
# Epoch 62/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0099 - mae: 0.0652 - val_loss: 0.0100 - val_mae: 0.0651
# Epoch 63/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0097 - mae: 0.0643 - val_loss: 0.0098 - val_mae: 0.0643
# Epoch 64/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0095 - mae: 0.0635 - val_loss: 0.0096 - val_mae: 0.0635
# Epoch 65/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0093 - mae: 0.0628 - val_loss: 0.0094 - val_mae: 0.0627
# Epoch 66/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0092 - mae: 0.0621 - val_loss: 0.0093 - val_mae: 0.0619
# Epoch 67/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0090 - mae: 0.0613 - val_loss: 0.0091 - val_mae: 0.0614
# Epoch 68/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0089 - mae: 0.0607 - val_loss: 0.0090 - val_mae: 0.0608
# Epoch 69/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0087 - mae: 0.0600 - val_loss: 0.0088 - val_mae: 0.0600
# Epoch 70/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0086 - mae: 0.0594 - val_loss: 0.0087 - val_mae: 0.0594
# Epoch 71/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0084 - mae: 0.0587 - val_loss: 0.0085 - val_mae: 0.0588
# Epoch 72/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0083 - mae: 0.0581 - val_loss: 0.0084 - val_mae: 0.0582
# Epoch 73/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0082 - mae: 0.0575 - val_loss: 0.0083 - val_mae: 0.0576
# Epoch 74/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0081 - mae: 0.0570 - val_loss: 0.0081 - val_mae: 0.0569
# Epoch 75/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0079 - mae: 0.0564 - val_loss: 0.0080 - val_mae: 0.0564
# Epoch 76/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0078 - mae: 0.0559 - val_loss: 0.0079 - val_mae: 0.0560
# Epoch 77/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0077 - mae: 0.0553 - val_loss: 0.0078 - val_mae: 0.0554
# Epoch 78/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0076 - mae: 0.0548 - val_loss: 0.0077 - val_mae: 0.0549
# Epoch 79/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0075 - mae: 0.0544 - val_loss: 0.0076 - val_mae: 0.0543
# Epoch 80/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0074 - mae: 0.0539 - val_loss: 0.0075 - val_mae: 0.0538
# Epoch 81/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0073 - mae: 0.0534 - val_loss: 0.0074 - val_mae: 0.0534
# Epoch 82/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0072 - mae: 0.0530 - val_loss: 0.0073 - val_mae: 0.0530
# Epoch 83/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0071 - mae: 0.0525 - val_loss: 0.0072 - val_mae: 0.0527
# Epoch 84/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0070 - mae: 0.0521 - val_loss: 0.0071 - val_mae: 0.0521
# Epoch 85/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0070 - mae: 0.0517 - val_loss: 0.0070 - val_mae: 0.0518
# Epoch 86/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0069 - mae: 0.0513 - val_loss: 0.0070 - val_mae: 0.0516
# Epoch 87/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0068 - mae: 0.0508 - val_loss: 0.0069 - val_mae: 0.0510
# Epoch 88/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0067 - mae: 0.0505 - val_loss: 0.0068 - val_mae: 0.0506
# Epoch 89/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0066 - mae: 0.0501 - val_loss: 0.0067 - val_mae: 0.0501
# Epoch 90/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0066 - mae: 0.0497 - val_loss: 0.0067 - val_mae: 0.0499
# Epoch 91/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0065 - mae: 0.0494 - val_loss: 0.0066 - val_mae: 0.0496
# Epoch 92/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0064 - mae: 0.0490 - val_loss: 0.0065 - val_mae: 0.0491
# Epoch 93/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0064 - mae: 0.0487 - val_loss: 0.0065 - val_mae: 0.0489
# Epoch 94/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0063 - mae: 0.0483 - val_loss: 0.0064 - val_mae: 0.0485
# Epoch 95/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0062 - mae: 0.0480 - val_loss: 0.0063 - val_mae: 0.0480
# Epoch 96/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0062 - mae: 0.0477 - val_loss: 0.0062 - val_mae: 0.0477
# Epoch 97/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0061 - mae: 0.0473 - val_loss: 0.0062 - val_mae: 0.0474
# Epoch 98/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0060 - mae: 0.0470 - val_loss: 0.0061 - val_mae: 0.0471
# Epoch 99/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0060 - mae: 0.0467 - val_loss: 0.0061 - val_mae: 0.0466
# Epoch 100/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0059 - mae: 0.0464 - val_loss: 0.0060 - val_mae: 0.0464
# Epoch 101/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0059 - mae: 0.0461 - val_loss: 0.0060 - val_mae: 0.0462
# Epoch 102/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0058 - mae: 0.0458 - val_loss: 0.0059 - val_mae: 0.0458
# Epoch 103/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0058 - mae: 0.0455 - val_loss: 0.0058 - val_mae: 0.0455
# Epoch 104/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0057 - mae: 0.0453 - val_loss: 0.0058 - val_mae: 0.0453
# Epoch 105/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0057 - mae: 0.0450 - val_loss: 0.0058 - val_mae: 0.0450
# Epoch 106/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0056 - mae: 0.0447 - val_loss: 0.0057 - val_mae: 0.0449
# Epoch 107/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0055 - mae: 0.0445 - val_loss: 0.0056 - val_mae: 0.0444
# Epoch 108/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0055 - mae: 0.0442 - val_loss: 0.0056 - val_mae: 0.0443
# Epoch 109/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0055 - mae: 0.0439 - val_loss: 0.0056 - val_mae: 0.0443
# Epoch 110/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0054 - mae: 0.0437 - val_loss: 0.0055 - val_mae: 0.0438
# Epoch 111/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0054 - mae: 0.0435 - val_loss: 0.0055 - val_mae: 0.0438
# Epoch 112/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0053 - mae: 0.0432 - val_loss: 0.0054 - val_mae: 0.0435
# Epoch 113/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0053 - mae: 0.0430 - val_loss: 0.0054 - val_mae: 0.0432
# Epoch 114/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0052 - mae: 0.0428 - val_loss: 0.0053 - val_mae: 0.0428
# Epoch 115/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0052 - mae: 0.0425 - val_loss: 0.0053 - val_mae: 0.0429
# Epoch 116/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0051 - mae: 0.0423 - val_loss: 0.0053 - val_mae: 0.0426
# Epoch 117/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0051 - mae: 0.0421 - val_loss: 0.0052 - val_mae: 0.0425
# Epoch 118/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0051 - mae: 0.0419 - val_loss: 0.0052 - val_mae: 0.0420
# Epoch 119/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0050 - mae: 0.0417 - val_loss: 0.0052 - val_mae: 0.0420
# Epoch 120/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0050 - mae: 0.0414 - val_loss: 0.0051 - val_mae: 0.0415
# Epoch 121/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0049 - mae: 0.0412 - val_loss: 0.0051 - val_mae: 0.0413
# Epoch 122/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0049 - mae: 0.0410 - val_loss: 0.0050 - val_mae: 0.0412
# Epoch 123/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0049 - mae: 0.0408 - val_loss: 0.0050 - val_mae: 0.0412
# Epoch 124/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0048 - mae: 0.0406 - val_loss: 0.0050 - val_mae: 0.0408
# Epoch 125/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0048 - mae: 0.0404 - val_loss: 0.0049 - val_mae: 0.0406
# Epoch 126/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0048 - mae: 0.0402 - val_loss: 0.0049 - val_mae: 0.0402
# Epoch 127/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0047 - mae: 0.0400 - val_loss: 0.0049 - val_mae: 0.0403
# Epoch 128/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0047 - mae: 0.0398 - val_loss: 0.0048 - val_mae: 0.0399
# Epoch 129/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0047 - mae: 0.0396 - val_loss: 0.0048 - val_mae: 0.0398
# Epoch 130/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0046 - mae: 0.0394 - val_loss: 0.0048 - val_mae: 0.0396
# Epoch 131/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0046 - mae: 0.0393 - val_loss: 0.0047 - val_mae: 0.0394
# Epoch 132/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0046 - mae: 0.0391 - val_loss: 0.0047 - val_mae: 0.0392
# Epoch 133/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0045 - mae: 0.0389 - val_loss: 0.0047 - val_mae: 0.0391
# Epoch 134/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0045 - mae: 0.0387 - val_loss: 0.0046 - val_mae: 0.0389
# Epoch 135/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0045 - mae: 0.0385 - val_loss: 0.0046 - val_mae: 0.0388
# Epoch 136/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0044 - mae: 0.0384 - val_loss: 0.0046 - val_mae: 0.0386
# Epoch 137/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0044 - mae: 0.0382 - val_loss: 0.0045 - val_mae: 0.0386
# Epoch 138/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0044 - mae: 0.0380 - val_loss: 0.0045 - val_mae: 0.0382
# Epoch 139/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0044 - mae: 0.0379 - val_loss: 0.0045 - val_mae: 0.0381
# Epoch 140/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0043 - mae: 0.0377 - val_loss: 0.0044 - val_mae: 0.0381
# Epoch 141/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0043 - mae: 0.0376 - val_loss: 0.0044 - val_mae: 0.0378
# Epoch 142/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0043 - mae: 0.0374 - val_loss: 0.0044 - val_mae: 0.0376
# Epoch 143/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0042 - mae: 0.0372 - val_loss: 0.0044 - val_mae: 0.0375
# Epoch 144/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0042 - mae: 0.0371 - val_loss: 0.0043 - val_mae: 0.0373
# Epoch 145/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0042 - mae: 0.0369 - val_loss: 0.0043 - val_mae: 0.0370
# Epoch 146/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0042 - mae: 0.0367 - val_loss: 0.0043 - val_mae: 0.0370
# Epoch 147/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0041 - mae: 0.0366 - val_loss: 0.0043 - val_mae: 0.0368
# Epoch 148/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0041 - mae: 0.0364 - val_loss: 0.0042 - val_mae: 0.0366
# Epoch 149/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0041 - mae: 0.0363 - val_loss: 0.0042 - val_mae: 0.0363
# Epoch 150/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0041 - mae: 0.0361 - val_loss: 0.0042 - val_mae: 0.0366
# Epoch 151/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0040 - mae: 0.0360 - val_loss: 0.0042 - val_mae: 0.0364
# Epoch 152/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0040 - mae: 0.0358 - val_loss: 0.0041 - val_mae: 0.0361
# Epoch 153/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0040 - mae: 0.0357 - val_loss: 0.0041 - val_mae: 0.0359
# Epoch 154/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0040 - mae: 0.0356 - val_loss: 0.0041 - val_mae: 0.0358
# Epoch 155/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0039 - mae: 0.0355 - val_loss: 0.0041 - val_mae: 0.0356
# Epoch 156/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0039 - mae: 0.0353 - val_loss: 0.0040 - val_mae: 0.0355
# Epoch 157/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0039 - mae: 0.0352 - val_loss: 0.0040 - val_mae: 0.0355
# Epoch 158/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0039 - mae: 0.0350 - val_loss: 0.0040 - val_mae: 0.0352
# Epoch 159/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0038 - mae: 0.0349 - val_loss: 0.0040 - val_mae: 0.0351
# Epoch 160/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0038 - mae: 0.0348 - val_loss: 0.0039 - val_mae: 0.0349
# Epoch 161/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0038 - mae: 0.0347 - val_loss: 0.0039 - val_mae: 0.0349
# Epoch 162/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0038 - mae: 0.0345 - val_loss: 0.0039 - val_mae: 0.0348
# Epoch 163/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0038 - mae: 0.0344 - val_loss: 0.0039 - val_mae: 0.0347
# Epoch 164/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0037 - mae: 0.0343 - val_loss: 0.0039 - val_mae: 0.0345
# Epoch 165/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0037 - mae: 0.0341 - val_loss: 0.0039 - val_mae: 0.0345
# Epoch 166/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0037 - mae: 0.0340 - val_loss: 0.0038 - val_mae: 0.0344
# Epoch 167/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0037 - mae: 0.0339 - val_loss: 0.0038 - val_mae: 0.0342
# Epoch 168/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0037 - mae: 0.0338 - val_loss: 0.0038 - val_mae: 0.0341
# Epoch 169/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0036 - mae: 0.0337 - val_loss: 0.0038 - val_mae: 0.0340
# Epoch 170/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0036 - mae: 0.0336 - val_loss: 0.0037 - val_mae: 0.0338
# Epoch 171/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0036 - mae: 0.0334 - val_loss: 0.0037 - val_mae: 0.0338
# Epoch 172/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0036 - mae: 0.0333 - val_loss: 0.0037 - val_mae: 0.0336
# Epoch 173/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0036 - mae: 0.0332 - val_loss: 0.0037 - val_mae: 0.0335
# Epoch 174/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0035 - mae: 0.0331 - val_loss: 0.0037 - val_mae: 0.0333
# Epoch 175/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0035 - mae: 0.0330 - val_loss: 0.0037 - val_mae: 0.0333
# Epoch 176/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0035 - mae: 0.0329 - val_loss: 0.0036 - val_mae: 0.0332
# Epoch 177/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0035 - mae: 0.0328 - val_loss: 0.0036 - val_mae: 0.0330
# Epoch 178/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0035 - mae: 0.0327 - val_loss: 0.0036 - val_mae: 0.0329
# Epoch 179/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0034 - mae: 0.0325 - val_loss: 0.0036 - val_mae: 0.0328
# Epoch 180/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0034 - mae: 0.0324 - val_loss: 0.0036 - val_mae: 0.0329
# Epoch 181/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0034 - mae: 0.0323 - val_loss: 0.0035 - val_mae: 0.0325
# Epoch 182/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0034 - mae: 0.0322 - val_loss: 0.0035 - val_mae: 0.0323
# Epoch 183/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0034 - mae: 0.0321 - val_loss: 0.0035 - val_mae: 0.0324
# Epoch 184/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0034 - mae: 0.0320 - val_loss: 0.0035 - val_mae: 0.0323
# Epoch 185/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0033 - mae: 0.0319 - val_loss: 0.0035 - val_mae: 0.0323
# Epoch 186/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0033 - mae: 0.0318 - val_loss: 0.0035 - val_mae: 0.0323
# Epoch 187/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0033 - mae: 0.0317 - val_loss: 0.0035 - val_mae: 0.0321
# Epoch 188/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0033 - mae: 0.0316 - val_loss: 0.0034 - val_mae: 0.0319
# Epoch 189/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0033 - mae: 0.0315 - val_loss: 0.0034 - val_mae: 0.0319
# Epoch 190/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0033 - mae: 0.0314 - val_loss: 0.0034 - val_mae: 0.0317
# Epoch 191/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0033 - mae: 0.0313 - val_loss: 0.0034 - val_mae: 0.0315
# Epoch 192/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0032 - mae: 0.0312 - val_loss: 0.0034 - val_mae: 0.0315
# Epoch 193/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0032 - mae: 0.0311 - val_loss: 0.0034 - val_mae: 0.0314
# Epoch 194/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0032 - mae: 0.0311 - val_loss: 0.0033 - val_mae: 0.0312
# Epoch 195/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0032 - mae: 0.0310 - val_loss: 0.0033 - val_mae: 0.0312
# Epoch 196/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0032 - mae: 0.0309 - val_loss: 0.0033 - val_mae: 0.0312
# Epoch 197/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0032 - mae: 0.0307 - val_loss: 0.0033 - val_mae: 0.0310
# Epoch 198/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0031 - mae: 0.0307 - val_loss: 0.0033 - val_mae: 0.0309
# Epoch 199/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0031 - mae: 0.0306 - val_loss: 0.0033 - val_mae: 0.0309
# Epoch 200/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0031 - mae: 0.0305 - val_loss: 0.0033 - val_mae: 0.0307
# Epoch 201/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0031 - mae: 0.0304 - val_loss: 0.0032 - val_mae: 0.0306
# Epoch 202/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0031 - mae: 0.0303 - val_loss: 0.0032 - val_mae: 0.0306
# Epoch 203/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0031 - mae: 0.0302 - val_loss: 0.0032 - val_mae: 0.0305
# Epoch 204/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0031 - mae: 0.0302 - val_loss: 0.0032 - val_mae: 0.0306
# Epoch 205/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0030 - mae: 0.0300 - val_loss: 0.0032 - val_mae: 0.0304
# Epoch 206/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0030 - mae: 0.0300 - val_loss: 0.0032 - val_mae: 0.0302
# Epoch 207/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0030 - mae: 0.0299 - val_loss: 0.0032 - val_mae: 0.0304
# Epoch 208/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0030 - mae: 0.0298 - val_loss: 0.0031 - val_mae: 0.0300
# Epoch 209/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0030 - mae: 0.0297 - val_loss: 0.0031 - val_mae: 0.0301
# Epoch 210/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0030 - mae: 0.0297 - val_loss: 0.0031 - val_mae: 0.0301
# Epoch 211/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0030 - mae: 0.0295 - val_loss: 0.0031 - val_mae: 0.0298
# Epoch 212/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0030 - mae: 0.0295 - val_loss: 0.0031 - val_mae: 0.0298
# Epoch 213/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0029 - mae: 0.0294 - val_loss: 0.0031 - val_mae: 0.0297
# Epoch 214/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0029 - mae: 0.0293 - val_loss: 0.0031 - val_mae: 0.0296
# Epoch 215/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0029 - mae: 0.0293 - val_loss: 0.0031 - val_mae: 0.0295
# Epoch 216/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0029 - mae: 0.0292 - val_loss: 0.0031 - val_mae: 0.0296
# Epoch 217/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0029 - mae: 0.0291 - val_loss: 0.0030 - val_mae: 0.0294
# Epoch 218/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0029 - mae: 0.0291 - val_loss: 0.0030 - val_mae: 0.0294
# Epoch 219/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0029 - mae: 0.0290 - val_loss: 0.0030 - val_mae: 0.0292
# Epoch 220/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0029 - mae: 0.0289 - val_loss: 0.0030 - val_mae: 0.0291
# Epoch 221/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0029 - mae: 0.0288 - val_loss: 0.0030 - val_mae: 0.0291
# Epoch 222/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0028 - mae: 0.0288 - val_loss: 0.0030 - val_mae: 0.0291
# Epoch 223/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0028 - mae: 0.0287 - val_loss: 0.0030 - val_mae: 0.0289
# Epoch 224/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0028 - mae: 0.0286 - val_loss: 0.0030 - val_mae: 0.0289
# Epoch 225/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0028 - mae: 0.0285 - val_loss: 0.0029 - val_mae: 0.0287
# Epoch 226/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0028 - mae: 0.0285 - val_loss: 0.0029 - val_mae: 0.0288
# Epoch 227/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0028 - mae: 0.0284 - val_loss: 0.0029 - val_mae: 0.0286
# Epoch 228/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0028 - mae: 0.0283 - val_loss: 0.0029 - val_mae: 0.0286
# Epoch 229/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0028 - mae: 0.0283 - val_loss: 0.0029 - val_mae: 0.0286
# Epoch 230/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0028 - mae: 0.0282 - val_loss: 0.0029 - val_mae: 0.0285
# Epoch 231/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0027 - mae: 0.0281 - val_loss: 0.0029 - val_mae: 0.0283
# Epoch 232/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0027 - mae: 0.0281 - val_loss: 0.0029 - val_mae: 0.0284
# Epoch 233/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0027 - mae: 0.0280 - val_loss: 0.0029 - val_mae: 0.0283
# Epoch 234/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0027 - mae: 0.0279 - val_loss: 0.0029 - val_mae: 0.0281
# Epoch 235/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0027 - mae: 0.0279 - val_loss: 0.0028 - val_mae: 0.0281
# Epoch 236/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0027 - mae: 0.0278 - val_loss: 0.0028 - val_mae: 0.0280
# Epoch 237/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0027 - mae: 0.0277 - val_loss: 0.0028 - val_mae: 0.0278
# Epoch 238/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0027 - mae: 0.0277 - val_loss: 0.0028 - val_mae: 0.0279
# Epoch 239/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0027 - mae: 0.0276 - val_loss: 0.0028 - val_mae: 0.0278
# Epoch 240/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0027 - mae: 0.0275 - val_loss: 0.0028 - val_mae: 0.0279
# Epoch 241/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0026 - mae: 0.0275 - val_loss: 0.0028 - val_mae: 0.0279
# Epoch 242/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0026 - mae: 0.0274 - val_loss: 0.0028 - val_mae: 0.0275
# Epoch 243/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0026 - mae: 0.0273 - val_loss: 0.0028 - val_mae: 0.0276
# Epoch 244/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0026 - mae: 0.0273 - val_loss: 0.0028 - val_mae: 0.0275
# Epoch 245/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0026 - mae: 0.0272 - val_loss: 0.0027 - val_mae: 0.0276
# Epoch 246/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0026 - mae: 0.0272 - val_loss: 0.0027 - val_mae: 0.0274
# Epoch 247/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0026 - mae: 0.0271 - val_loss: 0.0027 - val_mae: 0.0276
# Epoch 248/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0026 - mae: 0.0270 - val_loss: 0.0027 - val_mae: 0.0274
# Epoch 249/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0026 - mae: 0.0270 - val_loss: 0.0027 - val_mae: 0.0272
# Epoch 250/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0026 - mae: 0.0269 - val_loss: 0.0027 - val_mae: 0.0271
# Epoch 251/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0026 - mae: 0.0269 - val_loss: 0.0027 - val_mae: 0.0272
# Epoch 252/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0025 - mae: 0.0268 - val_loss: 0.0027 - val_mae: 0.0271
# Epoch 253/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0025 - mae: 0.0267 - val_loss: 0.0027 - val_mae: 0.0270
# Epoch 254/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0025 - mae: 0.0267 - val_loss: 0.0027 - val_mae: 0.0269
# Epoch 255/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0025 - mae: 0.0266 - val_loss: 0.0027 - val_mae: 0.0269
# Epoch 256/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0025 - mae: 0.0266 - val_loss: 0.0026 - val_mae: 0.0269
# Epoch 257/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0025 - mae: 0.0265 - val_loss: 0.0026 - val_mae: 0.0267
# Epoch 258/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0025 - mae: 0.0265 - val_loss: 0.0026 - val_mae: 0.0267
# Epoch 259/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0025 - mae: 0.0264 - val_loss: 0.0026 - val_mae: 0.0269
# Epoch 260/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0025 - mae: 0.0263 - val_loss: 0.0026 - val_mae: 0.0267
# Epoch 261/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0025 - mae: 0.0263 - val_loss: 0.0026 - val_mae: 0.0267
# Epoch 262/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0025 - mae: 0.0262 - val_loss: 0.0026 - val_mae: 0.0265
# Epoch 263/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0025 - mae: 0.0262 - val_loss: 0.0026 - val_mae: 0.0264
# Epoch 264/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0024 - mae: 0.0261 - val_loss: 0.0026 - val_mae: 0.0263
# Epoch 265/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0024 - mae: 0.0260 - val_loss: 0.0026 - val_mae: 0.0264
# Epoch 266/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0024 - mae: 0.0260 - val_loss: 0.0026 - val_mae: 0.0263
# Epoch 267/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0024 - mae: 0.0259 - val_loss: 0.0025 - val_mae: 0.0262
# Epoch 268/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0024 - mae: 0.0259 - val_loss: 0.0026 - val_mae: 0.0263
# Epoch 269/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0024 - mae: 0.0258 - val_loss: 0.0025 - val_mae: 0.0260
# Epoch 270/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0024 - mae: 0.0258 - val_loss: 0.0025 - val_mae: 0.0260
# Epoch 271/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0024 - mae: 0.0257 - val_loss: 0.0025 - val_mae: 0.0260
# Epoch 272/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0024 - mae: 0.0257 - val_loss: 0.0025 - val_mae: 0.0258
# Epoch 273/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0024 - mae: 0.0256 - val_loss: 0.0025 - val_mae: 0.0258
# Epoch 274/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0024 - mae: 0.0255 - val_loss: 0.0025 - val_mae: 0.0257
# Epoch 275/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0024 - mae: 0.0255 - val_loss: 0.0025 - val_mae: 0.0258
# Epoch 276/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0024 - mae: 0.0254 - val_loss: 0.0025 - val_mae: 0.0258
# Epoch 277/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0023 - mae: 0.0254 - val_loss: 0.0025 - val_mae: 0.0259
# Epoch 278/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0023 - mae: 0.0254 - val_loss: 0.0025 - val_mae: 0.0255
# Epoch 279/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0023 - mae: 0.0253 - val_loss: 0.0025 - val_mae: 0.0256
# Epoch 280/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0023 - mae: 0.0252 - val_loss: 0.0025 - val_mae: 0.0255
# Epoch 281/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0023 - mae: 0.0252 - val_loss: 0.0024 - val_mae: 0.0255
# Epoch 282/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0023 - mae: 0.0251 - val_loss: 0.0024 - val_mae: 0.0254
# Epoch 283/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0023 - mae: 0.0251 - val_loss: 0.0024 - val_mae: 0.0253
# Epoch 284/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0023 - mae: 0.0250 - val_loss: 0.0024 - val_mae: 0.0252
# Epoch 285/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0023 - mae: 0.0250 - val_loss: 0.0024 - val_mae: 0.0252
# Epoch 286/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0023 - mae: 0.0249 - val_loss: 0.0024 - val_mae: 0.0253
# Epoch 287/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0023 - mae: 0.0249 - val_loss: 0.0024 - val_mae: 0.0253
# Epoch 288/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0023 - mae: 0.0248 - val_loss: 0.0024 - val_mae: 0.0253
# Epoch 289/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0023 - mae: 0.0248 - val_loss: 0.0024 - val_mae: 0.0252
# Epoch 290/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0023 - mae: 0.0247 - val_loss: 0.0024 - val_mae: 0.0252
# Epoch 291/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0022 - mae: 0.0247 - val_loss: 0.0024 - val_mae: 0.0250
# Epoch 292/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0022 - mae: 0.0246 - val_loss: 0.0024 - val_mae: 0.0251
# Epoch 293/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0022 - mae: 0.0246 - val_loss: 0.0024 - val_mae: 0.0248
# Epoch 294/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0022 - mae: 0.0245 - val_loss: 0.0024 - val_mae: 0.0249
# Epoch 295/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0022 - mae: 0.0245 - val_loss: 0.0023 - val_mae: 0.0246
# Epoch 296/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0022 - mae: 0.0244 - val_loss: 0.0023 - val_mae: 0.0247
# Epoch 297/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0022 - mae: 0.0244 - val_loss: 0.0023 - val_mae: 0.0245
# Epoch 298/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0022 - mae: 0.0243 - val_loss: 0.0023 - val_mae: 0.0246
# Epoch 299/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0022 - mae: 0.0243 - val_loss: 0.0023 - val_mae: 0.0245
# Epoch 300/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0022 - mae: 0.0243 - val_loss: 0.0023 - val_mae: 0.0245
# Epoch 301/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0022 - mae: 0.0242 - val_loss: 0.0023 - val_mae: 0.0244
# Epoch 302/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0022 - mae: 0.0241 - val_loss: 0.0023 - val_mae: 0.0243
# Epoch 303/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0022 - mae: 0.0241 - val_loss: 0.0023 - val_mae: 0.0246
# Epoch 304/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0022 - mae: 0.0240 - val_loss: 0.0023 - val_mae: 0.0242
# Epoch 305/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0022 - mae: 0.0240 - val_loss: 0.0023 - val_mae: 0.0242
# Epoch 306/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0021 - mae: 0.0240 - val_loss: 0.0023 - val_mae: 0.0242
# Epoch 307/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0021 - mae: 0.0239 - val_loss: 0.0023 - val_mae: 0.0240
# Epoch 308/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0021 - mae: 0.0239 - val_loss: 0.0023 - val_mae: 0.0242
# Epoch 309/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0021 - mae: 0.0238 - val_loss: 0.0023 - val_mae: 0.0241
# Epoch 310/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0021 - mae: 0.0238 - val_loss: 0.0022 - val_mae: 0.0240
# Epoch 311/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0021 - mae: 0.0237 - val_loss: 0.0022 - val_mae: 0.0240
# Epoch 312/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0021 - mae: 0.0237 - val_loss: 0.0022 - val_mae: 0.0239
# Epoch 313/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0021 - mae: 0.0236 - val_loss: 0.0022 - val_mae: 0.0238
# Epoch 314/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0021 - mae: 0.0236 - val_loss: 0.0022 - val_mae: 0.0238
# Epoch 315/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0021 - mae: 0.0235 - val_loss: 0.0022 - val_mae: 0.0239
# Epoch 316/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0021 - mae: 0.0235 - val_loss: 0.0022 - val_mae: 0.0237
# Epoch 317/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0021 - mae: 0.0234 - val_loss: 0.0022 - val_mae: 0.0236
# Epoch 318/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0021 - mae: 0.0234 - val_loss: 0.0022 - val_mae: 0.0236
# Epoch 319/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0021 - mae: 0.0233 - val_loss: 0.0022 - val_mae: 0.0235
# Epoch 320/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0021 - mae: 0.0233 - val_loss: 0.0022 - val_mae: 0.0237
# Epoch 321/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0020 - mae: 0.0232 - val_loss: 0.0022 - val_mae: 0.0234
# Epoch 322/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0020 - mae: 0.0232 - val_loss: 0.0022 - val_mae: 0.0234
# Epoch 323/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0020 - mae: 0.0231 - val_loss: 0.0022 - val_mae: 0.0235
# Epoch 324/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0020 - mae: 0.0231 - val_loss: 0.0022 - val_mae: 0.0235
# Epoch 325/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0020 - mae: 0.0230 - val_loss: 0.0022 - val_mae: 0.0234
# Epoch 326/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0020 - mae: 0.0230 - val_loss: 0.0021 - val_mae: 0.0232
# Epoch 327/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0020 - mae: 0.0229 - val_loss: 0.0021 - val_mae: 0.0233
# Epoch 328/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0020 - mae: 0.0229 - val_loss: 0.0021 - val_mae: 0.0231
# Epoch 329/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0020 - mae: 0.0228 - val_loss: 0.0021 - val_mae: 0.0230
# Epoch 330/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0020 - mae: 0.0228 - val_loss: 0.0021 - val_mae: 0.0230
# Epoch 331/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0020 - mae: 0.0228 - val_loss: 0.0021 - val_mae: 0.0230
# Epoch 332/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0020 - mae: 0.0227 - val_loss: 0.0021 - val_mae: 0.0228
# Epoch 333/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0020 - mae: 0.0226 - val_loss: 0.0021 - val_mae: 0.0229
# Epoch 334/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0020 - mae: 0.0226 - val_loss: 0.0021 - val_mae: 0.0229
# Epoch 335/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0020 - mae: 0.0226 - val_loss: 0.0021 - val_mae: 0.0227
# Epoch 336/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0020 - mae: 0.0225 - val_loss: 0.0021 - val_mae: 0.0226
# Epoch 337/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0019 - mae: 0.0224 - val_loss: 0.0021 - val_mae: 0.0227
# Epoch 338/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0019 - mae: 0.0224 - val_loss: 0.0021 - val_mae: 0.0226
# Epoch 339/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0019 - mae: 0.0224 - val_loss: 0.0021 - val_mae: 0.0228
# Epoch 340/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0019 - mae: 0.0223 - val_loss: 0.0021 - val_mae: 0.0227
# Epoch 341/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0019 - mae: 0.0223 - val_loss: 0.0021 - val_mae: 0.0229
# Epoch 342/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0019 - mae: 0.0222 - val_loss: 0.0020 - val_mae: 0.0224
# Epoch 343/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0019 - mae: 0.0222 - val_loss: 0.0020 - val_mae: 0.0223
# Epoch 344/3000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0019 - mae: 0.0221 - val_loss: 0.0020 - val_mae: 0.0224
# Epoch 345/3000
# ...
# Epoch 2122/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.3163e-04 - mae: 0.0100 - val_loss: 7.0095e-04 - val_mae: 0.0102
# Epoch 2123/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2965e-04 - mae: 0.0100 - val_loss: 7.0265e-04 - val_mae: 0.0102
# Epoch 2124/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.3122e-04 - mae: 0.0100 - val_loss: 7.1387e-04 - val_mae: 0.0105
# Epoch 2125/3000
# 672/672 [==============================] - 6s 8ms/step - loss: 5.3137e-04 - mae: 0.0100 - val_loss: 6.9705e-04 - val_mae: 0.0102
# Epoch 2126/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.3193e-04 - mae: 0.0100 - val_loss: 7.0856e-04 - val_mae: 0.0105
# Epoch 2127/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2921e-04 - mae: 0.0100 - val_loss: 7.0396e-04 - val_mae: 0.0103
# Epoch 2128/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.3098e-04 - mae: 0.0100 - val_loss: 7.1512e-04 - val_mae: 0.0107
# Epoch 2129/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2985e-04 - mae: 0.0100 - val_loss: 6.9983e-04 - val_mae: 0.0102
# Epoch 2130/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.3041e-04 - mae: 0.0100 - val_loss: 7.0616e-04 - val_mae: 0.0105
# Epoch 2131/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.3146e-04 - mae: 0.0100 - val_loss: 7.0867e-04 - val_mae: 0.0103
# Epoch 2132/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2705e-04 - mae: 0.0099 - val_loss: 7.0215e-04 - val_mae: 0.0105
# Epoch 2133/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2969e-04 - mae: 0.0100 - val_loss: 7.0503e-04 - val_mae: 0.0102
# Epoch 2134/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.3102e-04 - mae: 0.0100 - val_loss: 7.0508e-04 - val_mae: 0.0102
# Epoch 2135/3000
# 672/672 [==============================] - 6s 8ms/step - loss: 5.2921e-04 - mae: 0.0099 - val_loss: 6.9968e-04 - val_mae: 0.0102
# Epoch 2136/3000
# 672/672 [==============================] - 6s 8ms/step - loss: 5.2824e-04 - mae: 0.0100 - val_loss: 6.9740e-04 - val_mae: 0.0101
# Epoch 2137/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2953e-04 - mae: 0.0100 - val_loss: 6.9716e-04 - val_mae: 0.0102
# Epoch 2138/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2909e-04 - mae: 0.0100 - val_loss: 7.1914e-04 - val_mae: 0.0107
# Epoch 2139/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2906e-04 - mae: 0.0100 - val_loss: 6.9888e-04 - val_mae: 0.0103
# Epoch 2140/3000
# 672/672 [==============================] - 6s 8ms/step - loss: 5.3025e-04 - mae: 0.0100 - val_loss: 7.0358e-04 - val_mae: 0.0104
# Epoch 2141/3000
# 672/672 [==============================] - 6s 8ms/step - loss: 5.3113e-04 - mae: 0.0100 - val_loss: 7.0217e-04 - val_mae: 0.0103
# Epoch 2142/3000
# 672/672 [==============================] - 6s 8ms/step - loss: 5.2886e-04 - mae: 0.0100 - val_loss: 6.9699e-04 - val_mae: 0.0101
# Epoch 2143/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2741e-04 - mae: 0.0099 - val_loss: 7.0829e-04 - val_mae: 0.0106
# Epoch 2144/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2760e-04 - mae: 0.0099 - val_loss: 7.0613e-04 - val_mae: 0.0103
# Epoch 2145/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2926e-04 - mae: 0.0100 - val_loss: 7.1507e-04 - val_mae: 0.0105
# Epoch 2146/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2788e-04 - mae: 0.0100 - val_loss: 7.0647e-04 - val_mae: 0.0104
# Epoch 2147/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2805e-04 - mae: 0.0100 - val_loss: 7.0106e-04 - val_mae: 0.0102
# Epoch 2148/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2863e-04 - mae: 0.0100 - val_loss: 6.9930e-04 - val_mae: 0.0102
# Epoch 2149/3000
# 672/672 [==============================] - 6s 8ms/step - loss: 5.2909e-04 - mae: 0.0100 - val_loss: 6.9592e-04 - val_mae: 0.0102
# Epoch 2150/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2690e-04 - mae: 0.0099 - val_loss: 7.1494e-04 - val_mae: 0.0105
# Epoch 2151/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2824e-04 - mae: 0.0100 - val_loss: 7.0406e-04 - val_mae: 0.0103
# Epoch 2152/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2635e-04 - mae: 0.0099 - val_loss: 6.9596e-04 - val_mae: 0.0102
# Epoch 2153/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2693e-04 - mae: 0.0100 - val_loss: 6.9834e-04 - val_mae: 0.0102
# Epoch 2154/3000
# 672/672 [==============================] - 6s 8ms/step - loss: 5.2696e-04 - mae: 0.0100 - val_loss: 6.9939e-04 - val_mae: 0.0103
# Epoch 2155/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2666e-04 - mae: 0.0099 - val_loss: 6.9980e-04 - val_mae: 0.0104
# Epoch 2156/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2809e-04 - mae: 0.0100 - val_loss: 7.0642e-04 - val_mae: 0.0103
# Epoch 2157/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2668e-04 - mae: 0.0100 - val_loss: 6.9908e-04 - val_mae: 0.0102
# Epoch 2158/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2743e-04 - mae: 0.0099 - val_loss: 6.9095e-04 - val_mae: 0.0100
# Epoch 2159/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2584e-04 - mae: 0.0099 - val_loss: 7.0185e-04 - val_mae: 0.0102
# Epoch 2160/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2671e-04 - mae: 0.0100 - val_loss: 6.9787e-04 - val_mae: 0.0103
# Epoch 2161/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2676e-04 - mae: 0.0099 - val_loss: 6.9864e-04 - val_mae: 0.0103
# Epoch 2162/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2659e-04 - mae: 0.0100 - val_loss: 6.9458e-04 - val_mae: 0.0102
# Epoch 2163/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2467e-04 - mae: 0.0099 - val_loss: 6.9972e-04 - val_mae: 0.0103
# Epoch 2164/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2561e-04 - mae: 0.0099 - val_loss: 6.9831e-04 - val_mae: 0.0104
# Epoch 2165/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2359e-04 - mae: 0.0099 - val_loss: 6.9797e-04 - val_mae: 0.0103
# Epoch 2166/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2607e-04 - mae: 0.0100 - val_loss: 7.0741e-04 - val_mae: 0.0105
# Epoch 2167/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2526e-04 - mae: 0.0099 - val_loss: 7.0295e-04 - val_mae: 0.0103
# Epoch 2168/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2700e-04 - mae: 0.0100 - val_loss: 7.0350e-04 - val_mae: 0.0104
# Epoch 2169/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2478e-04 - mae: 0.0099 - val_loss: 6.9986e-04 - val_mae: 0.0102
# Epoch 2170/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2420e-04 - mae: 0.0099 - val_loss: 7.0167e-04 - val_mae: 0.0102
# Epoch 2171/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2459e-04 - mae: 0.0099 - val_loss: 7.1004e-04 - val_mae: 0.0105
# Epoch 2172/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2454e-04 - mae: 0.0099 - val_loss: 7.0089e-04 - val_mae: 0.0103
# Epoch 2173/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2675e-04 - mae: 0.0100 - val_loss: 7.0071e-04 - val_mae: 0.0103
# Epoch 2174/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2308e-04 - mae: 0.0099 - val_loss: 6.9661e-04 - val_mae: 0.0104
# Epoch 2175/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2443e-04 - mae: 0.0099 - val_loss: 7.0857e-04 - val_mae: 0.0103
# Epoch 2176/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2337e-04 - mae: 0.0099 - val_loss: 6.9932e-04 - val_mae: 0.0102
# Epoch 2177/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2327e-04 - mae: 0.0099 - val_loss: 6.9594e-04 - val_mae: 0.0103
# Epoch 2178/3000
# 672/672 [==============================] - 6s 8ms/step - loss: 5.2463e-04 - mae: 0.0099 - val_loss: 7.0092e-04 - val_mae: 0.0104
# Epoch 2179/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2472e-04 - mae: 0.0100 - val_loss: 6.9609e-04 - val_mae: 0.0104
# Epoch 2180/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2572e-04 - mae: 0.0100 - val_loss: 6.9586e-04 - val_mae: 0.0101
# Epoch 2181/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2304e-04 - mae: 0.0099 - val_loss: 6.9187e-04 - val_mae: 0.0101
# Epoch 2182/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2278e-04 - mae: 0.0099 - val_loss: 6.9497e-04 - val_mae: 0.0101
# Epoch 2183/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2780e-04 - mae: 0.0100 - val_loss: 6.9290e-04 - val_mae: 0.0101
# Epoch 2184/3000
# 672/672 [==============================] - 6s 8ms/step - loss: 5.2216e-04 - mae: 0.0099 - val_loss: 6.8901e-04 - val_mae: 0.0099
# Epoch 2185/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2279e-04 - mae: 0.0099 - val_loss: 6.9923e-04 - val_mae: 0.0103
# Epoch 2186/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2245e-04 - mae: 0.0099 - val_loss: 6.9415e-04 - val_mae: 0.0102
# Epoch 2187/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2165e-04 - mae: 0.0099 - val_loss: 7.0000e-04 - val_mae: 0.0103
# Epoch 2188/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2258e-04 - mae: 0.0099 - val_loss: 7.0092e-04 - val_mae: 0.0103
# Epoch 2189/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2263e-04 - mae: 0.0099 - val_loss: 6.9744e-04 - val_mae: 0.0101
# Epoch 2190/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2237e-04 - mae: 0.0099 - val_loss: 7.0083e-04 - val_mae: 0.0103
# Epoch 2191/3000
# 672/672 [==============================] - 6s 8ms/step - loss: 5.2248e-04 - mae: 0.0099 - val_loss: 6.8895e-04 - val_mae: 0.0100
# Epoch 2192/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2242e-04 - mae: 0.0099 - val_loss: 6.9172e-04 - val_mae: 0.0101
# Epoch 2193/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2195e-04 - mae: 0.0099 - val_loss: 6.8930e-04 - val_mae: 0.0100
# Epoch 2194/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2171e-04 - mae: 0.0099 - val_loss: 6.9468e-04 - val_mae: 0.0101
# Epoch 2195/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2165e-04 - mae: 0.0099 - val_loss: 6.9122e-04 - val_mae: 0.0101
# Epoch 2196/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2239e-04 - mae: 0.0099 - val_loss: 6.9509e-04 - val_mae: 0.0104
# Epoch 2197/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2197e-04 - mae: 0.0099 - val_loss: 6.9954e-04 - val_mae: 0.0103
# Epoch 2198/3000
# 672/672 [==============================] - 6s 8ms/step - loss: 5.2213e-04 - mae: 0.0099 - val_loss: 7.1360e-04 - val_mae: 0.0106
# Epoch 2199/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2014e-04 - mae: 0.0099 - val_loss: 6.9064e-04 - val_mae: 0.0102
# Epoch 2200/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2198e-04 - mae: 0.0099 - val_loss: 6.9772e-04 - val_mae: 0.0103
# Epoch 2201/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2129e-04 - mae: 0.0099 - val_loss: 7.0090e-04 - val_mae: 0.0104
# Epoch 2202/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2119e-04 - mae: 0.0099 - val_loss: 6.8901e-04 - val_mae: 0.0100
# Epoch 2203/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.1992e-04 - mae: 0.0099 - val_loss: 7.0710e-04 - val_mae: 0.0105
# Epoch 2204/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.1939e-04 - mae: 0.0098 - val_loss: 6.9720e-04 - val_mae: 0.0104
# Epoch 2205/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2162e-04 - mae: 0.0099 - val_loss: 6.9120e-04 - val_mae: 0.0101
# Epoch 2206/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2083e-04 - mae: 0.0099 - val_loss: 6.9199e-04 - val_mae: 0.0102
# Epoch 2207/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2293e-04 - mae: 0.0099 - val_loss: 6.9508e-04 - val_mae: 0.0103
# Epoch 2208/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.1954e-04 - mae: 0.0099 - val_loss: 6.8892e-04 - val_mae: 0.0101
# Epoch 2209/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.1928e-04 - mae: 0.0099 - val_loss: 6.9275e-04 - val_mae: 0.0101
# Epoch 2210/3000
# 672/672 [==============================] - 6s 8ms/step - loss: 5.1920e-04 - mae: 0.0099 - val_loss: 6.9832e-04 - val_mae: 0.0104
# Epoch 2211/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2043e-04 - mae: 0.0099 - val_loss: 6.9867e-04 - val_mae: 0.0103
# Epoch 2212/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.2031e-04 - mae: 0.0099 - val_loss: 7.0071e-04 - val_mae: 0.0104
# Epoch 2213/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.1898e-04 - mae: 0.0099 - val_loss: 6.9174e-04 - val_mae: 0.0102
# Epoch 2214/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.1859e-04 - mae: 0.0098 - val_loss: 6.8818e-04 - val_mae: 0.0101
# Epoch 2215/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.1978e-04 - mae: 0.0099 - val_loss: 6.9176e-04 - val_mae: 0.0102
# Epoch 2216/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.1758e-04 - mae: 0.0098 - val_loss: 6.9777e-04 - val_mae: 0.0103
# Epoch 2217/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.1808e-04 - mae: 0.0099 - val_loss: 6.9309e-04 - val_mae: 0.0101
# Epoch 2218/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.1833e-04 - mae: 0.0099 - val_loss: 6.9072e-04 - val_mae: 0.0101
# Epoch 2219/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.1863e-04 - mae: 0.0098 - val_loss: 6.8701e-04 - val_mae: 0.0099
# Epoch 2220/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.1885e-04 - mae: 0.0099 - val_loss: 6.9220e-04 - val_mae: 0.0102
# Epoch 2221/3000
# 672/672 [==============================] - 6s 8ms/step - loss: 5.1804e-04 - mae: 0.0099 - val_loss: 6.9068e-04 - val_mae: 0.0102
# Epoch 2222/3000
# 672/672 [==============================] - 6s 8ms/step - loss: 5.1861e-04 - mae: 0.0099 - val_loss: 6.8890e-04 - val_mae: 0.0101
# Epoch 2223/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.1687e-04 - mae: 0.0098 - val_loss: 6.9533e-04 - val_mae: 0.0101
# Epoch 2224/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.1965e-04 - mae: 0.0099 - val_loss: 6.9664e-04 - val_mae: 0.0101
# Epoch 2225/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.1730e-04 - mae: 0.0098 - val_loss: 6.9051e-04 - val_mae: 0.0101
# Epoch 2226/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.1779e-04 - mae: 0.0099 - val_loss: 6.9014e-04 - val_mae: 0.0101
# Epoch 2227/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.1929e-04 - mae: 0.0099 - val_loss: 6.8995e-04 - val_mae: 0.0100
# Epoch 2228/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.1756e-04 - mae: 0.0098 - val_loss: 6.9022e-04 - val_mae: 0.0101
# Epoch 2229/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.1713e-04 - mae: 0.0098 - val_loss: 6.9986e-04 - val_mae: 0.0104
# Epoch 2230/3000
# 672/672 [==============================] - 5s 8ms/step - loss: 5.1814e-04 - mae: 0.0099 - val_loss: 7.2536e-04 - val_mae: 0.0110
# Epoch 2231/3000
# 278/672 [===========>..................] - ETA: 2s - loss: 5.2016e-04 - mae: 0.0099

# %%
# !ls -lh ff_nn_Best_Model.h5 ff_nn_best_history.json

# %%
from IPython.display import FileLink

# Crear enlaces para descarga
FileLink('ff_nn_Best_Model.h5')

# %%
FileLink('ff_nn_best_history.json')

# %%
#import os
#os.remove("ff_nn_Best_Model.h5")
#os.remove("ff_nn_best_history.json")

# %%
accuracy_test_NN = FF_NN_network.evaluate(X_test_FF, y_test_FF)

# %%
predictions_NN = FF_NN_network.predict(X_test_FF)

# %%
y_test_FF[0]

# %% [markdown]
# # Verificación de métricas y validación con nuevo dataset

# %% [markdown]
# # Verificación con Dataset Lineal
