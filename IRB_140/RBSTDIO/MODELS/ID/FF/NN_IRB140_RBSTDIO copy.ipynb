# %%
import numpy as np
import scipy as sp
import sympy as smp
import matplotlib.pyplot as plt
import pandas as pd #Lo necesito para cargar y leer el csv
import tensorflow as tf
import os
import random
import time
import math
import keras 
import json
from datetime import datetime

#import tensorflow
from tensorflow import keras
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from tensorflow.keras.layers import Dense, LSTM, BatchNormalization, Dropout, InputLayer
from tensorflow.keras.models import Sequential #
from sklearn.model_selection import train_test_split
from keras.regularizers import l2, l1, l1_l2
from sklearn.utils import shuffle
import pandas as pd
from scipy.signal import savgol_filter
from scipy.interpolate import CubicSpline
from scipy.ndimage import gaussian_filter1d
#from keras_tuner import RandomSearch
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
# Out:
# 2025-07-20 16:39:52.439632: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-07-20 16:39:52.439656: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-07-20 16:39:52.439662: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
import tensorflow as tf
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available: 2

# %%
tf.keras.backend.set_floatx('float64')

# %% [markdown]
# # **Filtro Discreto para agregar aceleraciones**
# De acuerdo con el paper *Identification of robot forward dynamics via neural network*:
#
# “The corresponding joint accelerations were retrieved through the application of an appropriate discrete filter to the joint velocities just collected.”
#
# Entonces, se tomarán dos datos “de más” (muestra 0 y muestra 101) para permitir aplicar el filtro discreto a las n-2 muestras y tener información de velocidad. Se podrán estudiar otras técnicas para derivar las aceleraciones a partir de las velocidades.

# %%
# Definir una función para calcular las aceleraciones utilizando un filtro de diferencia finita
def calcular_aceleraciones(velocidades, h):
    aceleraciones = []
    for i in range(1, len(velocidades) -1 ):
        # Aplicar el filtro de diferencia finita para calcular la aceleración
        #aceleracion = (velocidades[i + 1] - 2 * velocidades[i] + velocidades[i - 1]) #->Esto no seria la segunda derivada?
        aceleracion = (velocidades[i + 1] -  velocidades[i - 1])/(2*h)
        aceleraciones.append(aceleracion)
    return np.array(aceleraciones)

# Definir una función para calcular las aceleraciones utilizando un filtro de diferencia finita
def calcular_aceleraciones_2(velocidades, h):
    aceleraciones = []
    for i in range(1, len(velocidades) - 4 ):
        # Aplicar el filtro de diferencia finita para calcular la aceleración
        aceleracion = (- velocidades[i + 2] +  8*velocidades[i + 1] - 8*velocidades[i - 2] + velocidades[i - 1]) /(12*h)
        aceleraciones.append(aceleracion)
    return np.array(aceleraciones)



import os, types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.

cos_client = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='1eFnNpgSMiDaf_Yx-ZXteaGaokoLTfIKQXajc1kbdepo',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/identity/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.direct.us-south.cloud-object-storage.appdomain.cloud')

bucket = 'irb140-donotdelete-pr-sdzbp1zcz7qnal'
object_key = 'Output_linear_002_test_NN_NN.csv'

body = cos_client.get_object(Bucket=bucket,Key=object_key)['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_1 = pd.read_csv(body)
df_1.head(10)



def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.

cos_client = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='1eFnNpgSMiDaf_Yx-ZXteaGaokoLTfIKQXajc1kbdepo',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/identity/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.direct.us-south.cloud-object-storage.appdomain.cloud')

bucket = 'irb140-donotdelete-pr-sdzbp1zcz7qnal'
object_key = 'Output_NN_NN_merged_2.csv'

body = cos_client.get_object(Bucket=bucket,Key=object_key)['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_2 = pd.read_csv(body)
df_2.head(10)





def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.

cos_client = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='1eFnNpgSMiDaf_Yx-ZXteaGaokoLTfIKQXajc1kbdepo',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/identity/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.direct.us-south.cloud-object-storage.appdomain.cloud')

bucket = 'irb140-donotdelete-pr-sdzbp1zcz7qnal'
object_key = 'Output_NN_NN_merged.csv'

body = cos_client.get_object(Bucket=bucket,Key=object_key)['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_3 = pd.read_csv(body)
df_3.head(10)



def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.

cos_client = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='1eFnNpgSMiDaf_Yx-ZXteaGaokoLTfIKQXajc1kbdepo',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/identity/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.direct.us-south.cloud-object-storage.appdomain.cloud')

bucket = 'irb140-donotdelete-pr-sdzbp1zcz7qnal'
object_key = 'Output_NN_NN_4e6_fixed.csv'

body = cos_client.get_object(Bucket=bucket,Key=object_key)['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_4 = pd.read_csv(body)
df_4.head(10)



def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.

cos_client = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='1eFnNpgSMiDaf_Yx-ZXteaGaokoLTfIKQXajc1kbdepo',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/identity/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.direct.us-south.cloud-object-storage.appdomain.cloud')

bucket = 'irb140-donotdelete-pr-sdzbp1zcz7qnal'
object_key = 'Output_NN_NN_1.csv'

body = cos_client.get_object(Bucket=bucket,Key=object_key)['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_5 = pd.read_csv(body)
df_5.head(10)



def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.

cos_client = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='1eFnNpgSMiDaf_Yx-ZXteaGaokoLTfIKQXajc1kbdepo',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/identity/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.direct.us-south.cloud-object-storage.appdomain.cloud')

bucket = 'irb140-donotdelete-pr-sdzbp1zcz7qnal'
object_key = 'Output_NN_NN_CUT_MERGED.csv'

body = cos_client.get_object(Bucket=bucket,Key=object_key)['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_6 = pd.read_csv(body)
df_6.head(10)




def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.

cos_client = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='1eFnNpgSMiDaf_Yx-ZXteaGaokoLTfIKQXajc1kbdepo',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/identity/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.direct.us-south.cloud-object-storage.appdomain.cloud')

bucket = 'irb140-donotdelete-pr-sdzbp1zcz7qnal'
object_key = 'Output_linear_NN_NN.csv'

body = cos_client.get_object(Bucket=bucket,Key=object_key)['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_7 = pd.read_csv(body)
df_7.head(10)
# Out:
#    start_time   random_ID   end_time   random_V   random_Z   pos_j1   pos_j2  \
# 0        0.01           1       0.01    44.3387    13.3286  38.8691  56.8166
# 1        0.02           1       0.02    44.3387    13.3286  38.8691  56.8166
# 2        0.03           1       0.03    44.3387    13.3286  38.8692  56.8166
# 3        0.04           1       0.04    44.3387    13.3286  38.8699  56.8153
# 4        0.05           1       0.05    44.3387    13.3286  38.8714  56.8120
# 5        0.06           1       0.06    44.3387    13.3286  38.8763  56.7989
# 6        0.07           1       0.07    44.3387    13.3286  38.8817  56.7832
# 7        0.08           1       0.08    44.3387    13.3286  38.8929  56.7504
# 8        0.09           1       0.09    44.3387    13.3286  38.9018  56.7246
# 9        0.10           1       0.10    44.3387    13.3286  38.9163  56.6832
#
#     pos_j3   pos_j4   pos_j5  ...        vel_j3        vel_j4        vel_j5  \
# 0 -44.4538  27.1509  77.9901  ... -7.966630e-07  6.367170e-07  1.104570e-06
# 1 -44.4538  27.1509  77.9901  ... -2.476310e-07  1.979140e-07  3.433390e-07
# 2 -44.4537  27.1509  77.9901  ...  3.026870e-02  4.242320e-03  2.885760e-03
# 3 -44.4507  27.1520  77.9909  ...  5.273590e-01  2.336480e-01  1.593350e-01
# 4 -44.4418  27.1564  77.9938  ...  1.585330e+00  7.950580e-01  5.422220e-01
# 5 -44.4053  27.1760  78.0072  ...  4.291600e+00  2.351820e+00  1.603630e+00
# 6 -44.3611  27.2004  78.0239  ...  6.281490e+00  3.492510e+00  2.380870e+00
# 7 -44.2693  27.2516  78.0587  ...  8.464700e+00  4.705810e+00  3.206830e+00
# 8 -44.1971  27.2916  78.0860  ...  9.247770e+00  5.125500e+00  3.492240e+00
# 9 -44.0811  27.3558  78.1297  ...  9.772430e+00  5.406370e+00  3.683100e+00
#
#          vel_j6    torq_j1   torq_j2    torq_j3   torq_j4   torq_j5   torq_j6
# 0  1.654760e-06   0.000081  -102.576 -20.845600  0.074018  0.003685  0.000014
# 1  5.143560e-07   0.000025  -102.576 -20.845500  0.074011  0.003668  0.000000
# 2 -3.938810e-03   2.260020  -103.952 -19.350800  0.492498  0.581197 -0.202456
# 3 -2.190560e-01  11.834500  -111.350 -11.681700  2.834510  4.505330 -1.883060
# 4 -7.461850e-01  16.103400  -116.560  -6.329820  3.748950  6.033220 -2.586040
# 5 -2.208290e+00  18.597000  -122.413  -0.557024  4.770580  7.714690 -3.344290
# 6 -3.278950e+00  18.280300  -124.063  -0.119863  5.282180  8.566820 -3.707570
# 7 -4.416410e+00  17.220700  -124.072  -1.504390  5.758580  9.368880 -4.036480
# 8 -4.809320e+00  16.861400  -123.960  -2.147740  5.917320  9.636010 -4.145240
# 9 -5.072010e+00  16.645000  -123.820  -2.589730  6.023040  9.813340 -4.217430
#
# [10 rows x 23 columns]

# %%
import numpy as np

# Variables y configuraciones
num_variables = 6
time_interval = 0.05

datos_IRB_140 = {
    'datos_IRB_140_Output_linear_NN_NN': df_7,
    'datos_IRB_140_Output_NN_NN_merged': df_5,
    'datos_IRB_140_Output_NN_NN_New_2': df_3
}

tcps_vels = {}
tcps_accus = {}

j_poses = {}
j_vels = {}
j_accels = {}
j_torqs = {}
times = {}

# Nombres de los archivos base usados como etiquetas
files = ['Output_linear_NN_NN', 'Output_NN_NN_merged', 'Output_NN_NN_New_2']
datos_IRB_140_st = 'datos_IRB_140_'

tcp_vel = 'rand_v'
tcp_accu = 'rand_z'

j_pos = 'pos_j'
j_vel = 'vel_j'
j_accel = 'acc_j'
j_torq = 'torq_j'

def calcular_aceleraciones(vels, dt):
    """Calcula aceleración usando esquema de diferencias finitas centradas de 5 puntos."""
    acc = np.zeros_like(vels)
    n = len(vels)
    for i in range(2, n - 2):
        acc[i] = (-vels[i + 2] + 8 * vels[i + 1] - 8 * vels[i - 1] + vels[i - 2]) / (12 * dt)
    return acc

# Procesamiento de los dataframes
for file in files:
    print(file)
    variable_name = datos_IRB_140_st + file
    df = datos_IRB_140[variable_name]

    # Tiempo
    time_var = f"{file}_time"
    times[time_var] = df.iloc[:, 0].values

    # Velocidades y aceleraciones TCP
    tcps_vels_name = f"{file}_{tcp_vel}"
    tcps_vels[tcps_vels_name] = df.iloc[1:-1, 3].values

    tcps_accus_name = f"{file}_{tcp_accu}"
    tcps_accus[tcps_accus_name] = df.iloc[1:-1, 4].values

    # Articulaciones
    for i in range(1, num_variables + 1):
        # Posición articular (en radianes)
        pos_j_name = f"{file}_{j_pos}{i}"
        j_poses[pos_j_name] = df.iloc[:, 4 + i].values *(np.pi/180.0)

        # Velocidad articular (en radianes/s)
        vel_j_name = f"{file}_{j_vel}{i}"
        j_vels[vel_j_name] = df.iloc[:, 10 + i].values *(np.pi/180.0)

        # Torque articular
        torq_j_name = f"{file}_{j_torq}{i}"
        j_torqs[torq_j_name] = df.iloc[:, 16 + i].values

        # Torque articular: calcular max y normalizar inmediatamente
        #torq_j_name = f"{file}_{j_torq}{i}"
        #raw_torque = df.iloc[:, 16 + i].values

        #max_torque = np.max(np.abs(raw_torque))
        #if max_torque == 0:
        #    print(f"⚠️ Torque máximo en {file} eje {i} es 0. Se dejará sin normalizar.")
        #    normalized_torque = raw_torque
        #else:
        #    normalized_torque = raw_torque / max_torque

        #j_torqs[torq_j_name] = normalized_torque

        # Aceleración articular (calculada numéricamente)
        acc_j_name = f"{file}_{j_accel}{i}"
        j_accels[acc_j_name] = calcular_aceleraciones(j_vels[vel_j_name], time_interval) *(np.pi/180.0)
# Out:
# Output_linear_NN_NN
# Output_NN_NN_merged
# Output_NN_NN_New_2

# %%
tcps_vels['Output_NN_NN_merged_rand_v']#[2:-2]
tcps_accus['Output_NN_NN_merged_rand_z']#[2:-2]

j_poses['Output_NN_NN_merged_pos_j1']#[2:-2]
j_poses['Output_NN_NN_merged_pos_j2']#[2:-2]
j_poses['Output_NN_NN_merged_pos_j3']#[2:-2]
j_poses['Output_NN_NN_merged_pos_j4']#[2:-2]
j_poses['Output_NN_NN_merged_pos_j5']#[2:-2]
j_poses['Output_NN_NN_merged_pos_j6']#[2:-2]

j_vels['Output_NN_NN_merged_vel_j1']#[2:-2]
j_vels['Output_NN_NN_merged_vel_j2']#[2:-2]
j_vels['Output_NN_NN_merged_vel_j3']#[2:-2]
j_vels['Output_NN_NN_merged_vel_j4']#[2:-2]
j_vels['Output_NN_NN_merged_vel_j5']#[2:-2]
j_vels['Output_NN_NN_merged_vel_j6']#[2:-2]

j_torqs['Output_NN_NN_merged_torq_j1']#[2:-2]
j_torqs['Output_NN_NN_merged_torq_j2']#[2:-2]
j_torqs['Output_NN_NN_merged_torq_j3']#[2:-2]
j_torqs['Output_NN_NN_merged_torq_j4']#[2:-2]
j_torqs['Output_NN_NN_merged_torq_j5']#[2:-2]
j_torqs['Output_NN_NN_merged_torq_j6']#[2:-2]

j_accels['Output_NN_NN_merged_acc_j1']#[2:-2]
j_accels['Output_NN_NN_merged_acc_j2']#[2:-2]
j_accels['Output_NN_NN_merged_acc_j3']#[2:-2]
j_accels['Output_NN_NN_merged_acc_j4']#[2:-2]
j_accels['Output_NN_NN_merged_acc_j5']#[2:-2]
j_accels['Output_NN_NN_merged_acc_j6']#[2:-2]
# Out:
# array([0.00000000e+00, 0.00000000e+00, 1.46989582e-04, ...,
#        1.00269901e-06, 0.00000000e+00, 0.00000000e+00])

# %%
tcps_vels['Output_linear_NN_NN_rand_v']#[2:-2]
tcps_accus['Output_linear_NN_NN_rand_z']#[2:-2]

j_poses['Output_linear_NN_NN_pos_j1']#[2:-2]
j_poses['Output_linear_NN_NN_pos_j2']#[2:-2]
j_poses['Output_linear_NN_NN_pos_j3']#[2:-2]
j_poses['Output_linear_NN_NN_pos_j4']#[2:-2]
j_poses['Output_linear_NN_NN_pos_j5']#[2:-2]
j_poses['Output_linear_NN_NN_pos_j6']#[2:-2]

j_vels['Output_linear_NN_NN_vel_j1']#[2:-2]
j_vels['Output_linear_NN_NN_vel_j2']#[2:-2]
j_vels['Output_linear_NN_NN_vel_j3']#[2:-2]
j_vels['Output_linear_NN_NN_vel_j4']#[2:-2]
j_vels['Output_linear_NN_NN_vel_j5']#[2:-2]
j_vels['Output_linear_NN_NN_vel_j6']#[2:-2]

j_torqs['Output_linear_NN_NN_torq_j1']#[2:-2]
j_torqs['Output_linear_NN_NN_torq_j2']#[2:-2]
j_torqs['Output_linear_NN_NN_torq_j3']#[2:-2]
j_torqs['Output_linear_NN_NN_torq_j4']#[2:-2]
j_torqs['Output_linear_NN_NN_torq_j5']#[2:-2]
j_torqs['Output_linear_NN_NN_torq_j6']#[2:-2]

j_accels['Output_linear_NN_NN_acc_j1']#[2:-2]
j_accels['Output_linear_NN_NN_acc_j2']#[2:-2]
j_accels['Output_linear_NN_NN_acc_j3']#[2:-2]
j_accels['Output_linear_NN_NN_acc_j4']#[2:-2]
j_accels['Output_linear_NN_NN_acc_j5']#[2:-2]
j_accels['Output_linear_NN_NN_acc_j6']#[2:-2]
# Out:
# array([ 0.00000000e+00,  0.00000000e+00, -5.10876647e-04, ...,
#        -3.22950787e-18,  0.00000000e+00,  0.00000000e+00])

# %%
print(j_poses['Output_NN_NN_merged_pos_j6'].shape)
print(j_accels['Output_NN_NN_merged_acc_j6'].shape)
# Out:
# (299999,)
# (299999,)

# %%
print(j_accels['Output_NN_NN_merged_acc_j6'][2:-2].shape)
# Out:
# (299995,)

# %%
pos_j1 = np.concatenate([j_poses['Output_NN_NN_merged_pos_j1'][2:-2],j_poses['Output_linear_NN_NN_pos_j1'][2:-2]])
pos_j2 = np.concatenate([j_poses['Output_NN_NN_merged_pos_j2'][2:-2],j_poses['Output_linear_NN_NN_pos_j2'][2:-2]])
pos_j3 = np.concatenate([j_poses['Output_NN_NN_merged_pos_j3'][2:-2],j_poses['Output_linear_NN_NN_pos_j3'][2:-2]])
pos_j4 = np.concatenate([j_poses['Output_NN_NN_merged_pos_j4'][2:-2],j_poses['Output_linear_NN_NN_pos_j4'][2:-2]])
pos_j5 = np.concatenate([j_poses['Output_NN_NN_merged_pos_j5'][2:-2],j_poses['Output_linear_NN_NN_pos_j5'][2:-2]])
pos_j6 = np.concatenate([j_poses['Output_NN_NN_merged_pos_j6'][2:-2],j_poses['Output_linear_NN_NN_pos_j6'][2:-2]])

vels_j1 = np.concatenate([j_vels['Output_NN_NN_merged_vel_j1'][2:-2],j_vels['Output_linear_NN_NN_vel_j1'][2:-2]])
vels_j2 = np.concatenate([j_vels['Output_NN_NN_merged_vel_j2'][2:-2],j_vels['Output_linear_NN_NN_vel_j2'][2:-2]])
vels_j3 = np.concatenate([j_vels['Output_NN_NN_merged_vel_j3'][2:-2],j_vels['Output_linear_NN_NN_vel_j3'][2:-2]])
vels_j4 = np.concatenate([j_vels['Output_NN_NN_merged_vel_j4'][2:-2],j_vels['Output_linear_NN_NN_vel_j4'][2:-2]])
vels_j5 = np.concatenate([j_vels['Output_NN_NN_merged_vel_j5'][2:-2],j_vels['Output_linear_NN_NN_vel_j5'][2:-2]])
vels_j6 = np.concatenate([j_vels['Output_NN_NN_merged_vel_j6'][2:-2],j_vels['Output_linear_NN_NN_vel_j6'][2:-2]])

torq_j1 = np.concatenate([j_torqs['Output_NN_NN_merged_torq_j1'][2:-2],j_torqs['Output_linear_NN_NN_torq_j1'][2:-2]])
torq_j2 = np.concatenate([j_torqs['Output_NN_NN_merged_torq_j2'][2:-2],j_torqs['Output_linear_NN_NN_torq_j2'][2:-2]])
torq_j3 = np.concatenate([j_torqs['Output_NN_NN_merged_torq_j3'][2:-2],j_torqs['Output_linear_NN_NN_torq_j3'][2:-2]])
torq_j4 = np.concatenate([j_torqs['Output_NN_NN_merged_torq_j4'][2:-2],j_torqs['Output_linear_NN_NN_torq_j4'][2:-2]])
torq_j5 = np.concatenate([j_torqs['Output_NN_NN_merged_torq_j5'][2:-2],j_torqs['Output_linear_NN_NN_torq_j5'][2:-2]])
torq_j6 = np.concatenate([j_torqs['Output_NN_NN_merged_torq_j6'][2:-2],j_torqs['Output_linear_NN_NN_torq_j6'][2:-2]])

accs_j1 = np.concatenate([j_accels['Output_NN_NN_merged_acc_j1'][2:-2],j_accels['Output_linear_NN_NN_acc_j1'][2:-2]])
accs_j2 = np.concatenate([j_accels['Output_NN_NN_merged_acc_j2'][2:-2],j_accels['Output_linear_NN_NN_acc_j2'][2:-2]])
accs_j3 = np.concatenate([j_accels['Output_NN_NN_merged_acc_j3'][2:-2],j_accels['Output_linear_NN_NN_acc_j3'][2:-2]])
accs_j4 = np.concatenate([j_accels['Output_NN_NN_merged_acc_j4'][2:-2],j_accels['Output_linear_NN_NN_acc_j4'][2:-2]])
accs_j5 = np.concatenate([j_accels['Output_NN_NN_merged_acc_j5'][2:-2],j_accels['Output_linear_NN_NN_acc_j5'][2:-2]])
accs_j6 = np.concatenate([j_accels['Output_NN_NN_merged_acc_j6'][2:-2],j_accels['Output_linear_NN_NN_acc_j6'][2:-2]])

# %%
#Los dos primeros y los dos ultimos puntos no tienen informacion de aceleración, ya que la misma usa cuatro puntos para reconsruirse
#time_joint= times['Output_NN_NN_merged_time'][2:-2]

#pos_j1 = j_poses['Output_NN_NN_merged_pos_j1'][2:-2]  #34440 -> 34438, k
#pos_j2 = j_poses['Output_NN_NN_merged_pos_j2'][2:-2]
#pos_j3 = j_poses['Output_NN_NN_merged_pos_j3'][2:-2]
#pos_j4 = j_poses['Output_NN_NN_merged_pos_j4'][2:-2]
#pos_j5 = j_poses['Output_NN_NN_merged_pos_j5'][2:-2]
#pos_j6 = j_poses['Output_NN_NN_merged_pos_j6'][2:-2]

#vels_j1 = j_vels['Output_NN_NN_merged_vel_j1'][2:-2]  #34440 -> 34438 k
#vels_j2 = j_vels['Output_NN_NN_merged_vel_j2'][2:-2]
#vels_j3 = j_vels['Output_NN_NN_merged_vel_j3'][2:-2]
#vels_j4 = j_vels['Output_NN_NN_merged_vel_j4'][2:-2] 
#vels_j5 = j_vels['Output_NN_NN_merged_vel_j5'][2:-2]
#vels_j6 = j_vels['Output_NN_NN_merged_vel_j6'][2:-2]

#torq_j1 = j_torqs['Output_NN_NN_merged_torq_j1'][2:-2] #34440 -> 34438 k
#torq_j2 = j_torqs['Output_NN_NN_merged_torq_j2'][2:-2]
#torq_j3 = j_torqs['Output_NN_NN_merged_torq_j3'][2:-2]
#torq_j4 = j_torqs['Output_NN_NN_merged_torq_j4'][2:-2] 
#torq_j5 = j_torqs['Output_NN_NN_merged_torq_j5'][2:-2]
#torq_j6 = j_torqs['Output_NN_NN_merged_torq_j6'][2:-2]

#accs_j1 = j_accels['Output_NN_NN_merged_acc_j1'][2:-2]  #34438 k
#accs_j2 = j_accels['Output_NN_NN_merged_acc_j2'][2:-2] 
#accs_j3 = j_accels['Output_NN_NN_merged_acc_j3'][2:-2] 
#accs_j4 = j_accels['Output_NN_NN_merged_acc_j4'][2:-2]
#accs_j5 = j_accels['Output_NN_NN_merged_acc_j5'][2:-2]
#accs_j6 = j_accels['Output_NN_NN_merged_acc_j6'][2:-2]

# %% [markdown]
# # **PROBLEMA DINÁMICO INVERSO**

# %%
inputs = np.vstack((pos_j1, pos_j2, pos_j3, pos_j4, pos_j5, pos_j6, vels_j1, vels_j2, vels_j3, vels_j4, vels_j5, vels_j6, accs_j1, accs_j2, accs_j3, accs_j4, accs_j5, accs_j6)).T
outputs = np.vstack((torq_j1, torq_j2, torq_j3, torq_j4, torq_j5, torq_j6)).T

# %% [markdown]
# # Red Feed-Forward

# %%
X_train_FF, X_test_FF, y_train_FF, y_test_FF = train_test_split(inputs, outputs, test_size = 0.2)

#Tengo que hacer preprocesado de los datos para que los calculos no sean tan pesados
scaler1_FF = StandardScaler() #RobustScaler()#
X_train_FF = scaler1_FF.fit_transform(X_train_FF)#Primero se llama a la funcion fit para que ajuste los datos
X_test_FF = scaler1_FF.transform(X_test_FF) #Una vez que los datos fueron ajustados se puede llamar a la transformacion directamente
#X_val_FF = scaler1_FF.transform(X_val_FF)

#Lo mismo para los outputs
scaler2_FF = StandardScaler() #RobustScaler()#
y_train_FF = scaler2_FF.fit_transform(y_train_FF)
y_test_FF = scaler2_FF.transform(y_test_FF)
#y_val_FF = scaler2_FF.transform(y_val_FF)

# %%
# Verificar si el modelo ya existe

FF_NN_model_path = "ff_nn_Best_Model.h5"
FF_NN_history_path = "ff_nn_best_history.json"

if os.path.exists(FF_NN_model_path):
    print("🔄 Cargando modelo FF NN existente...")
    FF_SS_network = keras.models.load_model(FF_NN_model_path)
    FF_SS_network.summary()

    if os.path.exists(FF_NN_history_path):
        with open(FF_NN_history_path, "r") as f:
            FF_NN_history = json.load(f)  # Load the history data as a dictionary

        # Create a dummy History object for plotting:
        #FF_NN_history = type('DummyHistory', (object,), {'history': FF_NN_history_dict})()

        # Graficar el history
        plt.figure(figsize=(8, 5))
        plt.plot(FF_NN_history["loss"], label="Training Loss")
        plt.plot(FF_NN_history["val_loss"], label="Validation Loss")
        plt.legend()
        plt.xlabel("Épocas")
        plt.ylabel("Loss")
        plt.grid(True)
        plt.gca().set_ylim(0, 2e-3)
        plt.title("Historial de entrenamiento del modelo FF NN (Dataset Random)")
        plt.show()
    else:
        print("⚠️ No se encontró el archivo de history.")
else:
    print("⚙️ Creando nuevo modelo...")
    #Esta forma es lo más parecida posible al paper
    FF_NN_network = keras.models.Sequential([
        keras.layers.Input(shape=(inputs.shape[1],)),  # Input layer with the shape of the input data
        #keras.layers.LayerNormalization(epsilon=1e-4),
        keras.layers.Dense(200, activation="swish"),  # First hidden layer with GELU activation
        keras.layers.Dense(100, activation="swish"),
        #keras.layers.Dense(100, activation="swish"),
        #keras.layers.Dense(200, activation="tanh"),
        keras.layers.Dense(6)
    ])
    FF_NN_network.summary()

    FF_NN_network.compile(loss = 'mean_squared_error', optimizer=keras.optimizers.Adam(learning_rate=1e-3), 
                          metrics = ['mae'])#Que pasa si uso SGD con learning rate

    checkpoint_cb = keras.callbacks.ModelCheckpoint(FF_NN_model_path, 
                                                    save_best_only=True)
    early_stopping_cb = keras.callbacks.EarlyStopping(patience=200, min_delta=1e-10, restore_best_weights=True)

    reduce_lr = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=20, min_lr=1e-8)       
    FF_NN_history = FF_NN_network.fit(X_train_FF, y_train_FF, epochs=1000, 
                                      batch_size=500, validation_split=0.3, shuffle=True, 
                                      callbacks=[checkpoint_cb, early_stopping_cb])

    with open(FF_NN_history_path, "w") as f:
        json.dump(FF_NN_history.history, f)
    with open(FF_NN_history_path, "r") as f:
        FF_NN_history = json.load(f)  # Load the history data as a dictionary

    # Create a dummy History object for plotting:
    #FF_NN_history = type('DummyHistory', (object,), {'history': FF_NN_history_dict})()

    pd.DataFrame(FF_NN_history).plot(figsize=(8, 5))
    plt.grid(True)
    #plt.gca().set_xlim(0, 1)
    plt.gca().set_ylim(0, 2e-3)
    plt.show()

print("✅ Modelo FF NN listo para usar.")
# Out:
# ⚙️ Creando nuevo modelo...
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 200)               3800
#
#  dense_1 (Dense)             (None, 100)               20100
#
#  dense_2 (Dense)             (None, 6)                 606
#
# =================================================================
# Total params: 24506 (191.45 KB)
# Trainable params: 24506 (191.45 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/1000
# 672/672 [==============================] - 8s 9ms/step - loss: 0.1985 - mae: 0.3712 - val_loss: 0.1035 - val_mae: 0.2638
# Epoch 2/1000
#  18/672 [..............................] - ETA: 4s - loss: 0.1007 - mae: 0.2611
# /opt/conda/envs/Python-RT24.1-CUDA/lib/python3.11/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0784 - mae: 0.2230 - val_loss: 0.0590 - val_mae: 0.1887
# Epoch 3/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 0.0474 - mae: 0.1658 - val_loss: 0.0382 - val_mae: 0.1466
# Epoch 4/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0320 - mae: 0.1323 - val_loss: 0.0271 - val_mae: 0.1199
# Epoch 5/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0235 - mae: 0.1102 - val_loss: 0.0209 - val_mae: 0.1025
# Epoch 6/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 0.0182 - mae: 0.0946 - val_loss: 0.0165 - val_mae: 0.0887
# Epoch 7/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 0.0148 - mae: 0.0833 - val_loss: 0.0138 - val_mae: 0.0795
# Epoch 8/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0126 - mae: 0.0751 - val_loss: 0.0118 - val_mae: 0.0717
# Epoch 9/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0112 - mae: 0.0691 - val_loss: 0.0108 - val_mae: 0.0669
# Epoch 10/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0100 - mae: 0.0644 - val_loss: 0.0094 - val_mae: 0.0609
# Epoch 11/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0090 - mae: 0.0602 - val_loss: 0.0087 - val_mae: 0.0579
# Epoch 12/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 0.0084 - mae: 0.0571 - val_loss: 0.0080 - val_mae: 0.0553
# Epoch 13/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0078 - mae: 0.0546 - val_loss: 0.0076 - val_mae: 0.0527
# Epoch 14/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 0.0073 - mae: 0.0522 - val_loss: 0.0073 - val_mae: 0.0515
# Epoch 15/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0069 - mae: 0.0503 - val_loss: 0.0069 - val_mae: 0.0497
# Epoch 16/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0065 - mae: 0.0486 - val_loss: 0.0066 - val_mae: 0.0485
# Epoch 17/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 0.0062 - mae: 0.0471 - val_loss: 0.0063 - val_mae: 0.0468
# Epoch 18/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0060 - mae: 0.0458 - val_loss: 0.0062 - val_mae: 0.0462
# Epoch 19/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 0.0058 - mae: 0.0446 - val_loss: 0.0059 - val_mae: 0.0445
# Epoch 20/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0055 - mae: 0.0434 - val_loss: 0.0057 - val_mae: 0.0437
# Epoch 21/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0053 - mae: 0.0422 - val_loss: 0.0053 - val_mae: 0.0414
# Epoch 22/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0051 - mae: 0.0413 - val_loss: 0.0051 - val_mae: 0.0411
# Epoch 23/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0049 - mae: 0.0402 - val_loss: 0.0051 - val_mae: 0.0404
# Epoch 24/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0047 - mae: 0.0393 - val_loss: 0.0048 - val_mae: 0.0394
# Epoch 25/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0046 - mae: 0.0383 - val_loss: 0.0048 - val_mae: 0.0397
# Epoch 26/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 0.0045 - mae: 0.0377 - val_loss: 0.0046 - val_mae: 0.0380
# Epoch 27/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0042 - mae: 0.0365 - val_loss: 0.0044 - val_mae: 0.0366
# Epoch 28/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0042 - mae: 0.0362 - val_loss: 0.0042 - val_mae: 0.0359
# Epoch 29/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0040 - mae: 0.0354 - val_loss: 0.0040 - val_mae: 0.0347
# Epoch 30/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0039 - mae: 0.0345 - val_loss: 0.0040 - val_mae: 0.0349
# Epoch 31/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 0.0038 - mae: 0.0341 - val_loss: 0.0039 - val_mae: 0.0337
# Epoch 32/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 0.0037 - mae: 0.0333 - val_loss: 0.0037 - val_mae: 0.0332
# Epoch 33/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0035 - mae: 0.0326 - val_loss: 0.0037 - val_mae: 0.0332
# Epoch 34/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 0.0035 - mae: 0.0321 - val_loss: 0.0036 - val_mae: 0.0326
# Epoch 35/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0033 - mae: 0.0315 - val_loss: 0.0037 - val_mae: 0.0335
# Epoch 36/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0033 - mae: 0.0314 - val_loss: 0.0033 - val_mae: 0.0305
# Epoch 37/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0032 - mae: 0.0304 - val_loss: 0.0032 - val_mae: 0.0301
# Epoch 38/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0031 - mae: 0.0301 - val_loss: 0.0033 - val_mae: 0.0304
# Epoch 39/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0030 - mae: 0.0296 - val_loss: 0.0032 - val_mae: 0.0302
# Epoch 40/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 0.0030 - mae: 0.0295 - val_loss: 0.0031 - val_mae: 0.0294
# Epoch 41/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0029 - mae: 0.0288 - val_loss: 0.0030 - val_mae: 0.0284
# Epoch 42/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0028 - mae: 0.0284 - val_loss: 0.0029 - val_mae: 0.0283
# Epoch 43/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0027 - mae: 0.0279 - val_loss: 0.0029 - val_mae: 0.0283
# Epoch 44/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0027 - mae: 0.0277 - val_loss: 0.0028 - val_mae: 0.0270
# Epoch 45/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0027 - mae: 0.0274 - val_loss: 0.0027 - val_mae: 0.0271
# Epoch 46/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 0.0026 - mae: 0.0271 - val_loss: 0.0026 - val_mae: 0.0258
# Epoch 47/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 0.0028 - mae: 0.0277 - val_loss: 0.0027 - val_mae: 0.0267
# Epoch 48/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0025 - mae: 0.0261 - val_loss: 0.0025 - val_mae: 0.0259
# Epoch 49/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0024 - mae: 0.0259 - val_loss: 0.0026 - val_mae: 0.0267
# Epoch 50/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0024 - mae: 0.0255 - val_loss: 0.0025 - val_mae: 0.0255
# Epoch 51/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0023 - mae: 0.0251 - val_loss: 0.0025 - val_mae: 0.0260
# Epoch 52/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0023 - mae: 0.0250 - val_loss: 0.0025 - val_mae: 0.0257
# Epoch 53/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0023 - mae: 0.0247 - val_loss: 0.0024 - val_mae: 0.0247
# Epoch 54/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0022 - mae: 0.0245 - val_loss: 0.0024 - val_mae: 0.0254
# Epoch 55/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 0.0022 - mae: 0.0244 - val_loss: 0.0023 - val_mae: 0.0245
# Epoch 56/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 0.0021 - mae: 0.0238 - val_loss: 0.0023 - val_mae: 0.0241
# Epoch 57/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0021 - mae: 0.0235 - val_loss: 0.0022 - val_mae: 0.0244
# Epoch 58/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0021 - mae: 0.0235 - val_loss: 0.0022 - val_mae: 0.0244
# Epoch 59/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0020 - mae: 0.0231 - val_loss: 0.0024 - val_mae: 0.0249
# Epoch 60/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 0.0020 - mae: 0.0234 - val_loss: 0.0021 - val_mae: 0.0223
# Epoch 61/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 0.0020 - mae: 0.0229 - val_loss: 0.0022 - val_mae: 0.0239
# Epoch 62/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0019 - mae: 0.0226 - val_loss: 0.0020 - val_mae: 0.0225
# Epoch 63/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0019 - mae: 0.0224 - val_loss: 0.0020 - val_mae: 0.0227
# Epoch 64/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0019 - mae: 0.0223 - val_loss: 0.0020 - val_mae: 0.0223
# Epoch 65/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0019 - mae: 0.0221 - val_loss: 0.0020 - val_mae: 0.0221
# Epoch 66/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 0.0019 - mae: 0.0219 - val_loss: 0.0022 - val_mae: 0.0243
# Epoch 67/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0018 - mae: 0.0218 - val_loss: 0.0019 - val_mae: 0.0215
# Epoch 68/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 0.0018 - mae: 0.0214 - val_loss: 0.0018 - val_mae: 0.0207
# Epoch 69/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0017 - mae: 0.0211 - val_loss: 0.0019 - val_mae: 0.0213
# Epoch 70/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0017 - mae: 0.0210 - val_loss: 0.0018 - val_mae: 0.0212
# Epoch 71/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0017 - mae: 0.0208 - val_loss: 0.0020 - val_mae: 0.0236
# Epoch 72/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0017 - mae: 0.0209 - val_loss: 0.0018 - val_mae: 0.0213
# Epoch 73/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0017 - mae: 0.0206 - val_loss: 0.0017 - val_mae: 0.0205
# Epoch 74/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 0.0016 - mae: 0.0204 - val_loss: 0.0018 - val_mae: 0.0210
# Epoch 75/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0016 - mae: 0.0204 - val_loss: 0.0018 - val_mae: 0.0199
# Epoch 76/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0016 - mae: 0.0203 - val_loss: 0.0018 - val_mae: 0.0214
# Epoch 77/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0016 - mae: 0.0201 - val_loss: 0.0017 - val_mae: 0.0208
# Epoch 78/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0016 - mae: 0.0198 - val_loss: 0.0017 - val_mae: 0.0199
# Epoch 79/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 0.0016 - mae: 0.0198 - val_loss: 0.0016 - val_mae: 0.0194
# Epoch 80/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0016 - mae: 0.0196 - val_loss: 0.0016 - val_mae: 0.0196
# Epoch 81/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0015 - mae: 0.0195 - val_loss: 0.0016 - val_mae: 0.0200
# Epoch 82/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0015 - mae: 0.0192 - val_loss: 0.0016 - val_mae: 0.0194
# Epoch 83/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0015 - mae: 0.0196 - val_loss: 0.0016 - val_mae: 0.0186
# Epoch 84/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 0.0015 - mae: 0.0191 - val_loss: 0.0015 - val_mae: 0.0188
# Epoch 85/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0015 - mae: 0.0191 - val_loss: 0.0016 - val_mae: 0.0194
# Epoch 86/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0014 - mae: 0.0189 - val_loss: 0.0015 - val_mae: 0.0183
# Epoch 87/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0015 - mae: 0.0192 - val_loss: 0.0015 - val_mae: 0.0189
# Epoch 88/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0014 - mae: 0.0186 - val_loss: 0.0017 - val_mae: 0.0213
# Epoch 89/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0014 - mae: 0.0185 - val_loss: 0.0015 - val_mae: 0.0186
# Epoch 90/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 0.0014 - mae: 0.0184 - val_loss: 0.0015 - val_mae: 0.0183
# Epoch 91/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0014 - mae: 0.0185 - val_loss: 0.0016 - val_mae: 0.0199
# Epoch 92/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0014 - mae: 0.0184 - val_loss: 0.0015 - val_mae: 0.0184
# Epoch 93/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0014 - mae: 0.0183 - val_loss: 0.0014 - val_mae: 0.0178
# Epoch 94/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 0.0013 - mae: 0.0181 - val_loss: 0.0014 - val_mae: 0.0175
# Epoch 95/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 0.0013 - mae: 0.0181 - val_loss: 0.0014 - val_mae: 0.0175
# Epoch 96/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 0.0013 - mae: 0.0182 - val_loss: 0.0014 - val_mae: 0.0184
# Epoch 97/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 0.0013 - mae: 0.0178 - val_loss: 0.0014 - val_mae: 0.0179
# Epoch 98/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0013 - mae: 0.0179 - val_loss: 0.0014 - val_mae: 0.0177
# Epoch 99/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0013 - mae: 0.0179 - val_loss: 0.0014 - val_mae: 0.0181
# Epoch 100/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0013 - mae: 0.0177 - val_loss: 0.0014 - val_mae: 0.0169
# Epoch 101/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0012 - mae: 0.0174 - val_loss: 0.0013 - val_mae: 0.0170
# Epoch 102/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 0.0012 - mae: 0.0174 - val_loss: 0.0014 - val_mae: 0.0178
# Epoch 103/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0013 - mae: 0.0176 - val_loss: 0.0015 - val_mae: 0.0187
# Epoch 104/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0013 - mae: 0.0174 - val_loss: 0.0014 - val_mae: 0.0180
# Epoch 105/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0012 - mae: 0.0172 - val_loss: 0.0013 - val_mae: 0.0173
# Epoch 106/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0012 - mae: 0.0170 - val_loss: 0.0013 - val_mae: 0.0172
# Epoch 107/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0012 - mae: 0.0173 - val_loss: 0.0013 - val_mae: 0.0176
# Epoch 108/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0012 - mae: 0.0172 - val_loss: 0.0013 - val_mae: 0.0171
# Epoch 109/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 0.0012 - mae: 0.0168 - val_loss: 0.0013 - val_mae: 0.0170
# Epoch 110/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0012 - mae: 0.0169 - val_loss: 0.0013 - val_mae: 0.0165
# Epoch 111/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 0.0012 - mae: 0.0169 - val_loss: 0.0013 - val_mae: 0.0168
# Epoch 112/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0012 - mae: 0.0167 - val_loss: 0.0013 - val_mae: 0.0168
# Epoch 113/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0011 - mae: 0.0166 - val_loss: 0.0014 - val_mae: 0.0181
# Epoch 114/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0012 - mae: 0.0169 - val_loss: 0.0014 - val_mae: 0.0177
# Epoch 115/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0011 - mae: 0.0166 - val_loss: 0.0012 - val_mae: 0.0163
# Epoch 116/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 0.0011 - mae: 0.0166 - val_loss: 0.0012 - val_mae: 0.0160
# Epoch 117/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0011 - mae: 0.0163 - val_loss: 0.0013 - val_mae: 0.0171
# Epoch 118/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0011 - mae: 0.0164 - val_loss: 0.0012 - val_mae: 0.0161
# Epoch 119/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 0.0011 - mae: 0.0164 - val_loss: 0.0013 - val_mae: 0.0174
# Epoch 120/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0011 - mae: 0.0162 - val_loss: 0.0012 - val_mae: 0.0163
# Epoch 121/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0011 - mae: 0.0163 - val_loss: 0.0012 - val_mae: 0.0160
# Epoch 122/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0011 - mae: 0.0164 - val_loss: 0.0012 - val_mae: 0.0161
# Epoch 123/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0011 - mae: 0.0160 - val_loss: 0.0012 - val_mae: 0.0164
# Epoch 124/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0011 - mae: 0.0160 - val_loss: 0.0012 - val_mae: 0.0165
# Epoch 125/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0011 - mae: 0.0159 - val_loss: 0.0012 - val_mae: 0.0156
# Epoch 126/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0011 - mae: 0.0160 - val_loss: 0.0012 - val_mae: 0.0158
# Epoch 127/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0010 - mae: 0.0158 - val_loss: 0.0013 - val_mae: 0.0172
# Epoch 128/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0010 - mae: 0.0158 - val_loss: 0.0012 - val_mae: 0.0169
# Epoch 129/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 0.0011 - mae: 0.0160 - val_loss: 0.0012 - val_mae: 0.0159
# Epoch 130/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0010 - mae: 0.0158 - val_loss: 0.0012 - val_mae: 0.0165
# Epoch 131/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0010 - mae: 0.0155 - val_loss: 0.0011 - val_mae: 0.0154
# Epoch 132/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0010 - mae: 0.0158 - val_loss: 0.0012 - val_mae: 0.0163
# Epoch 133/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0010 - mae: 0.0156 - val_loss: 0.0011 - val_mae: 0.0155
# Epoch 134/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0010 - mae: 0.0156 - val_loss: 0.0012 - val_mae: 0.0168
# Epoch 135/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0010 - mae: 0.0155 - val_loss: 0.0011 - val_mae: 0.0147
# Epoch 136/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 9.9136e-04 - mae: 0.0154 - val_loss: 0.0011 - val_mae: 0.0153
# Epoch 137/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0010 - mae: 0.0157 - val_loss: 0.0011 - val_mae: 0.0159
# Epoch 138/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 9.7627e-04 - mae: 0.0153 - val_loss: 0.0011 - val_mae: 0.0154
# Epoch 139/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 9.7929e-04 - mae: 0.0153 - val_loss: 0.0011 - val_mae: 0.0149
# Epoch 140/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 9.7850e-04 - mae: 0.0154 - val_loss: 0.0011 - val_mae: 0.0156
# Epoch 141/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 9.5941e-04 - mae: 0.0152 - val_loss: 0.0011 - val_mae: 0.0163
# Epoch 142/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 9.4946e-04 - mae: 0.0151 - val_loss: 0.0011 - val_mae: 0.0149
# Epoch 143/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 9.5159e-04 - mae: 0.0151 - val_loss: 0.0012 - val_mae: 0.0153
# Epoch 144/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 9.7444e-04 - mae: 0.0154 - val_loss: 0.0010 - val_mae: 0.0142
# Epoch 145/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 9.4366e-04 - mae: 0.0150 - val_loss: 0.0011 - val_mae: 0.0150
# Epoch 146/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 9.4038e-04 - mae: 0.0151 - val_loss: 0.0011 - val_mae: 0.0152
# Epoch 147/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 9.4152e-04 - mae: 0.0150 - val_loss: 0.0010 - val_mae: 0.0143
# Epoch 148/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 9.2772e-04 - mae: 0.0149 - val_loss: 0.0011 - val_mae: 0.0152
# Epoch 149/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0010 - mae: 0.0157 - val_loss: 0.0010 - val_mae: 0.0145
# Epoch 150/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 9.1709e-04 - mae: 0.0148 - val_loss: 0.0011 - val_mae: 0.0155
# Epoch 151/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 9.5671e-04 - mae: 0.0152 - val_loss: 0.0010 - val_mae: 0.0152
# Epoch 152/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 9.1982e-04 - mae: 0.0149 - val_loss: 0.0010 - val_mae: 0.0148
# Epoch 153/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 8.9455e-04 - mae: 0.0146 - val_loss: 0.0011 - val_mae: 0.0156
# Epoch 154/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 9.1255e-04 - mae: 0.0149 - val_loss: 0.0010 - val_mae: 0.0146
# Epoch 155/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 9.0019e-04 - mae: 0.0147 - val_loss: 0.0010 - val_mae: 0.0148
# Epoch 156/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 9.2719e-04 - mae: 0.0151 - val_loss: 0.0010 - val_mae: 0.0144
# Epoch 157/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 8.9033e-04 - mae: 0.0146 - val_loss: 0.0010 - val_mae: 0.0147
# Epoch 158/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 8.8838e-04 - mae: 0.0146 - val_loss: 0.0010 - val_mae: 0.0144
# Epoch 159/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 8.9650e-04 - mae: 0.0147 - val_loss: 0.0011 - val_mae: 0.0158
# Epoch 160/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 9.0554e-04 - mae: 0.0148 - val_loss: 0.0010 - val_mae: 0.0146
# Epoch 161/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 9.0283e-04 - mae: 0.0147 - val_loss: 0.0010 - val_mae: 0.0146
# Epoch 162/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 8.9966e-04 - mae: 0.0147 - val_loss: 0.0011 - val_mae: 0.0160
# Epoch 163/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 8.6194e-04 - mae: 0.0144 - val_loss: 0.0010 - val_mae: 0.0157
# Epoch 164/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 8.6472e-04 - mae: 0.0144 - val_loss: 0.0010 - val_mae: 0.0144
# Epoch 165/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 8.6117e-04 - mae: 0.0144 - val_loss: 0.0010 - val_mae: 0.0157
# Epoch 166/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 8.6864e-04 - mae: 0.0145 - val_loss: 0.0010 - val_mae: 0.0150
# Epoch 167/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 8.7475e-04 - mae: 0.0145 - val_loss: 9.8750e-04 - val_mae: 0.0145
# Epoch 168/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 8.4817e-04 - mae: 0.0143 - val_loss: 9.4930e-04 - val_mae: 0.0138
# Epoch 169/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 8.5587e-04 - mae: 0.0144 - val_loss: 0.0010 - val_mae: 0.0149
# Epoch 170/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 9.1451e-04 - mae: 0.0150 - val_loss: 9.7549e-04 - val_mae: 0.0145
# Epoch 171/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 8.6169e-04 - mae: 0.0144 - val_loss: 9.4173e-04 - val_mae: 0.0138
# Epoch 172/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 8.5086e-04 - mae: 0.0143 - val_loss: 9.5040e-04 - val_mae: 0.0139
# Epoch 173/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 8.3861e-04 - mae: 0.0142 - val_loss: 9.9725e-04 - val_mae: 0.0149
# Epoch 174/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 8.3664e-04 - mae: 0.0142 - val_loss: 9.2179e-04 - val_mae: 0.0136
# Epoch 175/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 8.4502e-04 - mae: 0.0143 - val_loss: 0.0010 - val_mae: 0.0146
# Epoch 176/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 8.3479e-04 - mae: 0.0141 - val_loss: 9.9817e-04 - val_mae: 0.0149
# Epoch 177/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 8.3750e-04 - mae: 0.0142 - val_loss: 9.6599e-04 - val_mae: 0.0143
# Epoch 178/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 8.5814e-04 - mae: 0.0144 - val_loss: 9.4666e-04 - val_mae: 0.0136
# Epoch 179/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 8.2240e-04 - mae: 0.0140 - val_loss: 9.9625e-04 - val_mae: 0.0145
# Epoch 180/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 8.4880e-04 - mae: 0.0142 - val_loss: 9.5135e-04 - val_mae: 0.0140
# Epoch 181/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 8.4837e-04 - mae: 0.0144 - val_loss: 9.2018e-04 - val_mae: 0.0133
# Epoch 182/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 8.0600e-04 - mae: 0.0139 - val_loss: 9.3092e-04 - val_mae: 0.0142
# Epoch 183/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 8.1182e-04 - mae: 0.0141 - val_loss: 0.0010 - val_mae: 0.0160
# Epoch 184/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 8.1058e-04 - mae: 0.0140 - val_loss: 9.6652e-04 - val_mae: 0.0141
# Epoch 185/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 8.0562e-04 - mae: 0.0139 - val_loss: 8.8010e-04 - val_mae: 0.0132
# Epoch 186/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 8.0025e-04 - mae: 0.0139 - val_loss: 9.3703e-04 - val_mae: 0.0141
# Epoch 187/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 7.9887e-04 - mae: 0.0139 - val_loss: 9.2637e-04 - val_mae: 0.0136
# Epoch 188/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 8.0280e-04 - mae: 0.0139 - val_loss: 9.2139e-04 - val_mae: 0.0139
# Epoch 189/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 8.0054e-04 - mae: 0.0139 - val_loss: 9.5175e-04 - val_mae: 0.0146
# Epoch 190/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 8.0600e-04 - mae: 0.0140 - val_loss: 9.8934e-04 - val_mae: 0.0146
# Epoch 191/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 8.0935e-04 - mae: 0.0140 - val_loss: 0.0010 - val_mae: 0.0155
# Epoch 192/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 8.0136e-04 - mae: 0.0139 - val_loss: 9.0663e-04 - val_mae: 0.0136
# Epoch 193/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 7.8541e-04 - mae: 0.0138 - val_loss: 9.2590e-04 - val_mae: 0.0135
# Epoch 194/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 7.8360e-04 - mae: 0.0138 - val_loss: 0.0010 - val_mae: 0.0156
# Epoch 195/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 7.8287e-04 - mae: 0.0137 - val_loss: 8.9026e-04 - val_mae: 0.0132
# Epoch 196/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 8.0063e-04 - mae: 0.0139 - val_loss: 9.3607e-04 - val_mae: 0.0143
# Epoch 197/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 7.8597e-04 - mae: 0.0138 - val_loss: 9.2235e-04 - val_mae: 0.0145
# Epoch 198/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 7.6341e-04 - mae: 0.0136 - val_loss: 8.6856e-04 - val_mae: 0.0128
# Epoch 199/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 7.8298e-04 - mae: 0.0138 - val_loss: 9.2543e-04 - val_mae: 0.0140
# Epoch 200/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 7.6194e-04 - mae: 0.0136 - val_loss: 8.7715e-04 - val_mae: 0.0137
# Epoch 201/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 7.7226e-04 - mae: 0.0137 - val_loss: 9.4031e-04 - val_mae: 0.0147
# Epoch 202/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 7.8705e-04 - mae: 0.0140 - val_loss: 9.7812e-04 - val_mae: 0.0146
# Epoch 203/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 8.0168e-04 - mae: 0.0139 - val_loss: 9.2749e-04 - val_mae: 0.0145
# Epoch 204/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 7.6009e-04 - mae: 0.0136 - val_loss: 9.4589e-04 - val_mae: 0.0138
# Epoch 205/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 7.6085e-04 - mae: 0.0137 - val_loss: 9.3030e-04 - val_mae: 0.0149
# Epoch 206/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 7.7031e-04 - mae: 0.0137 - val_loss: 8.6887e-04 - val_mae: 0.0130
# Epoch 207/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 7.5615e-04 - mae: 0.0135 - val_loss: 9.0739e-04 - val_mae: 0.0138
# Epoch 208/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 7.7432e-04 - mae: 0.0138 - val_loss: 9.1695e-04 - val_mae: 0.0134
# Epoch 209/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 7.5467e-04 - mae: 0.0135 - val_loss: 8.7577e-04 - val_mae: 0.0133
# Epoch 210/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 7.4325e-04 - mae: 0.0134 - val_loss: 9.3964e-04 - val_mae: 0.0145
# Epoch 211/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 7.9400e-04 - mae: 0.0140 - val_loss: 9.5233e-04 - val_mae: 0.0143
# Epoch 212/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 7.4772e-04 - mae: 0.0134 - val_loss: 8.4519e-04 - val_mae: 0.0129
# Epoch 213/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 7.4075e-04 - mae: 0.0134 - val_loss: 8.3376e-04 - val_mae: 0.0129
# Epoch 214/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 7.4879e-04 - mae: 0.0135 - val_loss: 8.3631e-04 - val_mae: 0.0131
# Epoch 215/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 7.4494e-04 - mae: 0.0135 - val_loss: 8.5085e-04 - val_mae: 0.0133
# Epoch 216/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 7.4866e-04 - mae: 0.0135 - val_loss: 9.4008e-04 - val_mae: 0.0142
# Epoch 217/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 7.3442e-04 - mae: 0.0134 - val_loss: 8.8010e-04 - val_mae: 0.0143
# Epoch 218/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 7.2687e-04 - mae: 0.0132 - val_loss: 8.5394e-04 - val_mae: 0.0134
# Epoch 219/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 7.3729e-04 - mae: 0.0134 - val_loss: 8.3169e-04 - val_mae: 0.0129
# Epoch 220/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 7.2655e-04 - mae: 0.0133 - val_loss: 8.2955e-04 - val_mae: 0.0130
# Epoch 221/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 8.0273e-04 - mae: 0.0141 - val_loss: 8.9843e-04 - val_mae: 0.0137
# Epoch 222/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 7.3263e-04 - mae: 0.0134 - val_loss: 9.0149e-04 - val_mae: 0.0145
# Epoch 223/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 7.4425e-04 - mae: 0.0135 - val_loss: 9.7115e-04 - val_mae: 0.0154
# Epoch 224/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 7.4664e-04 - mae: 0.0135 - val_loss: 8.4885e-04 - val_mae: 0.0131
# Epoch 225/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 8.5093e-04 - mae: 0.0145 - val_loss: 8.7847e-04 - val_mae: 0.0132
# Epoch 226/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 7.3011e-04 - mae: 0.0132 - val_loss: 8.3992e-04 - val_mae: 0.0131
# Epoch 227/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 7.1042e-04 - mae: 0.0132 - val_loss: 8.2495e-04 - val_mae: 0.0125
# Epoch 228/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 7.1130e-04 - mae: 0.0131 - val_loss: 8.9284e-04 - val_mae: 0.0135
# Epoch 229/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 7.1738e-04 - mae: 0.0132 - val_loss: 8.8861e-04 - val_mae: 0.0142
# Epoch 230/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 7.1001e-04 - mae: 0.0131 - val_loss: 8.1878e-04 - val_mae: 0.0130
# Epoch 231/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 7.0111e-04 - mae: 0.0131 - val_loss: 8.7601e-04 - val_mae: 0.0142
# Epoch 232/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 7.0995e-04 - mae: 0.0132 - val_loss: 8.3945e-04 - val_mae: 0.0134
# Epoch 233/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 7.2215e-04 - mae: 0.0133 - val_loss: 8.6610e-04 - val_mae: 0.0133
# Epoch 234/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 7.2280e-04 - mae: 0.0133 - val_loss: 8.4139e-04 - val_mae: 0.0133
# Epoch 235/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.9622e-04 - mae: 0.0130 - val_loss: 8.2355e-04 - val_mae: 0.0131
# Epoch 236/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.9406e-04 - mae: 0.0130 - val_loss: 8.8706e-04 - val_mae: 0.0138
# Epoch 237/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 7.0156e-04 - mae: 0.0131 - val_loss: 8.3419e-04 - val_mae: 0.0131
# Epoch 238/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 7.0341e-04 - mae: 0.0131 - val_loss: 8.9203e-04 - val_mae: 0.0141
# Epoch 239/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 7.0035e-04 - mae: 0.0131 - val_loss: 8.5810e-04 - val_mae: 0.0135
# Epoch 240/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 7.0066e-04 - mae: 0.0131 - val_loss: 8.1421e-04 - val_mae: 0.0129
# Epoch 241/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.9965e-04 - mae: 0.0131 - val_loss: 8.2782e-04 - val_mae: 0.0129
# Epoch 242/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.8139e-04 - mae: 0.0129 - val_loss: 7.9304e-04 - val_mae: 0.0125
# Epoch 243/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.9066e-04 - mae: 0.0130 - val_loss: 8.2367e-04 - val_mae: 0.0134
# Epoch 244/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.8188e-04 - mae: 0.0129 - val_loss: 8.7705e-04 - val_mae: 0.0135
# Epoch 245/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.9114e-04 - mae: 0.0130 - val_loss: 8.2144e-04 - val_mae: 0.0132
# Epoch 246/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 6.8217e-04 - mae: 0.0130 - val_loss: 8.2183e-04 - val_mae: 0.0131
# Epoch 247/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 6.8477e-04 - mae: 0.0129 - val_loss: 8.4638e-04 - val_mae: 0.0130
# Epoch 248/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 6.8254e-04 - mae: 0.0129 - val_loss: 8.6700e-04 - val_mae: 0.0138
# Epoch 249/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 6.7438e-04 - mae: 0.0128 - val_loss: 7.9795e-04 - val_mae: 0.0125
# Epoch 250/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.8055e-04 - mae: 0.0129 - val_loss: 7.8293e-04 - val_mae: 0.0125
# Epoch 251/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.9102e-04 - mae: 0.0131 - val_loss: 8.9291e-04 - val_mae: 0.0144
# Epoch 252/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.7170e-04 - mae: 0.0129 - val_loss: 8.1609e-04 - val_mae: 0.0126
# Epoch 253/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 7.1179e-04 - mae: 0.0132 - val_loss: 7.9778e-04 - val_mae: 0.0132
# Epoch 254/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.6002e-04 - mae: 0.0127 - val_loss: 8.1081e-04 - val_mae: 0.0130
# Epoch 255/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 6.7187e-04 - mae: 0.0128 - val_loss: 8.3203e-04 - val_mae: 0.0131
# Epoch 256/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 6.6849e-04 - mae: 0.0128 - val_loss: 7.9840e-04 - val_mae: 0.0129
# Epoch 257/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.5989e-04 - mae: 0.0127 - val_loss: 8.4868e-04 - val_mae: 0.0133
# Epoch 258/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.8420e-04 - mae: 0.0129 - val_loss: 8.1606e-04 - val_mae: 0.0126
# Epoch 259/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 7.4493e-04 - mae: 0.0135 - val_loss: 8.1052e-04 - val_mae: 0.0130
# Epoch 260/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.6032e-04 - mae: 0.0126 - val_loss: 8.4561e-04 - val_mae: 0.0127
# Epoch 261/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.5740e-04 - mae: 0.0127 - val_loss: 7.9005e-04 - val_mae: 0.0131
# Epoch 262/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.5382e-04 - mae: 0.0127 - val_loss: 7.8662e-04 - val_mae: 0.0125
# Epoch 263/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.5781e-04 - mae: 0.0126 - val_loss: 7.7464e-04 - val_mae: 0.0123
# Epoch 264/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.5695e-04 - mae: 0.0127 - val_loss: 7.8520e-04 - val_mae: 0.0126
# Epoch 265/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.5660e-04 - mae: 0.0127 - val_loss: 8.2008e-04 - val_mae: 0.0135
# Epoch 266/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.7449e-04 - mae: 0.0129 - val_loss: 0.0011 - val_mae: 0.0153
# Epoch 267/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 6.8951e-04 - mae: 0.0131 - val_loss: 8.1651e-04 - val_mae: 0.0122
# Epoch 268/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.3944e-04 - mae: 0.0125 - val_loss: 8.0904e-04 - val_mae: 0.0130
# Epoch 269/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.4591e-04 - mae: 0.0126 - val_loss: 7.6387e-04 - val_mae: 0.0121
# Epoch 270/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.3973e-04 - mae: 0.0125 - val_loss: 7.9417e-04 - val_mae: 0.0125
# Epoch 271/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.4688e-04 - mae: 0.0127 - val_loss: 8.1707e-04 - val_mae: 0.0126
# Epoch 272/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.4937e-04 - mae: 0.0126 - val_loss: 8.2755e-04 - val_mae: 0.0132
# Epoch 273/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 6.4249e-04 - mae: 0.0126 - val_loss: 7.9633e-04 - val_mae: 0.0126
# Epoch 274/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.4751e-04 - mae: 0.0127 - val_loss: 8.7889e-04 - val_mae: 0.0138
# Epoch 275/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.5049e-04 - mae: 0.0127 - val_loss: 7.7496e-04 - val_mae: 0.0122
# Epoch 276/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 6.4473e-04 - mae: 0.0126 - val_loss: 7.7339e-04 - val_mae: 0.0126
# Epoch 277/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.6314e-04 - mae: 0.0128 - val_loss: 8.1842e-04 - val_mae: 0.0129
# Epoch 278/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.4625e-04 - mae: 0.0126 - val_loss: 7.7829e-04 - val_mae: 0.0123
# Epoch 279/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.2121e-04 - mae: 0.0124 - val_loss: 7.7764e-04 - val_mae: 0.0125
# Epoch 280/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.4201e-04 - mae: 0.0125 - val_loss: 8.4434e-04 - val_mae: 0.0131
# Epoch 281/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.2744e-04 - mae: 0.0124 - val_loss: 7.4432e-04 - val_mae: 0.0123
# Epoch 282/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.6016e-04 - mae: 0.0128 - val_loss: 7.8413e-04 - val_mae: 0.0126
# Epoch 283/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.2727e-04 - mae: 0.0124 - val_loss: 7.8470e-04 - val_mae: 0.0126
# Epoch 284/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 6.2496e-04 - mae: 0.0125 - val_loss: 7.9656e-04 - val_mae: 0.0129
# Epoch 285/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.5455e-04 - mae: 0.0127 - val_loss: 8.7082e-04 - val_mae: 0.0139
# Epoch 286/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.5370e-04 - mae: 0.0127 - val_loss: 8.7964e-04 - val_mae: 0.0131
# Epoch 287/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 6.2574e-04 - mae: 0.0124 - val_loss: 7.7344e-04 - val_mae: 0.0128
# Epoch 288/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 6.4703e-04 - mae: 0.0127 - val_loss: 8.1522e-04 - val_mae: 0.0125
# Epoch 289/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 6.3625e-04 - mae: 0.0125 - val_loss: 8.3489e-04 - val_mae: 0.0139
# Epoch 290/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.2096e-04 - mae: 0.0123 - val_loss: 7.4170e-04 - val_mae: 0.0118
# Epoch 291/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.0948e-04 - mae: 0.0122 - val_loss: 7.5885e-04 - val_mae: 0.0123
# Epoch 292/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 6.2872e-04 - mae: 0.0125 - val_loss: 8.0807e-04 - val_mae: 0.0126
# Epoch 293/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.2537e-04 - mae: 0.0124 - val_loss: 8.7939e-04 - val_mae: 0.0142
# Epoch 294/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.1440e-04 - mae: 0.0124 - val_loss: 7.5017e-04 - val_mae: 0.0122
# Epoch 295/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.4434e-04 - mae: 0.0126 - val_loss: 8.5424e-04 - val_mae: 0.0135
# Epoch 296/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.3808e-04 - mae: 0.0126 - val_loss: 7.7857e-04 - val_mae: 0.0122
# Epoch 297/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 6.3241e-04 - mae: 0.0125 - val_loss: 7.5197e-04 - val_mae: 0.0124
# Epoch 298/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.3516e-04 - mae: 0.0125 - val_loss: 7.4155e-04 - val_mae: 0.0118
# Epoch 299/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.0253e-04 - mae: 0.0122 - val_loss: 7.6394e-04 - val_mae: 0.0123
# Epoch 300/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.1172e-04 - mae: 0.0122 - val_loss: 7.8583e-04 - val_mae: 0.0135
# Epoch 301/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 6.1388e-04 - mae: 0.0123 - val_loss: 7.4217e-04 - val_mae: 0.0118
# Epoch 302/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 6.2846e-04 - mae: 0.0125 - val_loss: 7.5392e-04 - val_mae: 0.0123
# Epoch 303/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 6.0004e-04 - mae: 0.0121 - val_loss: 7.5269e-04 - val_mae: 0.0118
# Epoch 304/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 6.1025e-04 - mae: 0.0123 - val_loss: 8.0821e-04 - val_mae: 0.0126
# Epoch 305/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 6.2780e-04 - mae: 0.0125 - val_loss: 7.6753e-04 - val_mae: 0.0123
# Epoch 306/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 5.9508e-04 - mae: 0.0121 - val_loss: 7.6921e-04 - val_mae: 0.0127
# Epoch 307/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.0816e-04 - mae: 0.0123 - val_loss: 7.2763e-04 - val_mae: 0.0124
# Epoch 308/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 6.1693e-04 - mae: 0.0124 - val_loss: 8.5297e-04 - val_mae: 0.0131
# Epoch 309/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.2082e-04 - mae: 0.0125 - val_loss: 7.2644e-04 - val_mae: 0.0118
# Epoch 310/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 6.0067e-04 - mae: 0.0122 - val_loss: 7.4937e-04 - val_mae: 0.0126
# Epoch 311/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.0640e-04 - mae: 0.0122 - val_loss: 7.5743e-04 - val_mae: 0.0126
# Epoch 312/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.0237e-04 - mae: 0.0122 - val_loss: 7.3289e-04 - val_mae: 0.0115
# Epoch 313/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 5.9043e-04 - mae: 0.0120 - val_loss: 7.8945e-04 - val_mae: 0.0129
# Epoch 314/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.0076e-04 - mae: 0.0123 - val_loss: 7.5817e-04 - val_mae: 0.0127
# Epoch 315/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.1560e-04 - mae: 0.0124 - val_loss: 7.7081e-04 - val_mae: 0.0132
# Epoch 316/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.0653e-04 - mae: 0.0122 - val_loss: 7.4203e-04 - val_mae: 0.0122
# Epoch 317/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 5.9096e-04 - mae: 0.0121 - val_loss: 7.2529e-04 - val_mae: 0.0117
# Epoch 318/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 5.8641e-04 - mae: 0.0120 - val_loss: 7.3701e-04 - val_mae: 0.0121
# Epoch 319/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.2918e-04 - mae: 0.0125 - val_loss: 7.7031e-04 - val_mae: 0.0129
# Epoch 320/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 5.7999e-04 - mae: 0.0120 - val_loss: 7.4055e-04 - val_mae: 0.0121
# Epoch 321/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 5.9954e-04 - mae: 0.0123 - val_loss: 7.5417e-04 - val_mae: 0.0119
# Epoch 322/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 5.7853e-04 - mae: 0.0119 - val_loss: 7.7942e-04 - val_mae: 0.0128
# Epoch 323/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 5.8788e-04 - mae: 0.0121 - val_loss: 7.5492e-04 - val_mae: 0.0124
# Epoch 324/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.1703e-04 - mae: 0.0123 - val_loss: 7.5816e-04 - val_mae: 0.0122
# Epoch 325/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 5.7916e-04 - mae: 0.0120 - val_loss: 7.3375e-04 - val_mae: 0.0118
# Epoch 326/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 5.9008e-04 - mae: 0.0121 - val_loss: 8.4153e-04 - val_mae: 0.0134
# Epoch 327/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.5389e-04 - mae: 0.0130 - val_loss: 7.5265e-04 - val_mae: 0.0121
# Epoch 328/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 5.9500e-04 - mae: 0.0122 - val_loss: 8.4623e-04 - val_mae: 0.0144
# Epoch 329/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 6.3504e-04 - mae: 0.0127 - val_loss: 7.5476e-04 - val_mae: 0.0126
# Epoch 330/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 5.8810e-04 - mae: 0.0121 - val_loss: 7.4711e-04 - val_mae: 0.0124
# Epoch 331/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 5.6673e-04 - mae: 0.0119 - val_loss: 7.4941e-04 - val_mae: 0.0122
# Epoch 332/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 5.7509e-04 - mae: 0.0120 - val_loss: 7.5576e-04 - val_mae: 0.0127
# Epoch 333/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 6.1119e-04 - mae: 0.0124 - val_loss: 8.0916e-04 - val_mae: 0.0128
# Epoch 334/1000
# ...
# 672/672 [==============================] - 6s 9ms/step - loss: 3.7938e-04 - mae: 0.0100 - val_loss: 5.6951e-04 - val_mae: 0.0104
# Epoch 891/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 4.8537e-04 - mae: 0.0107 - val_loss: 5.6985e-04 - val_mae: 0.0104
# Epoch 892/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.7470e-04 - mae: 0.0098 - val_loss: 5.3169e-04 - val_mae: 0.0100
# Epoch 893/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.6064e-04 - mae: 0.0097 - val_loss: 5.2522e-04 - val_mae: 0.0094
# Epoch 894/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.4877e-04 - mae: 0.0096 - val_loss: 5.4189e-04 - val_mae: 0.0095
# Epoch 895/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 3.5375e-04 - mae: 0.0096 - val_loss: 5.3467e-04 - val_mae: 0.0098
# Epoch 896/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.4979e-04 - mae: 0.0097 - val_loss: 5.1791e-04 - val_mae: 0.0096
# Epoch 897/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 3.8280e-04 - mae: 0.0100 - val_loss: 5.0989e-04 - val_mae: 0.0092
# Epoch 898/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.5915e-04 - mae: 0.0097 - val_loss: 5.8096e-04 - val_mae: 0.0103
# Epoch 899/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.5698e-04 - mae: 0.0097 - val_loss: 5.4321e-04 - val_mae: 0.0089
# Epoch 900/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.8562e-04 - mae: 0.0099 - val_loss: 5.1148e-04 - val_mae: 0.0095
# Epoch 901/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.5253e-04 - mae: 0.0096 - val_loss: 5.4499e-04 - val_mae: 0.0103
# Epoch 902/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 3.5502e-04 - mae: 0.0097 - val_loss: 5.3455e-04 - val_mae: 0.0104
# Epoch 903/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.8656e-04 - mae: 0.0100 - val_loss: 5.6041e-04 - val_mae: 0.0099
# Epoch 904/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.6233e-04 - mae: 0.0097 - val_loss: 5.4210e-04 - val_mae: 0.0103
# Epoch 905/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.6640e-04 - mae: 0.0098 - val_loss: 5.2959e-04 - val_mae: 0.0100
# Epoch 906/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.5904e-04 - mae: 0.0098 - val_loss: 5.9540e-04 - val_mae: 0.0112
# Epoch 907/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.9295e-04 - mae: 0.0102 - val_loss: 5.2704e-04 - val_mae: 0.0098
# Epoch 908/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 3.5069e-04 - mae: 0.0096 - val_loss: 5.1381e-04 - val_mae: 0.0093
# Epoch 909/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 3.4998e-04 - mae: 0.0097 - val_loss: 5.4542e-04 - val_mae: 0.0099
# Epoch 910/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.6039e-04 - mae: 0.0097 - val_loss: 5.2744e-04 - val_mae: 0.0096
# Epoch 911/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 3.5986e-04 - mae: 0.0098 - val_loss: 5.4358e-04 - val_mae: 0.0102
# Epoch 912/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 3.6596e-04 - mae: 0.0098 - val_loss: 5.6149e-04 - val_mae: 0.0099
# Epoch 913/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 3.5933e-04 - mae: 0.0097 - val_loss: 5.5932e-04 - val_mae: 0.0106
# Epoch 914/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.8438e-04 - mae: 0.0099 - val_loss: 8.0620e-04 - val_mae: 0.0147
# Epoch 915/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 4.3951e-04 - mae: 0.0107 - val_loss: 5.0099e-04 - val_mae: 0.0090
# Epoch 916/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.4775e-04 - mae: 0.0095 - val_loss: 5.4819e-04 - val_mae: 0.0099
# Epoch 917/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.5200e-04 - mae: 0.0096 - val_loss: 5.3160e-04 - val_mae: 0.0097
# Epoch 918/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.4378e-04 - mae: 0.0095 - val_loss: 5.1662e-04 - val_mae: 0.0094
# Epoch 919/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.6471e-04 - mae: 0.0098 - val_loss: 5.6254e-04 - val_mae: 0.0108
# Epoch 920/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.6491e-04 - mae: 0.0097 - val_loss: 5.6294e-04 - val_mae: 0.0098
# Epoch 921/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.9074e-04 - mae: 0.0101 - val_loss: 5.6571e-04 - val_mae: 0.0105
# Epoch 922/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 3.4063e-04 - mae: 0.0095 - val_loss: 5.3587e-04 - val_mae: 0.0099
# Epoch 923/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 3.5749e-04 - mae: 0.0097 - val_loss: 5.8041e-04 - val_mae: 0.0108
# Epoch 924/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.7428e-04 - mae: 0.0099 - val_loss: 5.2287e-04 - val_mae: 0.0095
# Epoch 925/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 3.5607e-04 - mae: 0.0096 - val_loss: 5.3552e-04 - val_mae: 0.0101
# Epoch 926/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.7445e-04 - mae: 0.0099 - val_loss: 5.1332e-04 - val_mae: 0.0095
# Epoch 927/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.4922e-04 - mae: 0.0096 - val_loss: 5.6832e-04 - val_mae: 0.0105
# Epoch 928/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.9582e-04 - mae: 0.0102 - val_loss: 5.2735e-04 - val_mae: 0.0098
# Epoch 929/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 3.5392e-04 - mae: 0.0096 - val_loss: 5.3304e-04 - val_mae: 0.0100
# Epoch 930/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.4936e-04 - mae: 0.0095 - val_loss: 5.1644e-04 - val_mae: 0.0097
# Epoch 931/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.4964e-04 - mae: 0.0096 - val_loss: 5.1612e-04 - val_mae: 0.0093
# Epoch 932/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 3.5560e-04 - mae: 0.0096 - val_loss: 6.0467e-04 - val_mae: 0.0111
# Epoch 933/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.5655e-04 - mae: 0.0097 - val_loss: 5.2315e-04 - val_mae: 0.0093
# Epoch 934/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.4606e-04 - mae: 0.0095 - val_loss: 5.7069e-04 - val_mae: 0.0101
# Epoch 935/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.4838e-04 - mae: 0.0096 - val_loss: 5.6096e-04 - val_mae: 0.0106
# Epoch 936/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.5398e-04 - mae: 0.0096 - val_loss: 5.4220e-04 - val_mae: 0.0107
# Epoch 937/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.4744e-04 - mae: 0.0095 - val_loss: 5.4430e-04 - val_mae: 0.0103
# Epoch 938/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 3.6374e-04 - mae: 0.0098 - val_loss: 5.7433e-04 - val_mae: 0.0106
# Epoch 939/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 3.8528e-04 - mae: 0.0100 - val_loss: 5.5422e-04 - val_mae: 0.0109
# Epoch 940/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.5020e-04 - mae: 0.0095 - val_loss: 5.0732e-04 - val_mae: 0.0092
# Epoch 941/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.5046e-04 - mae: 0.0096 - val_loss: 5.2368e-04 - val_mae: 0.0100
# Epoch 942/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.6849e-04 - mae: 0.0099 - val_loss: 5.6758e-04 - val_mae: 0.0106
# Epoch 943/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.5997e-04 - mae: 0.0098 - val_loss: 6.2888e-04 - val_mae: 0.0109
# Epoch 944/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.5949e-04 - mae: 0.0098 - val_loss: 4.9520e-04 - val_mae: 0.0089
# Epoch 945/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.4589e-04 - mae: 0.0095 - val_loss: 5.2759e-04 - val_mae: 0.0103
# Epoch 946/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 3.4876e-04 - mae: 0.0096 - val_loss: 4.9723e-04 - val_mae: 0.0092
# Epoch 947/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.4427e-04 - mae: 0.0095 - val_loss: 5.9510e-04 - val_mae: 0.0120
# Epoch 948/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.5595e-04 - mae: 0.0096 - val_loss: 5.7220e-04 - val_mae: 0.0109
# Epoch 949/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.9809e-04 - mae: 0.0102 - val_loss: 5.5759e-04 - val_mae: 0.0103
# Epoch 950/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.6719e-04 - mae: 0.0097 - val_loss: 5.9086e-04 - val_mae: 0.0103
# Epoch 951/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.6346e-04 - mae: 0.0097 - val_loss: 4.9089e-04 - val_mae: 0.0091
# Epoch 952/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 3.3995e-04 - mae: 0.0095 - val_loss: 5.4693e-04 - val_mae: 0.0107
# Epoch 953/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 4.2546e-04 - mae: 0.0103 - val_loss: 7.1730e-04 - val_mae: 0.0125
# Epoch 954/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 4.3707e-04 - mae: 0.0104 - val_loss: 5.6545e-04 - val_mae: 0.0104
# Epoch 955/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.8884e-04 - mae: 0.0100 - val_loss: 5.3295e-04 - val_mae: 0.0098
# Epoch 956/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.4711e-04 - mae: 0.0095 - val_loss: 5.3667e-04 - val_mae: 0.0101
# Epoch 957/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.4121e-04 - mae: 0.0095 - val_loss: 5.1388e-04 - val_mae: 0.0092
# Epoch 958/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.5916e-04 - mae: 0.0097 - val_loss: 5.0629e-04 - val_mae: 0.0094
# Epoch 959/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 4.2328e-04 - mae: 0.0105 - val_loss: 5.2421e-04 - val_mae: 0.0097
# Epoch 960/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.6562e-04 - mae: 0.0097 - val_loss: 5.5605e-04 - val_mae: 0.0099
# Epoch 961/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.3843e-04 - mae: 0.0094 - val_loss: 5.1321e-04 - val_mae: 0.0097
# Epoch 962/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.8161e-04 - mae: 0.0099 - val_loss: 5.3892e-04 - val_mae: 0.0103
# Epoch 963/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.5248e-04 - mae: 0.0097 - val_loss: 5.5228e-04 - val_mae: 0.0100
# Epoch 964/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 3.5023e-04 - mae: 0.0095 - val_loss: 5.1410e-04 - val_mae: 0.0096
# Epoch 965/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.3622e-04 - mae: 0.0094 - val_loss: 5.1098e-04 - val_mae: 0.0097
# Epoch 966/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.5022e-04 - mae: 0.0096 - val_loss: 5.0804e-04 - val_mae: 0.0095
# Epoch 967/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.5122e-04 - mae: 0.0096 - val_loss: 5.4958e-04 - val_mae: 0.0098
# Epoch 968/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 3.4661e-04 - mae: 0.0096 - val_loss: 5.8604e-04 - val_mae: 0.0115
# Epoch 969/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 3.5251e-04 - mae: 0.0096 - val_loss: 5.1454e-04 - val_mae: 0.0095
# Epoch 970/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.5468e-04 - mae: 0.0097 - val_loss: 5.8386e-04 - val_mae: 0.0104
# Epoch 971/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.4793e-04 - mae: 0.0095 - val_loss: 5.4218e-04 - val_mae: 0.0104
# Epoch 972/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.4413e-04 - mae: 0.0095 - val_loss: 5.3234e-04 - val_mae: 0.0093
# Epoch 973/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.7394e-04 - mae: 0.0099 - val_loss: 5.4445e-04 - val_mae: 0.0098
# Epoch 974/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 3.7264e-04 - mae: 0.0097 - val_loss: 5.2306e-04 - val_mae: 0.0097
# Epoch 975/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.4966e-04 - mae: 0.0096 - val_loss: 5.1728e-04 - val_mae: 0.0095
# Epoch 976/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.6748e-04 - mae: 0.0098 - val_loss: 5.8217e-04 - val_mae: 0.0112
# Epoch 977/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 3.5742e-04 - mae: 0.0097 - val_loss: 5.2557e-04 - val_mae: 0.0098
# Epoch 978/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 3.7205e-04 - mae: 0.0098 - val_loss: 5.0983e-04 - val_mae: 0.0094
# Epoch 979/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.4681e-04 - mae: 0.0095 - val_loss: 4.8371e-04 - val_mae: 0.0088
# Epoch 980/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.3557e-04 - mae: 0.0094 - val_loss: 5.0065e-04 - val_mae: 0.0093
# Epoch 981/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.4167e-04 - mae: 0.0096 - val_loss: 5.7474e-04 - val_mae: 0.0110
# Epoch 982/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 3.4740e-04 - mae: 0.0095 - val_loss: 5.7169e-04 - val_mae: 0.0103
# Epoch 983/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.6565e-04 - mae: 0.0099 - val_loss: 5.4053e-04 - val_mae: 0.0097
# Epoch 984/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.6496e-04 - mae: 0.0097 - val_loss: 5.3011e-04 - val_mae: 0.0100
# Epoch 985/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 3.5446e-04 - mae: 0.0097 - val_loss: 5.1891e-04 - val_mae: 0.0094
# Epoch 986/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.3568e-04 - mae: 0.0094 - val_loss: 5.1092e-04 - val_mae: 0.0097
# Epoch 987/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.5025e-04 - mae: 0.0096 - val_loss: 5.3498e-04 - val_mae: 0.0098
# Epoch 988/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.5708e-04 - mae: 0.0097 - val_loss: 5.0443e-04 - val_mae: 0.0094
# Epoch 989/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.4009e-04 - mae: 0.0094 - val_loss: 5.2292e-04 - val_mae: 0.0091
# Epoch 990/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.3958e-04 - mae: 0.0094 - val_loss: 5.3983e-04 - val_mae: 0.0100
# Epoch 991/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.5852e-04 - mae: 0.0098 - val_loss: 5.8341e-04 - val_mae: 0.0111
# Epoch 992/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.6521e-04 - mae: 0.0097 - val_loss: 6.5793e-04 - val_mae: 0.0099
# Epoch 993/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 0.0014 - mae: 0.0138 - val_loss: 7.1256e-04 - val_mae: 0.0119
# Epoch 994/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 4.7129e-04 - mae: 0.0107 - val_loss: 5.9723e-04 - val_mae: 0.0103
# Epoch 995/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 4.0765e-04 - mae: 0.0101 - val_loss: 5.5429e-04 - val_mae: 0.0099
# Epoch 996/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.7224e-04 - mae: 0.0097 - val_loss: 5.5337e-04 - val_mae: 0.0106
# Epoch 997/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.5374e-04 - mae: 0.0096 - val_loss: 5.2869e-04 - val_mae: 0.0097
# Epoch 998/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.4687e-04 - mae: 0.0095 - val_loss: 5.3637e-04 - val_mae: 0.0102
# Epoch 999/1000
# 672/672 [==============================] - 6s 9ms/step - loss: 3.4151e-04 - mae: 0.0095 - val_loss: 5.2480e-04 - val_mae: 0.0101
# Epoch 1000/1000
# 672/672 [==============================] - 6s 8ms/step - loss: 3.7315e-04 - mae: 0.0099 - val_loss: 5.2790e-04 - val_mae: 0.0102
# ✅ Modelo FF NN listo para usar.

# %%
# !ls -lh ff_nn_Best_Model.h5 ff_nn_best_history.json
# Out:
# -rw-rw---- 1 wsuser wscommon  88K Jul 20 18:16 ff_nn_best_history.json
# -rw-rw---- 1 wsuser wscommon 608K Jul 20 18:14 ff_nn_Best_Model.h5

# %%
from IPython.display import FileLink

# Crear enlaces para descarga
FileLink('ff_nn_Best_Model.h5')
# Out:
# /home/wsuser/work/ff_nn_Best_Model.h5

# %%
FileLink('ff_nn_best_history.json')
# Out:
# /home/wsuser/work/ff_nn_best_history.json

# %%
#import os
#os.remove("ff_nn_Best_Model.h5")
#os.remove("ff_nn_best_history.json")

# %%
accuracy_test_NN = FF_NN_network.evaluate(X_test_FF, y_test_FF)
# Out:
# 3750/3750 [==============================] - 17s 5ms/step - loss: 5.5201e-04 - mae: 0.0103

# %%
predictions_NN = FF_NN_network.predict(X_test_FF)
# Out:
# 3750/3750 [==============================] - 12s 3ms/step

# %%
y_test_FF[0]
# Out:
# array([-1.41566256, -0.47920488, -1.20153633,  1.50982546,  0.79871603,
#         1.60489404])

# %% [markdown]
# # Verificación de métricas y validación con nuevo dataset

# %% [markdown]
# # Verificación con Dataset Lineal
