# %%
import numpy as np
import scipy as sp
import sympy as smp
import matplotlib.pyplot as plt
import pandas as pd #Lo necesito para cargar y leer el csv
import tensorflow as tf
import os
import random
import time
import math
import keras 
import json
from datetime import datetime

#import tensorflow
from tensorflow import keras
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from tensorflow.keras.layers import Dense, LSTM, BatchNormalization, Dropout, InputLayer
from tensorflow.keras.models import Sequential #
from sklearn.model_selection import train_test_split
from keras.regularizers import l2, l1, l1_l2
from sklearn.utils import shuffle
import pandas as pd
from scipy.signal import savgol_filter
from scipy.interpolate import CubicSpline
from scipy.ndimage import gaussian_filter1d
#from keras_tuner import RandomSearch
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
# Out:
# 2025-07-22 11:42:48.312235: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-07-22 11:42:48.312258: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-07-22 11:42:48.312263: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
import tensorflow as tf
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available: 2

# %%
tf.keras.backend.set_floatx('float64')

# %% [markdown]
# # **Filtro Discreto para agregar aceleraciones**
# De acuerdo con el paper *Identification of robot forward dynamics via neural network*:
#
# “The corresponding joint accelerations were retrieved through the application of an appropriate discrete filter to the joint velocities just collected.”
#
# Entonces, se tomarán dos datos “de más” (muestra 0 y muestra 101) para permitir aplicar el filtro discreto a las n-2 muestras y tener información de velocidad. Se podrán estudiar otras técnicas para derivar las aceleraciones a partir de las velocidades.

# %%
# Definir una función para calcular las aceleraciones utilizando un filtro de diferencia finita
def calcular_aceleraciones(velocidades, h):
    aceleraciones = []
    for i in range(1, len(velocidades) -1 ):
        # Aplicar el filtro de diferencia finita para calcular la aceleración
        #aceleracion = (velocidades[i + 1] - 2 * velocidades[i] + velocidades[i - 1]) #->Esto no seria la segunda derivada?
        aceleracion = (velocidades[i + 1] -  velocidades[i - 1])/(2*h)
        aceleraciones.append(aceleracion)
    return np.array(aceleraciones)

# Definir una función para calcular las aceleraciones utilizando un filtro de diferencia finita
def calcular_aceleraciones_2(velocidades, h):
    aceleraciones = []
    for i in range(1, len(velocidades) - 4 ):
        # Aplicar el filtro de diferencia finita para calcular la aceleración
        aceleracion = (- velocidades[i + 2] +  8*velocidades[i + 1] - 8*velocidades[i - 2] + velocidades[i - 1]) /(12*h)
        aceleraciones.append(aceleracion)
    return np.array(aceleraciones)



import os, types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.

cos_client = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='1eFnNpgSMiDaf_Yx-ZXteaGaokoLTfIKQXajc1kbdepo',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/identity/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.direct.us-south.cloud-object-storage.appdomain.cloud')

bucket = 'irb140-donotdelete-pr-sdzbp1zcz7qnal'
object_key = 'Output_linear_002_test_NN_NN.csv'

body = cos_client.get_object(Bucket=bucket,Key=object_key)['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_1 = pd.read_csv(body)
df_1.head(10)



def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.

cos_client = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='1eFnNpgSMiDaf_Yx-ZXteaGaokoLTfIKQXajc1kbdepo',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/identity/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.direct.us-south.cloud-object-storage.appdomain.cloud')

bucket = 'irb140-donotdelete-pr-sdzbp1zcz7qnal'
object_key = 'Output_NN_NN_merged_2.csv'

body = cos_client.get_object(Bucket=bucket,Key=object_key)['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_2 = pd.read_csv(body)
df_2.head(10)





def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.

cos_client = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='1eFnNpgSMiDaf_Yx-ZXteaGaokoLTfIKQXajc1kbdepo',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/identity/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.direct.us-south.cloud-object-storage.appdomain.cloud')

bucket = 'irb140-donotdelete-pr-sdzbp1zcz7qnal'
object_key = 'Output_NN_NN_merged.csv'

body = cos_client.get_object(Bucket=bucket,Key=object_key)['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_3 = pd.read_csv(body)
df_3.head(10)



def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.

cos_client = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='1eFnNpgSMiDaf_Yx-ZXteaGaokoLTfIKQXajc1kbdepo',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/identity/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.direct.us-south.cloud-object-storage.appdomain.cloud')

bucket = 'irb140-donotdelete-pr-sdzbp1zcz7qnal'
object_key = 'Output_NN_NN_4e6_fixed.csv'

body = cos_client.get_object(Bucket=bucket,Key=object_key)['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_4 = pd.read_csv(body)
df_4.head(10)



def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.

cos_client = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='1eFnNpgSMiDaf_Yx-ZXteaGaokoLTfIKQXajc1kbdepo',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/identity/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.direct.us-south.cloud-object-storage.appdomain.cloud')

bucket = 'irb140-donotdelete-pr-sdzbp1zcz7qnal'
object_key = 'Output_NN_NN_1.csv'

body = cos_client.get_object(Bucket=bucket,Key=object_key)['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_5 = pd.read_csv(body)
df_5.head(10)



def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.

cos_client = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='1eFnNpgSMiDaf_Yx-ZXteaGaokoLTfIKQXajc1kbdepo',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/identity/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.direct.us-south.cloud-object-storage.appdomain.cloud')

bucket = 'irb140-donotdelete-pr-sdzbp1zcz7qnal'
object_key = 'Output_NN_NN_CUT_MERGED.csv'

body = cos_client.get_object(Bucket=bucket,Key=object_key)['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_6 = pd.read_csv(body)
df_6.head(10)




def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.

cos_client = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='1eFnNpgSMiDaf_Yx-ZXteaGaokoLTfIKQXajc1kbdepo',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/identity/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.direct.us-south.cloud-object-storage.appdomain.cloud')

bucket = 'irb140-donotdelete-pr-sdzbp1zcz7qnal'
object_key = 'Output_linear_NN_NN.csv'

body = cos_client.get_object(Bucket=bucket,Key=object_key)['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_7 = pd.read_csv(body)
df_7.head(10)
# Out:
#    start_time   random_ID   end_time   random_V   random_Z   pos_j1   pos_j2  \
# 0        0.01           1       0.01    44.3387    13.3286  38.8691  56.8166
# 1        0.02           1       0.02    44.3387    13.3286  38.8691  56.8166
# 2        0.03           1       0.03    44.3387    13.3286  38.8692  56.8166
# 3        0.04           1       0.04    44.3387    13.3286  38.8699  56.8153
# 4        0.05           1       0.05    44.3387    13.3286  38.8714  56.8120
# 5        0.06           1       0.06    44.3387    13.3286  38.8763  56.7989
# 6        0.07           1       0.07    44.3387    13.3286  38.8817  56.7832
# 7        0.08           1       0.08    44.3387    13.3286  38.8929  56.7504
# 8        0.09           1       0.09    44.3387    13.3286  38.9018  56.7246
# 9        0.10           1       0.10    44.3387    13.3286  38.9163  56.6832
#
#     pos_j3   pos_j4   pos_j5  ...        vel_j3        vel_j4        vel_j5  \
# 0 -44.4538  27.1509  77.9901  ... -7.966630e-07  6.367170e-07  1.104570e-06
# 1 -44.4538  27.1509  77.9901  ... -2.476310e-07  1.979140e-07  3.433390e-07
# 2 -44.4537  27.1509  77.9901  ...  3.026870e-02  4.242320e-03  2.885760e-03
# 3 -44.4507  27.1520  77.9909  ...  5.273590e-01  2.336480e-01  1.593350e-01
# 4 -44.4418  27.1564  77.9938  ...  1.585330e+00  7.950580e-01  5.422220e-01
# 5 -44.4053  27.1760  78.0072  ...  4.291600e+00  2.351820e+00  1.603630e+00
# 6 -44.3611  27.2004  78.0239  ...  6.281490e+00  3.492510e+00  2.380870e+00
# 7 -44.2693  27.2516  78.0587  ...  8.464700e+00  4.705810e+00  3.206830e+00
# 8 -44.1971  27.2916  78.0860  ...  9.247770e+00  5.125500e+00  3.492240e+00
# 9 -44.0811  27.3558  78.1297  ...  9.772430e+00  5.406370e+00  3.683100e+00
#
#          vel_j6    torq_j1   torq_j2    torq_j3   torq_j4   torq_j5   torq_j6
# 0  1.654760e-06   0.000081  -102.576 -20.845600  0.074018  0.003685  0.000014
# 1  5.143560e-07   0.000025  -102.576 -20.845500  0.074011  0.003668  0.000000
# 2 -3.938810e-03   2.260020  -103.952 -19.350800  0.492498  0.581197 -0.202456
# 3 -2.190560e-01  11.834500  -111.350 -11.681700  2.834510  4.505330 -1.883060
# 4 -7.461850e-01  16.103400  -116.560  -6.329820  3.748950  6.033220 -2.586040
# 5 -2.208290e+00  18.597000  -122.413  -0.557024  4.770580  7.714690 -3.344290
# 6 -3.278950e+00  18.280300  -124.063  -0.119863  5.282180  8.566820 -3.707570
# 7 -4.416410e+00  17.220700  -124.072  -1.504390  5.758580  9.368880 -4.036480
# 8 -4.809320e+00  16.861400  -123.960  -2.147740  5.917320  9.636010 -4.145240
# 9 -5.072010e+00  16.645000  -123.820  -2.589730  6.023040  9.813340 -4.217430
#
# [10 rows x 23 columns]

# %%
import numpy as np

# Variables y configuraciones
num_variables = 6
time_interval = 0.05

datos_IRB_140 = {
    'datos_IRB_140_Output_linear_NN_NN': df_7,
    'datos_IRB_140_Output_NN_NN_merged': df_5,
    'datos_IRB_140_Output_NN_NN_New_2': df_3
}

tcps_vels = {}
tcps_accus = {}

j_poses = {}
j_vels = {}
j_accels = {}
j_torqs = {}
times = {}

# Nombres de los archivos base usados como etiquetas
files = ['Output_linear_NN_NN', 'Output_NN_NN_merged', 'Output_NN_NN_New_2']
datos_IRB_140_st = 'datos_IRB_140_'

tcp_vel = 'rand_v'
tcp_accu = 'rand_z'

j_pos = 'pos_j'
j_vel = 'vel_j'
j_accel = 'acc_j'
j_torq = 'torq_j'

def calcular_aceleraciones(vels, dt):
    """Calcula aceleración usando esquema de diferencias finitas centradas de 5 puntos."""
    acc = np.zeros_like(vels)
    n = len(vels)
    for i in range(2, n - 2):
        acc[i] = (-vels[i + 2] + 8 * vels[i + 1] - 8 * vels[i - 1] + vels[i - 2]) / (12 * dt)
    return acc

# Procesamiento de los dataframes
for file in files:
    print(file)
    variable_name = datos_IRB_140_st + file
    df = datos_IRB_140[variable_name]

    # Tiempo
    time_var = f"{file}_time"
    times[time_var] = df.iloc[:, 0].values

    # Velocidades y aceleraciones TCP
    tcps_vels_name = f"{file}_{tcp_vel}"
    tcps_vels[tcps_vels_name] = df.iloc[1:-1, 3].values

    tcps_accus_name = f"{file}_{tcp_accu}"
    tcps_accus[tcps_accus_name] = df.iloc[1:-1, 4].values

    # Articulaciones
    for i in range(1, num_variables + 1):
        # Posición articular (en radianes)
        pos_j_name = f"{file}_{j_pos}{i}"
        j_poses[pos_j_name] = df.iloc[:, 4 + i].values *(np.pi/180.0)

        # Velocidad articular (en radianes/s)
        vel_j_name = f"{file}_{j_vel}{i}"
        j_vels[vel_j_name] = df.iloc[:, 10 + i].values *(np.pi/180.0)

        # Torque articular
        torq_j_name = f"{file}_{j_torq}{i}"
        j_torqs[torq_j_name] = df.iloc[:, 16 + i].values

        # Torque articular: calcular max y normalizar inmediatamente
        #torq_j_name = f"{file}_{j_torq}{i}"
        #raw_torque = df.iloc[:, 16 + i].values

        #max_torque = np.max(np.abs(raw_torque))
        #if max_torque == 0:
        #    print(f"⚠️ Torque máximo en {file} eje {i} es 0. Se dejará sin normalizar.")
        #    normalized_torque = raw_torque
        #else:
        #    normalized_torque = raw_torque / max_torque

        #j_torqs[torq_j_name] = normalized_torque

        # Aceleración articular (calculada numéricamente)
        acc_j_name = f"{file}_{j_accel}{i}"
        j_accels[acc_j_name] = calcular_aceleraciones(j_vels[vel_j_name], time_interval) *(np.pi/180.0)
# Out:
# Output_linear_NN_NN
# Output_NN_NN_merged
# Output_NN_NN_New_2

# %%
tcps_vels['Output_NN_NN_merged_rand_v']#[2:-2]
tcps_accus['Output_NN_NN_merged_rand_z']#[2:-2]

j_poses['Output_NN_NN_merged_pos_j1']#[2:-2]
j_poses['Output_NN_NN_merged_pos_j2']#[2:-2]
j_poses['Output_NN_NN_merged_pos_j3']#[2:-2]
j_poses['Output_NN_NN_merged_pos_j4']#[2:-2]
j_poses['Output_NN_NN_merged_pos_j5']#[2:-2]
j_poses['Output_NN_NN_merged_pos_j6']#[2:-2]

j_vels['Output_NN_NN_merged_vel_j1']#[2:-2]
j_vels['Output_NN_NN_merged_vel_j2']#[2:-2]
j_vels['Output_NN_NN_merged_vel_j3']#[2:-2]
j_vels['Output_NN_NN_merged_vel_j4']#[2:-2]
j_vels['Output_NN_NN_merged_vel_j5']#[2:-2]
j_vels['Output_NN_NN_merged_vel_j6']#[2:-2]

j_torqs['Output_NN_NN_merged_torq_j1']#[2:-2]
j_torqs['Output_NN_NN_merged_torq_j2']#[2:-2]
j_torqs['Output_NN_NN_merged_torq_j3']#[2:-2]
j_torqs['Output_NN_NN_merged_torq_j4']#[2:-2]
j_torqs['Output_NN_NN_merged_torq_j5']#[2:-2]
j_torqs['Output_NN_NN_merged_torq_j6']#[2:-2]

j_accels['Output_NN_NN_merged_acc_j1']#[2:-2]
j_accels['Output_NN_NN_merged_acc_j2']#[2:-2]
j_accels['Output_NN_NN_merged_acc_j3']#[2:-2]
j_accels['Output_NN_NN_merged_acc_j4']#[2:-2]
j_accels['Output_NN_NN_merged_acc_j5']#[2:-2]
j_accels['Output_NN_NN_merged_acc_j6']#[2:-2]
# Out:
# array([0.00000000e+00, 0.00000000e+00, 1.46989582e-04, ...,
#        1.00269901e-06, 0.00000000e+00, 0.00000000e+00])

# %%
tcps_vels['Output_linear_NN_NN_rand_v']#[2:-2]
tcps_accus['Output_linear_NN_NN_rand_z']#[2:-2]

j_poses['Output_linear_NN_NN_pos_j1']#[2:-2]
j_poses['Output_linear_NN_NN_pos_j2']#[2:-2]
j_poses['Output_linear_NN_NN_pos_j3']#[2:-2]
j_poses['Output_linear_NN_NN_pos_j4']#[2:-2]
j_poses['Output_linear_NN_NN_pos_j5']#[2:-2]
j_poses['Output_linear_NN_NN_pos_j6']#[2:-2]

j_vels['Output_linear_NN_NN_vel_j1']#[2:-2]
j_vels['Output_linear_NN_NN_vel_j2']#[2:-2]
j_vels['Output_linear_NN_NN_vel_j3']#[2:-2]
j_vels['Output_linear_NN_NN_vel_j4']#[2:-2]
j_vels['Output_linear_NN_NN_vel_j5']#[2:-2]
j_vels['Output_linear_NN_NN_vel_j6']#[2:-2]

j_torqs['Output_linear_NN_NN_torq_j1']#[2:-2]
j_torqs['Output_linear_NN_NN_torq_j2']#[2:-2]
j_torqs['Output_linear_NN_NN_torq_j3']#[2:-2]
j_torqs['Output_linear_NN_NN_torq_j4']#[2:-2]
j_torqs['Output_linear_NN_NN_torq_j5']#[2:-2]
j_torqs['Output_linear_NN_NN_torq_j6']#[2:-2]

j_accels['Output_linear_NN_NN_acc_j1']#[2:-2]
j_accels['Output_linear_NN_NN_acc_j2']#[2:-2]
j_accels['Output_linear_NN_NN_acc_j3']#[2:-2]
j_accels['Output_linear_NN_NN_acc_j4']#[2:-2]
j_accels['Output_linear_NN_NN_acc_j5']#[2:-2]
j_accels['Output_linear_NN_NN_acc_j6']#[2:-2]
# Out:
# array([ 0.00000000e+00,  0.00000000e+00, -5.10876647e-04, ...,
#        -3.22950787e-18,  0.00000000e+00,  0.00000000e+00])

# %%
print(j_poses['Output_NN_NN_merged_pos_j6'].shape)
print(j_accels['Output_NN_NN_merged_acc_j6'].shape)
# Out:
# (299999,)
# (299999,)

# %%
print(j_accels['Output_NN_NN_merged_acc_j6'][2:-2].shape)
# Out:
# (299995,)

# %%
pos_j1 = np.concatenate([j_poses['Output_NN_NN_merged_pos_j1'][2:-2],j_poses['Output_linear_NN_NN_pos_j1'][2:-2]])
pos_j2 = np.concatenate([j_poses['Output_NN_NN_merged_pos_j2'][2:-2],j_poses['Output_linear_NN_NN_pos_j2'][2:-2]])
pos_j3 = np.concatenate([j_poses['Output_NN_NN_merged_pos_j3'][2:-2],j_poses['Output_linear_NN_NN_pos_j3'][2:-2]])
pos_j4 = np.concatenate([j_poses['Output_NN_NN_merged_pos_j4'][2:-2],j_poses['Output_linear_NN_NN_pos_j4'][2:-2]])
pos_j5 = np.concatenate([j_poses['Output_NN_NN_merged_pos_j5'][2:-2],j_poses['Output_linear_NN_NN_pos_j5'][2:-2]])
pos_j6 = np.concatenate([j_poses['Output_NN_NN_merged_pos_j6'][2:-2],j_poses['Output_linear_NN_NN_pos_j6'][2:-2]])

vels_j1 = np.concatenate([j_vels['Output_NN_NN_merged_vel_j1'][2:-2],j_vels['Output_linear_NN_NN_vel_j1'][2:-2]])
vels_j2 = np.concatenate([j_vels['Output_NN_NN_merged_vel_j2'][2:-2],j_vels['Output_linear_NN_NN_vel_j2'][2:-2]])
vels_j3 = np.concatenate([j_vels['Output_NN_NN_merged_vel_j3'][2:-2],j_vels['Output_linear_NN_NN_vel_j3'][2:-2]])
vels_j4 = np.concatenate([j_vels['Output_NN_NN_merged_vel_j4'][2:-2],j_vels['Output_linear_NN_NN_vel_j4'][2:-2]])
vels_j5 = np.concatenate([j_vels['Output_NN_NN_merged_vel_j5'][2:-2],j_vels['Output_linear_NN_NN_vel_j5'][2:-2]])
vels_j6 = np.concatenate([j_vels['Output_NN_NN_merged_vel_j6'][2:-2],j_vels['Output_linear_NN_NN_vel_j6'][2:-2]])

torq_j1 = np.concatenate([j_torqs['Output_NN_NN_merged_torq_j1'][2:-2],j_torqs['Output_linear_NN_NN_torq_j1'][2:-2]])
torq_j2 = np.concatenate([j_torqs['Output_NN_NN_merged_torq_j2'][2:-2],j_torqs['Output_linear_NN_NN_torq_j2'][2:-2]])
torq_j3 = np.concatenate([j_torqs['Output_NN_NN_merged_torq_j3'][2:-2],j_torqs['Output_linear_NN_NN_torq_j3'][2:-2]])
torq_j4 = np.concatenate([j_torqs['Output_NN_NN_merged_torq_j4'][2:-2],j_torqs['Output_linear_NN_NN_torq_j4'][2:-2]])
torq_j5 = np.concatenate([j_torqs['Output_NN_NN_merged_torq_j5'][2:-2],j_torqs['Output_linear_NN_NN_torq_j5'][2:-2]])
torq_j6 = np.concatenate([j_torqs['Output_NN_NN_merged_torq_j6'][2:-2],j_torqs['Output_linear_NN_NN_torq_j6'][2:-2]])

accs_j1 = np.concatenate([j_accels['Output_NN_NN_merged_acc_j1'][2:-2],j_accels['Output_linear_NN_NN_acc_j1'][2:-2]])
accs_j2 = np.concatenate([j_accels['Output_NN_NN_merged_acc_j2'][2:-2],j_accels['Output_linear_NN_NN_acc_j2'][2:-2]])
accs_j3 = np.concatenate([j_accels['Output_NN_NN_merged_acc_j3'][2:-2],j_accels['Output_linear_NN_NN_acc_j3'][2:-2]])
accs_j4 = np.concatenate([j_accels['Output_NN_NN_merged_acc_j4'][2:-2],j_accels['Output_linear_NN_NN_acc_j4'][2:-2]])
accs_j5 = np.concatenate([j_accels['Output_NN_NN_merged_acc_j5'][2:-2],j_accels['Output_linear_NN_NN_acc_j5'][2:-2]])
accs_j6 = np.concatenate([j_accels['Output_NN_NN_merged_acc_j6'][2:-2],j_accels['Output_linear_NN_NN_acc_j6'][2:-2]])

# %%
#Los dos primeros y los dos ultimos puntos no tienen informacion de aceleración, ya que la misma usa cuatro puntos para reconsruirse
#time_joint= times['Output_NN_NN_merged_time'][2:-2]

#pos_j1 = j_poses['Output_NN_NN_merged_pos_j1'][2:-2]  #34440 -> 34438, k
#pos_j2 = j_poses['Output_NN_NN_merged_pos_j2'][2:-2]
#pos_j3 = j_poses['Output_NN_NN_merged_pos_j3'][2:-2]
#pos_j4 = j_poses['Output_NN_NN_merged_pos_j4'][2:-2]
#pos_j5 = j_poses['Output_NN_NN_merged_pos_j5'][2:-2]
#pos_j6 = j_poses['Output_NN_NN_merged_pos_j6'][2:-2]

#vels_j1 = j_vels['Output_NN_NN_merged_vel_j1'][2:-2]  #34440 -> 34438 k
#vels_j2 = j_vels['Output_NN_NN_merged_vel_j2'][2:-2]
#vels_j3 = j_vels['Output_NN_NN_merged_vel_j3'][2:-2]
#vels_j4 = j_vels['Output_NN_NN_merged_vel_j4'][2:-2] 
#vels_j5 = j_vels['Output_NN_NN_merged_vel_j5'][2:-2]
#vels_j6 = j_vels['Output_NN_NN_merged_vel_j6'][2:-2]

#torq_j1 = j_torqs['Output_NN_NN_merged_torq_j1'][2:-2] #34440 -> 34438 k
#torq_j2 = j_torqs['Output_NN_NN_merged_torq_j2'][2:-2]
#torq_j3 = j_torqs['Output_NN_NN_merged_torq_j3'][2:-2]
#torq_j4 = j_torqs['Output_NN_NN_merged_torq_j4'][2:-2] 
#torq_j5 = j_torqs['Output_NN_NN_merged_torq_j5'][2:-2]
#torq_j6 = j_torqs['Output_NN_NN_merged_torq_j6'][2:-2]

#accs_j1 = j_accels['Output_NN_NN_merged_acc_j1'][2:-2]  #34438 k
#accs_j2 = j_accels['Output_NN_NN_merged_acc_j2'][2:-2] 
#accs_j3 = j_accels['Output_NN_NN_merged_acc_j3'][2:-2] 
#accs_j4 = j_accels['Output_NN_NN_merged_acc_j4'][2:-2]
#accs_j5 = j_accels['Output_NN_NN_merged_acc_j5'][2:-2]
#accs_j6 = j_accels['Output_NN_NN_merged_acc_j6'][2:-2]

# %% [markdown]
# # **PROBLEMA DINÁMICO INVERSO**

# %%
inputs = np.vstack((pos_j1, pos_j2, pos_j3, pos_j4, pos_j5, pos_j6, vels_j1, vels_j2, vels_j3, vels_j4, vels_j5, vels_j6, accs_j1, accs_j2, accs_j3, accs_j4, accs_j5, accs_j6)).T
outputs = np.vstack((torq_j1, torq_j2, torq_j3, torq_j4, torq_j5, torq_j6)).T

# %% [markdown]
# # Red Feed-Forward

# %%
X_train_FF, X_test_FF, y_train_FF, y_test_FF = train_test_split(inputs, outputs, test_size = 0.2)

#Tengo que hacer preprocesado de los datos para que los calculos no sean tan pesados
scaler1_FF = StandardScaler() #RobustScaler()#
X_train_FF = scaler1_FF.fit_transform(X_train_FF)#Primero se llama a la funcion fit para que ajuste los datos
X_test_FF = scaler1_FF.transform(X_test_FF) #Una vez que los datos fueron ajustados se puede llamar a la transformacion directamente
#X_val_FF = scaler1_FF.transform(X_val_FF)

#Lo mismo para los outputs
scaler2_FF = StandardScaler() #RobustScaler()#
y_train_FF = scaler2_FF.fit_transform(y_train_FF)
y_test_FF = scaler2_FF.transform(y_test_FF)
#y_val_FF = scaler2_FF.transform(y_val_FF)

# %%
# Verificar si el modelo ya existe

FF_NN_model_path = "ff_nn_Best_Model.h5"
FF_NN_history_path = "ff_nn_best_history.json"

if os.path.exists(FF_NN_model_path):
    print("🔄 Cargando modelo FF NN existente...")
    FF_SS_network = keras.models.load_model(FF_NN_model_path)
    FF_SS_network.summary()

    if os.path.exists(FF_NN_history_path):
        with open(FF_NN_history_path, "r") as f:
            FF_NN_history = json.load(f)  # Load the history data as a dictionary

        # Create a dummy History object for plotting:
        #FF_NN_history = type('DummyHistory', (object,), {'history': FF_NN_history_dict})()

        # Graficar el history
        plt.figure(figsize=(8, 5))
        plt.plot(FF_NN_history["loss"], label="Training Loss")
        plt.plot(FF_NN_history["val_loss"], label="Validation Loss")
        plt.legend()
        plt.xlabel("Épocas")
        plt.ylabel("Loss")
        plt.grid(True)
        plt.gca().set_ylim(0, 2e-3)
        plt.title("Historial de entrenamiento del modelo FF NN (Dataset Random)")
        plt.show()
    else:
        print("⚠️ No se encontró el archivo de history.")
else:
    print("⚙️ Creando nuevo modelo...")
    #Esta forma es lo más parecida posible al paper
    FF_NN_network = keras.models.Sequential([
        keras.layers.Input(shape=(inputs.shape[1],)),  # Input layer with the shape of the input data
        #keras.layers.LayerNormalization(epsilon=1e-4),
        keras.layers.Dense(100, activation="gelu"),  # First hidden layer with GELU activation
        keras.layers.Dense(100, activation="gelu"),
        #keras.layers.Dense(100, activation="swish"),
        #keras.layers.Dense(200, activation="tanh"),
        keras.layers.Dense(6)
    ])
    FF_NN_network.summary()

    FF_NN_network.compile(loss = 'mean_squared_error', optimizer=keras.optimizers.Adam(learning_rate=5e-4), 
                          metrics = ['mae'])#Que pasa si uso SGD con learning rate

    checkpoint_cb = keras.callbacks.ModelCheckpoint(FF_NN_model_path, 
                                                    save_best_only=True)
    early_stopping_cb = keras.callbacks.EarlyStopping(patience=200, min_delta=1e-10, restore_best_weights=True)

    reduce_lr = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=20, min_lr=1e-8)       
    FF_NN_history = FF_NN_network.fit(X_train_FF, y_train_FF, epochs=1500, 
                                      batch_size=300, validation_split=0.3, shuffle=True, 
                                      callbacks=[checkpoint_cb, early_stopping_cb])

    with open(FF_NN_history_path, "w") as f:
        json.dump(FF_NN_history.history, f)
    with open(FF_NN_history_path, "r") as f:
        FF_NN_history = json.load(f)  # Load the history data as a dictionary

    # Create a dummy History object for plotting:
    #FF_NN_history = type('DummyHistory', (object,), {'history': FF_NN_history_dict})()

    pd.DataFrame(FF_NN_history).plot(figsize=(8, 5))
    plt.grid(True)
    #plt.gca().set_xlim(0, 1)
    plt.gca().set_ylim(0, 2e-3)
    plt.show()

print("✅ Modelo FF NN listo para usar.")
# Out:
# ⚙️ Creando nuevo modelo...
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               1900
#
#  dense_1 (Dense)             (None, 100)               10100
#
#  dense_2 (Dense)             (None, 6)                 606
#
# =================================================================
# Total params: 12606 (98.48 KB)
# Trainable params: 12606 (98.48 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/1500
# 1120/1120 [==============================] - 13s 9ms/step - loss: 0.2390 - mae: 0.4047 - val_loss: 0.1188 - val_mae: 0.2839
# Epoch 2/1500
#   17/1120 [..............................] - ETA: 7s - loss: 0.1187 - mae: 0.2842
# /opt/conda/envs/Python-RT24.1-CUDA/lib/python3.11/site-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0961 - mae: 0.2494 - val_loss: 0.0780 - val_mae: 0.2205
# Epoch 3/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0652 - mae: 0.1985 - val_loss: 0.0547 - val_mae: 0.1793
# Epoch 4/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0469 - mae: 0.1643 - val_loss: 0.0404 - val_mae: 0.1505
# Epoch 5/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0350 - mae: 0.1394 - val_loss: 0.0306 - val_mae: 0.1286
# Epoch 6/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0269 - mae: 0.1200 - val_loss: 0.0243 - val_mae: 0.1122
# Epoch 7/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0216 - mae: 0.1053 - val_loss: 0.0198 - val_mae: 0.0992
# Epoch 8/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0180 - mae: 0.0943 - val_loss: 0.0171 - val_mae: 0.0910
# Epoch 9/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0154 - mae: 0.0857 - val_loss: 0.0147 - val_mae: 0.0821
# Epoch 10/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0135 - mae: 0.0790 - val_loss: 0.0130 - val_mae: 0.0764
# Epoch 11/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.
1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0019 - mae: 0.0227 - val_loss: 0.0019 - val_mae: 0.0224
# Epoch 78/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0018 - mae: 0.0224 - val_loss: 0.0019 - val_mae: 0.0220
# Epoch 79/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0018 - mae: 0.0222 - val_loss: 0.0019 - val_mae: 0.0232
# Epoch 80/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0018 - mae: 0.0222 - val_loss: 0.0018 - val_mae: 0.0213
# Epoch 81/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0018 - mae: 0.0219 - val_loss: 0.0019 - val_mae: 0.0217
# Epoch 82/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0018 - mae: 0.0219 - val_loss: 0.0020 - val_mae: 0.0233
# Epoch 83/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0018 - mae: 0.0220 - val_loss: 0.0019 - val_mae: 0.0217
# Epoch 84/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0017 - mae: 0.0216 - val_loss: 0.0018 - val_mae: 0.0209
# Epoch 85/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0017 - mae: 0.0215 - val_loss: 0.0018 - val_mae: 0.0216
# Epoch 86/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0017 - mae: 0.0214 - val_loss: 0.0022 - val_mae: 0.0250
# Epoch 87/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0017 - mae: 0.0213 - val_loss: 0.0018 - val_mae: 0.0213
# Epoch 88/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0017 - mae: 0.0212 - val_loss: 0.0018 - val_mae: 0.0212
# Epoch 89/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0017 - mae: 0.0212 - val_loss: 0.0018 - val_mae: 0.0218
# Epoch 90/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0017 - mae: 0.0209 - val_loss: 0.0018 - val_mae: 0.0216
# Epoch 91/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0017 - mae: 0.0209 - val_loss: 0.0017 - val_mae: 0.0203
# Epoch 92/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0016 - mae: 0.0208 - val_loss: 0.0017 - val_mae: 0.0201
# Epoch 93/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0016 - mae: 0.0207 - val_loss: 0.0017 - val_mae: 0.0201
# Epoch 94/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0016 - mae: 0.0207 - val_loss: 0.0017 - val_mae: 0.0211
# Epoch 95/1500
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0016 - mae: 0.0206 - val_loss: 0.0017 - val_mae: 0.0207
# Epoch 96/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0016 - mae: 0.0205 - val_loss: 0.0017 - val_mae: 0.0210
# Epoch 97/1500
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0016 - mae: 0.0204 - val_loss: 0.0017 - val_mae: 0.0208
# Epoch 98/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0016 - mae: 0.0204 - val_loss: 0.0017 - val_mae: 0.0212
# Epoch 99/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0016 - mae: 0.0202 - val_loss: 0.0016 - val_mae: 0.0198
# Epoch 100/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0015 - mae: 0.0201 - val_loss: 0.0016 - val_mae: 0.0204
# Epoch 101/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0015 - mae: 0.0202 - val_loss: 0.0018 - val_mae: 0.0224
# Epoch 102/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0015 - mae: 0.0201 - val_loss: 0.0016 - val_mae: 0.0201
# Epoch 103/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0015 - mae: 0.0199 - val_loss: 0.0016 - val_mae: 0.0197
# Epoch 104/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0015 - mae: 0.0200 - val_loss: 0.0015 - val_mae: 0.0192
# Epoch 105/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0015 - mae: 0.0199 - val_loss: 0.0017 - val_mae: 0.0207
# Epoch 106/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0015 - mae: 0.0197 - val_loss: 0.0018 - val_mae: 0.0207
# Epoch 107/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0015 - mae: 0.0197 - val_loss: 0.0017 - val_mae: 0.0211
# Epoch 108/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0015 - mae: 0.0195 - val_loss: 0.0015 - val_mae: 0.0198
# Epoch 109/1500
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0015 - mae: 0.0194 - val_loss: 0.0015 - val_mae: 0.0195
# Epoch 110/1500
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0015 - mae: 0.0196 - val_loss: 0.0015 - val_mae: 0.0200
# Epoch 111/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0015 - mae: 0.0194 - val_loss: 0.0016 - val_mae: 0.0207
# Epoch 112/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0014 - mae: 0.0193 - val_loss: 0.0015 - val_mae: 0.0189
# Epoch 113/1500
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0014 - mae: 0.0193 - val_loss: 0.0016 - val_mae: 0.0209
# Epoch 114/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0014 - mae: 0.0194 - val_loss: 0.0015 - val_mae: 0.0185
# Epoch 115/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0014 - mae: 0.0191 - val_loss: 0.0015 - val_mae: 0.0192
# Epoch 116/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0014 - mae: 0.0190 - val_loss: 0.0015 - val_mae: 0.0188
# Epoch 117/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0014 - mae: 0.0190 - val_loss: 0.0015 - val_mae: 0.0191
# Epoch 118/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0014 - mae: 0.0190 - val_loss: 0.0014 - val_mae: 0.0183
# Epoch 119/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0014 - mae: 0.0193 - val_loss: 0.0014 - val_mae: 0.0182
# Epoch 120/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0014 - mae: 0.0188 - val_loss: 0.0015 - val_mae: 0.0190
# Epoch 121/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0014 - mae: 0.0187 - val_loss: 0.0015 - val_mae: 0.0195
# Epoch 122/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0014 - mae: 0.0187 - val_loss: 0.0014 - val_mae: 0.0184
# Epoch 123/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0014 - mae: 0.0188 - val_loss: 0.0015 - val_mae: 0.0185
# Epoch 124/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0014 - mae: 0.0187 - val_loss: 0.0014 - val_mae: 0.0186
# Epoch 125/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0013 - mae: 0.0186 - val_loss: 0.0014 - val_mae: 0.0185
# Epoch 126/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0013 - mae: 0.0185 - val_loss: 0.0014 - val_mae: 0.0183
# Epoch 127/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0014 - mae: 0.0187 - val_loss: 0.0014 - val_mae: 0.0180
# Epoch 128/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0013 - mae: 0.0184 - val_loss: 0.0014 - val_mae: 0.0178
# Epoch 129/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0013 - mae: 0.0183 - val_loss: 0.0015 - val_mae: 0.0191
# Epoch 130/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0013 - mae: 0.0183 - val_loss: 0.0014 - val_mae: 0.0181
# Epoch 131/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0013 - mae: 0.0184 - val_loss: 0.0014 - val_mae: 0.0182
# Epoch 132/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0013 - mae: 0.0181 - val_loss: 0.0013 - val_mae: 0.0179
# Epoch 133/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0013 - mae: 0.0183 - val_loss: 0.0013 - val_mae: 0.0175
# Epoch 134/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0013 - mae: 0.0181 - val_loss: 0.0013 - val_mae: 0.0179
# Epoch 135/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0013 - mae: 0.0182 - val_loss: 0.0013 - val_mae: 0.0180
# Epoch 136/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0013 - mae: 0.0180 - val_loss: 0.0013 - val_mae: 0.0177
# Epoch 137/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0013 - mae: 0.0179 - val_loss: 0.0014 - val_mae: 0.0183
# Epoch 138/1500
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0013 - mae: 0.0181 - val_loss: 0.0014 - val_mae: 0.0186
# Epoch 139/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0013 - mae: 0.0179 - val_loss: 0.0013 - val_mae: 0.0177
# Epoch 140/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0013 - mae: 0.0179 - val_loss: 0.0013 - val_mae: 0.0178
# Epoch 141/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0013 - mae: 0.0179 - val_loss: 0.0013 - val_mae: 0.0171
# Epoch 142/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0012 - mae: 0.0176 - val_loss: 0.0012 - val_mae: 0.0168
# Epoch 143/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0012 - mae: 0.0177 - val_loss: 0.0013 - val_mae: 0.0180
# Epoch 144/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0012 - mae: 0.0176 - val_loss: 0.0013 - val_mae: 0.0181
# Epoch 145/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0012 - mae: 0.0177 - val_loss: 0.0013 - val_mae: 0.0175
# Epoch 146/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0012 - mae: 0.0176 - val_loss: 0.0013 - val_mae: 0.0176
# Epoch 147/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0012 - mae: 0.0174 - val_loss: 0.0013 - val_mae: 0.0178
# Epoch 148/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0012 - mae: 0.0175 - val_loss: 0.0013 - val_mae: 0.0174
# Epoch 149/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0012 - mae: 0.0174 - val_loss: 0.0012 - val_mae: 0.0171
# Epoch 150/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0012 - mae: 0.0173 - val_loss: 0.0012 - val_mae: 0.0167
# Epoch 151/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0012 - mae: 0.0174 - val_loss: 0.0012 - val_mae: 0.0167
# Epoch 152/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0012 - mae: 0.0172 - val_loss: 0.0013 - val_mae: 0.0177
# Epoch 153/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0012 - mae: 0.0173 - val_loss: 0.0013 - val_mae: 0.0176
# Epoch 154/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0012 - mae: 0.0172 - val_loss: 0.0012 - val_mae: 0.0162
# Epoch 155/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0012 - mae: 0.0171 - val_loss: 0.0013 - val_mae: 0.0179
# Epoch 156/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0012 - mae: 0.0173 - val_loss: 0.0013 - val_mae: 0.0172
# Epoch 157/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0011 - mae: 0.0169 - val_loss: 0.0012 - val_mae: 0.0169
# Epoch 158/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0011 - mae: 0.0170 - val_loss: 0.0012 - val_mae: 0.0164
# Epoch 159/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0012 - mae: 0.0171 - val_loss: 0.0012 - val_mae: 0.0172
# Epoch 160/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0012 - mae: 0.0170 - val_loss: 0.0012 - val_mae: 0.0177
# Epoch 161/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0011 - mae: 0.0168 - val_loss: 0.0012 - val_mae: 0.0164
# Epoch 162/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0011 - mae: 0.0168 - val_loss: 0.0012 - val_mae: 0.0177
# Epoch 163/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0011 - mae: 0.0168 - val_loss: 0.0012 - val_mae: 0.0166
# Epoch 164/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0011 - mae: 0.0168 - val_loss: 0.0012 - val_mae: 0.0169
# Epoch 165/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0011 - mae: 0.0167 - val_loss: 0.0012 - val_mae: 0.0166
# Epoch 166/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0011 - mae: 0.0167 - val_loss: 0.0011 - val_mae: 0.0158
# Epoch 167/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0011 - mae: 0.0166 - val_loss: 0.0012 - val_mae: 0.0167
# Epoch 168/1500
# 1120/1120 [==============================] - 9s 8ms/step - loss: 0.0011 - mae: 0.0166 - val_loss: 0.0012 - val_mae: 0.0163
# Epoch 169/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0011 - mae: 0.0166 - val_loss: 0.0012 - val_mae: 0.0166
# Epoch 170/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0011 - mae: 0.0165 - val_loss: 0.0012 - val_mae: 0.0165
# Epoch 171/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0011 - mae: 0.0165 - val_loss: 0.0012 - val_mae: 0.0172
# Epoch 172/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0011 - mae: 0.0166 - val_loss: 0.0011 - val_mae: 0.0160
# Epoch 173/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0011 - mae: 0.0165 - val_loss: 0.0012 - val_mae: 0.0162
# Epoch 174/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0011 - mae: 0.0162 - val_loss: 0.0011 - val_mae: 0.0164
# Epoch 175/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0011 - mae: 0.0163 - val_loss: 0.0011 - val_mae: 0.0160
# Epoch 176/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0011 - mae: 0.0162 - val_loss: 0.0012 - val_mae: 0.0165
# Epoch 177/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0011 - mae: 0.0162 - val_loss: 0.0013 - val_mae: 0.0176
# Epoch 178/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 0.0011 - mae: 0.
1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 2.3800e-04 - mae: 0.0076 - val_loss: 3.9748e-04 - val_mae: 0.0072
# Epoch 1486/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 2.3065e-04 - mae: 0.0075 - val_loss: 4.5751e-04 - val_mae: 0.0092
# Epoch 1487/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 2.3893e-04 - mae: 0.0076 - val_loss: 4.2368e-04 - val_mae: 0.0080
# Epoch 1488/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 2.2821e-04 - mae: 0.0074 - val_loss: 4.2053e-04 - val_mae: 0.0080
# Epoch 1489/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 2.3744e-04 - mae: 0.0076 - val_loss: 4.1608e-04 - val_mae: 0.0077
# Epoch 1490/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 2.3249e-04 - mae: 0.0076 - val_loss: 4.0385e-04 - val_mae: 0.0073
# Epoch 1491/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 2.2935e-04 - mae: 0.0075 - val_loss: 4.4006e-04 - val_mae: 0.0078
# Epoch 1492/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 4.7256e-04 - mae: 0.0082 - val_loss: 4.7597e-04 - val_mae: 0.0087
# Epoch 1493/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 2.3518e-04 - mae: 0.0075 - val_loss: 4.0041e-04 - val_mae: 0.0072
# Epoch 1494/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 2.3364e-04 - mae: 0.0076 - val_loss: 4.2509e-04 - val_mae: 0.0078
# Epoch 1495/1500
# 1120/1120 [==============================] - 10s 8ms/step - loss: 2.3540e-04 - mae: 0.0075 - val_loss: 4.4759e-04 - val_mae: 0.0084
# Epoch 1496/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 2.3183e-04 - mae: 0.0075 - val_loss: 4.3688e-04 - val_mae: 0.0088
# Epoch 1497/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 2.2736e-04 - mae: 0.0075 - val_loss: 3.9892e-04 - val_mae: 0.0075
# Epoch 1498/1500
# 1120/1120 [==============================] - 9s 8ms/step - loss: 2.3121e-04 - mae: 0.0075 - val_loss: 4.2731e-04 - val_mae: 0.0078
# Epoch 1499/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 2.3656e-04 - mae: 0.0077 - val_loss: 4.5402e-04 - val_mae: 0.0091
# Epoch 1500/1500
# 1120/1120 [==============================] - 10s 9ms/step - loss: 2.3726e-04 - mae: 0.0076 - val_loss: 4.0602e-04 - val_mae: 0.0072
# ✅ Modelo FF NN listo para usar.

# %%
# !ls -lh ff_nn_Best_Model.h5 ff_nn_best_history.json
# Out:
# -rw-rw---- 1 wsuser wscommon 132K Jul 22 15:44 ff_nn_best_history.json
# -rw-rw---- 1 wsuser wscommon 327K Jul 22 15:29 ff_nn_Best_Model.h5

# %%
from IPython.display import FileLink

# Crear enlaces para descarga
FileLink('ff_nn_Best_Model.h5')
# Out:
# /home/wsuser/work/ff_nn_Best_Model.h5

# %%
FileLink('ff_nn_best_history.json')
# Out:
# /home/wsuser/work/ff_nn_best_history.json

# %%
#import os
#os.remove("ff_nn_Best_Model.h5")
#os.remove("ff_nn_best_history.json")

# %%
accuracy_test_NN = FF_NN_network.evaluate(X_test_FF, y_test_FF)
# Out:
# 3750/3750 [==============================] - 16s 4ms/step - loss: 5.8621e-04 - mae: 0.0073

# %%
predictions_NN = FF_NN_network.predict(X_test_FF)
# Out:
# 3750/3750 [==============================] - 10s 3ms/step

# %%
y_test_FF[0]
# Out:
# array([-1.4319068 ,  0.51775264,  1.63371601,  1.45059396,  1.1975666 ,
#         1.620792  ])

# %% [markdown]
# # Verificación de métricas y validación con nuevo dataset

# %% [markdown]
# # Verificación con Dataset Lineal
